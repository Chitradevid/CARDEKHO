# %%
import pandas as pd
import json

# %%
df=pd.read_excel("C:/Users/ASUS/Downloads/bangalore_cars.xlsx")

# %%
df
# Out:
#                                          new_car_detail  \
# 0     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 1     {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 2     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 3     {'it': 0, 'ft': 'Petrol', 'bt': 'Sedan', 'km':...
# 4     {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
# ...                                                 ...
# 1476  {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
# 1477  {'it': 0, 'ft': 'Petrol', 'bt': 'Sedan', 'km':...
# 1478  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 1479  {'it': 0, 'ft': 'Diesel', 'bt': 'Hatchback', '...
# 1480  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
#
#                                        new_car_overview  \
# 0     {'heading': 'Car overview', 'top': [{'key': 'R...
# 1     {'heading': 'Car overview', 'top': [{'key': 'R...
# 2     {'heading': 'Car overview', 'top': [{'key': 'R...
# 3     {'heading': 'Car overview', 'top': [{'key': 'R...
# 4     {'heading': 'Car overview', 'top': [{'key': 'R...
# ...                                                 ...
# 1476  {'heading': 'Car overview', 'top': [{'key': 'R...
# 1477  {'heading': 'Car overview', 'top': [{'key': 'R...
# 1478  {'heading': 'Car overview', 'top': [{'key': 'R...
# 1479  {'heading': 'Car overview', 'top': [{'key': 'R...
# 1480  {'heading': 'Car overview', 'top': [{'key': 'R...
#
#                                         new_car_feature  \
# 0     {'heading': 'Features', 'top': [{'value': 'Pow...
# 1     {'heading': 'Features', 'top': [{'value': 'Pow...
# 2     {'heading': 'Features', 'top': [{'value': 'Pow...
# 3     {'heading': 'Features', 'top': [{'value': 'Pow...
# 4     {'heading': 'Features', 'top': [{'value': 'Pow...
# ...                                                 ...
# 1476  {'heading': 'Features', 'top': [{'value': 'Pow...
# 1477  {'heading': 'Features', 'top': [{'value': 'Pow...
# 1478  {'heading': 'Features', 'top': [{'value': 'Pow...
# 1479  {'heading': 'Features', 'top': [{'value': 'Pow...
# 1480  {'heading': 'Features', 'top': [{'value': 'Pow...
#
#                                           new_car_specs  \
# 0     {'heading': 'Specifications', 'top': [{'key': ...
# 1     {'heading': 'Specifications', 'top': [{'key': ...
# 2     {'heading': 'Specifications', 'top': [{'key': ...
# 3     {'heading': 'Specifications', 'top': [{'key': ...
# 4     {'heading': 'Specifications', 'top': [{'key': ...
# ...                                                 ...
# 1476  {'heading': 'Specifications', 'top': [{'key': ...
# 1477  {'heading': 'Specifications', 'top': [{'key': ...
# 1478  {'heading': 'Specifications', 'top': [{'key': ...
# 1479  {'heading': 'Specifications', 'top': [{'key': ...
# 1480  {'heading': 'Specifications', 'top': [{'key': ...
#
#                                               car_links
# 0     https://www.cardekho.com/used-car-details/used...
# 1     https://www.cardekho.com/buy-used-car-details/...
# 2     https://www.cardekho.com/used-car-details/used...
# 3     https://www.cardekho.com/buy-used-car-details/...
# 4     https://www.cardekho.com/used-car-details/used...
# ...                                                 ...
# 1476  https://www.cardekho.com/used-car-details/used...
# 1477  https://www.cardekho.com/used-car-details/used...
# 1478  https://www.cardekho.com/used-car-details/used...
# 1479  https://www.cardekho.com/used-car-details/used...
# 1480  https://www.cardekho.com/used-car-details/used...
#
# [1481 rows x 5 columns]

# %%
# Function to safely load JSON if it's a string
def safe_load(x):
    if isinstance(x, str):
        return json.loads(x.replace("'", '"').replace("None", "1"))
    return x  # If it's already a dict, return as is

# Apply the safe_load function
df["new_car_detail"] = df["new_car_detail"].apply(safe_load)

# Expand the main dictionary into columns
df_expanded = pd.DataFrame(df["new_car_detail"].to_list())

# Expand the nested dictionary into columns
df_nested_expanded = df_expanded["trendingText"].apply(pd.Series)

# Combine the original and nested DataFrame
df11 = pd.concat([df_expanded.drop(columns=["trendingText"]), df_nested_expanded], axis=1)

# %%
df11
# Out:
#       it      ft         bt        km transmission  ownerNo      owner  \
# 0      0  Petrol  Hatchback  1,20,000       Manual        3  3rd Owner
# 1      0  Petrol        SUV    32,706       Manual        2  2nd Owner
# 2      0  Petrol  Hatchback    11,949       Manual        1  1st Owner
# 3      0  Petrol      Sedan    17,794       Manual        1  1st Owner
# 4      0  Diesel        SUV    60,000       Manual        1  1st Owner
# ...   ..     ...        ...       ...          ...      ...        ...
# 1476   0  Diesel        SUV  1,56,039       Manual        2  2nd Owner
# 1477   0  Petrol      Sedan    56,000       Manual        2  2nd Owner
# 1478   0  Petrol  Hatchback    42,000       Manual        2  2nd Owner
# 1479   0  Diesel  Hatchback    93,003       Manual        1  1st Owner
# 1480   0  Petrol  Hatchback    36,000    Automatic        2  2nd Owner
#
#           oem               model  modelYear  centralVariantId  \
# 0      Maruti      Maruti Celerio       2015              3979
# 1        Ford       Ford Ecosport       2018              6087
# 2        Tata          Tata Tiago       2018              2983
# 3     Hyundai       Hyundai Xcent       2014              1867
# 4      Maruti  Maruti SX4 S Cross       2015              4277
# ...       ...                 ...        ...               ...
# 1476   Toyota     Toyota Fortuner       2012              2253
# 1477   Maruti          Maruti SX4       2008              4257
# 1478    Honda          Honda Brio       2014              1188
# 1479  Hyundai         Hyundai i20       2018              5695
# 1480  Hyundai   Hyundai Grand i10       2017              1523
#
#                    variantName         price priceActual priceSaving  \
# 0                          VXI      ₹ 4 Lakh
# 1     1.5 Petrol Titanium BSIV   ₹ 8.11 Lakh
# 2              1.2 Revotron XZ   ₹ 5.85 Lakh
# 3           1.2 Kappa S Option   ₹ 4.62 Lakh
# 4                DDiS 200 Zeta   ₹ 7.90 Lakh
# ...                        ...           ...         ...         ...
# 1476                    4x4 MT  ₹ 16.49 Lakh
# 1477                 Zxi BSIII   ₹ 3.30 Lakh
# 1478                      S MT   ₹ 4.25 Lakh
# 1479        1.4 Asta Dual Tone   ₹ 7.50 Lakh
# 1480            Asta Option AT   ₹ 6.75 Lakh
#
#       priceFixedText                                             imgUrl  \
# 0                  1  https://stimg.cardekho.com/used-cars/common/ic...
# 1                  1  https://stimg.cardekho.com/used-cars/common/ic...
# 2                  1  https://stimg.cardekho.com/used-cars/common/ic...
# 3                  1  https://stimg.cardekho.com/used-cars/common/ic...
# 4                  1  https://stimg.cardekho.com/used-cars/common/ic...
# ...              ...                                                ...
# 1476               1  https://stimg.cardekho.com/used-cars/common/ic...
# 1477               1  https://stimg.cardekho.com/used-cars/common/ic...
# 1478               1  https://stimg.cardekho.com/used-cars/common/ic...
# 1479               1  https://stimg.cardekho.com/used-cars/common/ic...
# 1480               1  https://stimg.cardekho.com/used-cars/common/ic...
#
#             heading                                 desc
# 0     Trending Car!  High chances of sale in next 6 days
# 1     Trending Car!  High chances of sale in next 6 days
# 2     Trending Car!  High chances of sale in next 6 days
# 3     Trending Car!  High chances of sale in next 6 days
# 4     Trending Car!  High chances of sale in next 6 days
# ...             ...                                  ...
# 1476  Trending Car!  High chances of sale in next 6 days
# 1477  Trending Car!  High chances of sale in next 6 days
# 1478  Trending Car!  High chances of sale in next 6 days
# 1479  Trending Car!  High chances of sale in next 6 days
# 1480  Trending Car!  High chances of sale in next 6 days
#
# [1481 rows x 19 columns]

# %%
#OVERVIEW

# %%
df["new_car_overview"]
# Out:
# 0       {'heading': 'Car overview', 'top': [{'key': 'R...
# 1       {'heading': 'Car overview', 'top': [{'key': 'R...
# 2       {'heading': 'Car overview', 'top': [{'key': 'R...
# 3       {'heading': 'Car overview', 'top': [{'key': 'R...
# 4       {'heading': 'Car overview', 'top': [{'key': 'R...
#                               ...
# 1476    {'heading': 'Car overview', 'top': [{'key': 'R...
# 1477    {'heading': 'Car overview', 'top': [{'key': 'R...
# 1478    {'heading': 'Car overview', 'top': [{'key': 'R...
# 1479    {'heading': 'Car overview', 'top': [{'key': 'R...
# 1480    {'heading': 'Car overview', 'top': [{'key': 'R...
# Name: new_car_overview, Length: 1481, dtype: object

# %%
import pandas as pd
import json

# Function to safely load JSON if it's a string
def safe_load(x):
    if isinstance(x, str):
        try:
            return json.loads(x.replace("'", '"').replace("None", "1"))
        except json.JSONDecodeError:
            return None  # Return None if JSON loading fails
    return x  # If it's already a list or dict, return as is

# Apply the safe_load function to the 'new_car_overview' column
df["new_car_overview"] = df["new_car_overview"].apply(safe_load)

# Function to extract key-value pairs from the list of dictionaries
def extract_key_value_pairs(dict_list):
    if isinstance(dict_list, list):  # Check if the item is a list
        extracted_data = {}
        for item in dict_list:
            if isinstance(item, dict):  # Ensure each item is a dictionary
                key = item.get('key')
                value = item.get('value')
                if key:  # Only add if the key exists
                    extracted_data[key] = value
        return pd.Series(extracted_data)
    return pd.Series()  # Return an empty Series if dict_list is not a list

# Expand the 'new_car_overview' column into a new DataFrame
df_expanded = df["new_car_overview"].apply(extract_key_value_pairs)

# %%
def extract_key_value_pairs(dict_list):
    if isinstance(dict_list, list):
        extracted_data = {}
        for item in dict_list:
            if isinstance(item, dict):
                key = item.get('key')
                value = item.get('value')
                if key:  # Only add if the key exists
                    extracted_data[key] = value
        return pd.Series(extracted_data)
    return pd.Series()  # Return an empty Series if dict_list is not a list

# Apply the extraction function to the 'top' column
df2 = df['new_car_overview'].apply(lambda x: x['top'] if isinstance(x, dict) else None).apply(extract_key_value_pairs)

# %%
df2
# Out:
#      Registration Year     Insurance Validity Fuel Type    Seats  \
# 0                 2015  Third Party insurance    Petrol  5 Seats
# 1             Feb 2018          Comprehensive    Petrol  5 Seats
# 2            Sept 2018          Comprehensive    Petrol  5 Seats
# 3             Dec 2014          Comprehensive    Petrol  5 Seats
# 4                 2015  Third Party insurance    Diesel  5 Seats
# ...                ...                    ...       ...      ...
# 1476          May 2012          Comprehensive    Diesel  7 Seats
# 1477          Jun 2008  Third Party insurance    Petrol  5 Seats
# 1478         Sept 2014          Comprehensive    Petrol  5 Seats
# 1479          Dec 2018          Comprehensive    Diesel  5 Seats
# 1480          May 2017          Comprehensive    Petrol  5 Seats
#
#         Kms Driven   RTO     Ownership Engine Displacement Transmission  \
# 0     1,20,000 Kms  KA51   Third Owner              998 cc       Manual
# 1       32,706 Kms  KA05  Second Owner             1497 cc       Manual
# 2       11,949 Kms  KA03   First Owner             1199 cc       Manual
# 3       17,794 Kms  KA53   First Owner             1197 cc       Manual
# 4       60,000 Kms  KA04   First Owner             1248 cc       Manual
# ...            ...   ...           ...                 ...          ...
# 1476  1,56,039 Kms  KA01  Second Owner             2982 cc       Manual
# 1477    56,000 Kms  KA02  Second Owner             1586 cc       Manual
# 1478    42,000 Kms  KA03  Second Owner             1198 cc       Manual
# 1479    93,003 Kms  KA03   First Owner             1396 cc       Manual
# 1480    36,000 Kms  KA04  Second Owner             1197 cc    Automatic
#
#       Year of Manufacture
# 0                  2015.0
# 1                  2018.0
# 2                  2018.0
# 3                  2014.0
# 4                  2015.0
# ...                   ...
# 1476               2012.0
# 1477               2008.0
# 1478               2014.0
# 1479               2018.0
# 1480               2017.0
#
# [1481 rows x 10 columns]

# %%
# Concatenate horizontally
dfb= pd.concat([df11, df2], axis=1)

# %%
#features

# %%
df.new_car_feature=df["new_car_feature"].apply(lambda x:json.loads(x.replace("'",'"').replace("None","1")))
df_new=pd.DataFrame(df.new_car_feature.to_list())

# %%
df_new
# Out:
#        heading                                                top  \
# 0     Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 1     Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 2     Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 3     Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 4     Features  [{'value': 'Power Steering'}, {'value': 'Power...
# ...        ...                                                ...
# 1476  Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 1477  Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 1478  Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 1479  Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 1480  Features  [{'value': 'Power Steering'}, {'value': 'Power...
#
#                                                    data  \
# 0     [{'heading': 'Comfort & Convenience', 'subHead...
# 1     [{'heading': 'Comfort & Convenience', 'subHead...
# 2     [{'heading': 'Comfort & Convenience', 'subHead...
# 3     [{'heading': 'Comfort & Convenience', 'subHead...
# 4     [{'heading': 'Comfort & Convenience', 'subHead...
# ...                                                 ...
# 1476  [{'heading': 'Comfort & Convenience', 'subHead...
# 1477  [{'heading': 'Comfort & Convenience', 'subHead...
# 1478  [{'heading': 'Comfort & Convenience', 'subHead...
# 1479  [{'heading': 'Comfort & Convenience', 'subHead...
# 1480  [{'heading': 'Comfort & Convenience', 'subHead...
#
#                                              commonIcon
# 0     https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1     https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 2     https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 3     https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 4     https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# ...                                                 ...
# 1476  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1477  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1478  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1479  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1480  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
#
# [1481 rows x 4 columns]

# %%
import pandas as pd
import numpy as np


# Ensure 'top' column contains lists; replace non-lists with empty lists
df_new['top'] = df_new['top'].apply(lambda x: x if isinstance(x, list) else [])

# Extract feature values and concatenate them into a single string per row
df_new['Features'] = df_new['top'].apply(lambda x: ', '.join([item['value'] for item in x]))

# Drop the original 'top' column if no longer needed
df_new = df_new.drop(columns=['top'])

df_new
# Out:
#        heading                                               data  \
# 0     Features  [{'heading': 'Comfort & Convenience', 'subHead...
# 1     Features  [{'heading': 'Comfort & Convenience', 'subHead...
# 2     Features  [{'heading': 'Comfort & Convenience', 'subHead...
# 3     Features  [{'heading': 'Comfort & Convenience', 'subHead...
# 4     Features  [{'heading': 'Comfort & Convenience', 'subHead...
# ...        ...                                                ...
# 1476  Features  [{'heading': 'Comfort & Convenience', 'subHead...
# 1477  Features  [{'heading': 'Comfort & Convenience', 'subHead...
# 1478  Features  [{'heading': 'Comfort & Convenience', 'subHead...
# 1479  Features  [{'heading': 'Comfort & Convenience', 'subHead...
# 1480  Features  [{'heading': 'Comfort & Convenience', 'subHead...
#
#                                              commonIcon  \
# 0     https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1     https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 2     https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 3     https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 4     https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# ...                                                 ...
# 1476  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1477  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1478  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1479  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1480  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
#
#                                                Features
# 0     Power Steering, Power Windows Front, Air Condi...
# 1     Power Steering, Power Windows Front, Air Condi...
# 2     Power Steering, Power Windows Front, Air Condi...
# 3     Power Steering, Power Windows Front, Air Condi...
# 4     Power Steering, Power Windows Front, Air Condi...
# ...                                                 ...
# 1476  Power Steering, Power Windows Front, Air Condi...
# 1477  Power Steering, Power Windows Front, Air Condi...
# 1478  Power Steering, Power Windows Front, Air Condi...
# 1479  Power Steering, Power Windows Front, Air Condi...
# 1480  Power Steering, Power Windows Front, Air Condi...
#
# [1481 rows x 4 columns]

# %%
# Function to extract features and create columns
def extract_features(data):
    features_dict = {}
    for category in data:
        sub_heading = category['subHeading']
        features = [item['value'] for item in category['list']]
        features_dict[sub_heading] = ', '.join(features)
    return features_dict

# Apply the function to the 'data' column and convert to DataFrame
features_df = pd.json_normalize(df_new['data'].apply(extract_features))

# Concatenate with the original DataFrame 
df3 = pd.concat([df_new.drop(columns=['data']), features_df], axis=1)
df3
# Out:
#        heading                                         commonIcon  \
# 0     Features  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1     Features  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 2     Features  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 3     Features  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 4     Features  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# ...        ...                                                ...
# 1476  Features  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1477  Features  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1478  Features  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1479  Features  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1480  Features  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
#
#                                                Features  \
# 0     Power Steering, Power Windows Front, Air Condi...
# 1     Power Steering, Power Windows Front, Air Condi...
# 2     Power Steering, Power Windows Front, Air Condi...
# 3     Power Steering, Power Windows Front, Air Condi...
# 4     Power Steering, Power Windows Front, Air Condi...
# ...                                                 ...
# 1476  Power Steering, Power Windows Front, Air Condi...
# 1477  Power Steering, Power Windows Front, Air Condi...
# 1478  Power Steering, Power Windows Front, Air Condi...
# 1479  Power Steering, Power Windows Front, Air Condi...
# 1480  Power Steering, Power Windows Front, Air Condi...
#
#                                                 Comfort  \
# 0     Power Steering, Power Windows Front, Power Win...
# 1     Power Steering, Power Windows Front, Power Win...
# 2     Power Steering, Power Windows Front, Power Win...
# 3     Power Steering, Power Windows Front, Power Win...
# 4     Power Steering, Power Windows Front, Power Win...
# ...                                                 ...
# 1476  Power Steering, Power Windows Front, Power Win...
# 1477  Power Steering, Power Windows Front, Power Win...
# 1478  Power Steering, Power Windows Front, Power Win...
# 1479  Power Steering, Power Windows Front, Power Win...
# 1480  Power Steering, Power Windows Front, Power Win...
#
#                                                Interior  \
# 0     Air Conditioner, Heater, Digital Odometer, Ele...
# 1     Air Conditioner, Heater, Adjustable Steering, ...
# 2     Air Conditioner, Heater, Adjustable Steering, ...
# 3     Air Conditioner, Heater, Adjustable Steering, ...
# 4     Air Conditioner, Heater, Adjustable Steering, ...
# ...                                                 ...
# 1476  Air Conditioner, Heater, Adjustable Steering, ...
# 1477  Air Conditioner, Heater, Adjustable Steering, ...
# 1478  Air Conditioner, Heater, Digital Odometer, Tac...
# 1479  Air Conditioner, Heater, Adjustable Steering, ...
# 1480  Air Conditioner, Heater, Adjustable Steering, ...
#
#                                                Exterior  \
# 0     Adjustable Head Lights, Manually Adjustable Ex...
# 1     Adjustable Head Lights, Fog Lights Front, Powe...
# 2     Adjustable Head Lights, Fog Lights Front, Powe...
# 3     Adjustable Head Lights, Fog Lights Front, Powe...
# 4     Adjustable Head Lights, Fog Lights Front, Powe...
# ...                                                 ...
# 1476  Adjustable Head Lights, Fog Lights Front, Powe...
# 1477  Fog Lights Front, Fog Lights Rear, Power Adjus...
# 1478  Adjustable Head Lights, Power Adjustable Exter...
# 1479  Adjustable Head Lights, Fog Lights Front, Powe...
# 1480  Adjustable Head Lights, Fog Lights Front, Powe...
#
#                                                  Safety  \
# 0     Centeral Locking, Child Safety Locks, Day Nigh...
# 1     Anti Lock Braking System, Centeral Locking, Po...
# 2     Anti Lock Braking System, Centeral Locking, Po...
# 3     Anti Lock Braking System, Centeral Locking, Po...
# 4     Anti Lock Braking System, Centeral Locking, Po...
# ...                                                 ...
# 1476  Anti Lock Braking System, Brake Assist, Center...
# 1477  Anti Lock Braking System, Brake Assist, Center...
# 1478  Centeral Locking, Power Door Locks, Child Safe...
# 1479  Anti Lock Braking System, Centeral Locking, Po...
# 1480  Anti Lock Braking System, Centeral Locking, Po...
#
#                                           Entertainment
# 0                                                   NaN
# 1     Cd Player, Radio, Speakers Front, Speakers Rea...
# 2     Cd Player, Radio, Speakers Front, Speakers Rea...
# 3     Cd Player, Radio, Speakers Front, Speakers Rea...
# 4     Radio, Audio System Remote Control, Speakers F...
# ...                                                 ...
# 1476  Cd Player, Dvd Player, Radio, Audio System Rem...
# 1477  Cd Player, Radio, Audio System Remote Control,...
# 1478  Radio, Speakers Front, Speakers Rear, Integrat...
# 1479  Cd Player, Radio, Speakers Front, Speakers Rea...
# 1480  Cd Player, Radio, Speakers Front, Speakers Rea...
#
# [1481 rows x 8 columns]

# %%
# Concatenate horizontally
dfb=pd.concat([dfb, df3], axis=1)

# %%
dfb
# Out:
#       it      ft         bt        km transmission  ownerNo      owner  \
# 0      0  Petrol  Hatchback  1,20,000       Manual        3  3rd Owner
# 1      0  Petrol        SUV    32,706       Manual        2  2nd Owner
# 2      0  Petrol  Hatchback    11,949       Manual        1  1st Owner
# 3      0  Petrol      Sedan    17,794       Manual        1  1st Owner
# 4      0  Diesel        SUV    60,000       Manual        1  1st Owner
# ...   ..     ...        ...       ...          ...      ...        ...
# 1476   0  Diesel        SUV  1,56,039       Manual        2  2nd Owner
# 1477   0  Petrol      Sedan    56,000       Manual        2  2nd Owner
# 1478   0  Petrol  Hatchback    42,000       Manual        2  2nd Owner
# 1479   0  Diesel  Hatchback    93,003       Manual        1  1st Owner
# 1480   0  Petrol  Hatchback    36,000    Automatic        2  2nd Owner
#
#           oem               model  modelYear  ...  Transmission  \
# 0      Maruti      Maruti Celerio       2015  ...        Manual
# 1        Ford       Ford Ecosport       2018  ...        Manual
# 2        Tata          Tata Tiago       2018  ...        Manual
# 3     Hyundai       Hyundai Xcent       2014  ...        Manual
# 4      Maruti  Maruti SX4 S Cross       2015  ...        Manual
# ...       ...                 ...        ...  ...           ...
# 1476   Toyota     Toyota Fortuner       2012  ...        Manual
# 1477   Maruti          Maruti SX4       2008  ...        Manual
# 1478    Honda          Honda Brio       2014  ...        Manual
# 1479  Hyundai         Hyundai i20       2018  ...        Manual
# 1480  Hyundai   Hyundai Grand i10       2017  ...     Automatic
#
#      Year of Manufacture   heading  \
# 0                 2015.0  Features
# 1                 2018.0  Features
# 2                 2018.0  Features
# 3                 2014.0  Features
# 4                 2015.0  Features
# ...                  ...       ...
# 1476              2012.0  Features
# 1477              2008.0  Features
# 1478              2014.0  Features
# 1479              2018.0  Features
# 1480              2017.0  Features
#
#                                              commonIcon  \
# 0     https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1     https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 2     https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 3     https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 4     https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# ...                                                 ...
# 1476  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1477  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1478  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1479  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1480  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
#
#                                                Features  \
# 0     Power Steering, Power Windows Front, Air Condi...
# 1     Power Steering, Power Windows Front, Air Condi...
# 2     Power Steering, Power Windows Front, Air Condi...
# 3     Power Steering, Power Windows Front, Air Condi...
# 4     Power Steering, Power Windows Front, Air Condi...
# ...                                                 ...
# 1476  Power Steering, Power Windows Front, Air Condi...
# 1477  Power Steering, Power Windows Front, Air Condi...
# 1478  Power Steering, Power Windows Front, Air Condi...
# 1479  Power Steering, Power Windows Front, Air Condi...
# 1480  Power Steering, Power Windows Front, Air Condi...
#
#                                                 Comfort  \
# 0     Power Steering, Power Windows Front, Power Win...
# 1     Power Steering, Power Windows Front, Power Win...
# 2     Power Steering, Power Windows Front, Power Win...
# 3     Power Steering, Power Windows Front, Power Win...
# 4     Power Steering, Power Windows Front, Power Win...
# ...                                                 ...
# 1476  Power Steering, Power Windows Front, Power Win...
# 1477  Power Steering, Power Windows Front, Power Win...
# 1478  Power Steering, Power Windows Front, Power Win...
# 1479  Power Steering, Power Windows Front, Power Win...
# 1480  Power Steering, Power Windows Front, Power Win...
#
#                                                Interior  \
# 0     Air Conditioner, Heater, Digital Odometer, Ele...
# 1     Air Conditioner, Heater, Adjustable Steering, ...
# 2     Air Conditioner, Heater, Adjustable Steering, ...
# 3     Air Conditioner, Heater, Adjustable Steering, ...
# 4     Air Conditioner, Heater, Adjustable Steering, ...
# ...                                                 ...
# 1476  Air Conditioner, Heater, Adjustable Steering, ...
# 1477  Air Conditioner, Heater, Adjustable Steering, ...
# 1478  Air Conditioner, Heater, Digital Odometer, Tac...
# 1479  Air Conditioner, Heater, Adjustable Steering, ...
# 1480  Air Conditioner, Heater, Adjustable Steering, ...
#
#                                                Exterior  \
# 0     Adjustable Head Lights, Manually Adjustable Ex...
# 1     Adjustable Head Lights, Fog Lights Front, Powe...
# 2     Adjustable Head Lights, Fog Lights Front, Powe...
# 3     Adjustable Head Lights, Fog Lights Front, Powe...
# 4     Adjustable Head Lights, Fog Lights Front, Powe...
# ...                                                 ...
# 1476  Adjustable Head Lights, Fog Lights Front, Powe...
# 1477  Fog Lights Front, Fog Lights Rear, Power Adjus...
# 1478  Adjustable Head Lights, Power Adjustable Exter...
# 1479  Adjustable Head Lights, Fog Lights Front, Powe...
# 1480  Adjustable Head Lights, Fog Lights Front, Powe...
#
#                                                  Safety  \
# 0     Centeral Locking, Child Safety Locks, Day Nigh...
# 1     Anti Lock Braking System, Centeral Locking, Po...
# 2     Anti Lock Braking System, Centeral Locking, Po...
# 3     Anti Lock Braking System, Centeral Locking, Po...
# 4     Anti Lock Braking System, Centeral Locking, Po...
# ...                                                 ...
# 1476  Anti Lock Braking System, Brake Assist, Center...
# 1477  Anti Lock Braking System, Brake Assist, Center...
# 1478  Centeral Locking, Power Door Locks, Child Safe...
# 1479  Anti Lock Braking System, Centeral Locking, Po...
# 1480  Anti Lock Braking System, Centeral Locking, Po...
#
#                                           Entertainment
# 0                                                   NaN
# 1     Cd Player, Radio, Speakers Front, Speakers Rea...
# 2     Cd Player, Radio, Speakers Front, Speakers Rea...
# 3     Cd Player, Radio, Speakers Front, Speakers Rea...
# 4     Radio, Audio System Remote Control, Speakers F...
# ...                                                 ...
# 1476  Cd Player, Dvd Player, Radio, Audio System Rem...
# 1477  Cd Player, Radio, Audio System Remote Control,...
# 1478  Radio, Speakers Front, Speakers Rear, Integrat...
# 1479  Cd Player, Radio, Speakers Front, Speakers Rea...
# 1480  Cd Player, Radio, Speakers Front, Speakers Rea...
#
# [1481 rows x 37 columns]

# %%
#SPECIFICATION

# %%
import pandas as pd
import json

# Function to safely convert JSON strings to dictionaries
def safe_json_loads(x):
    if isinstance(x, str):  # Check if the data is a string
        try:
            # Replace single quotes with double quotes and handle 'None'
            return json.loads(x.replace("'", '"').replace("None", "1"))
        except json.JSONDecodeError:
            # Handle JSON parsing errors
            print(f"Error decoding JSON for: {x}")
            return None
    elif isinstance(x, dict):
        # If already a dictionary, return it as is
        return x
    else:
        # Handle unexpected data types
        print(f"Unexpected data type: {type(x)}")
        return None

# Apply the function to safely transform the data
df['new_car_specs'] = df['new_car_specs'].apply(safe_json_loads)

# Convert the list of dictionaries to a DataFrame
df_new = pd.DataFrame(df['new_car_specs'].tolist())
df_new
# Out:
#              heading                                                top  \
# 0     Specifications  [{'key': 'Mileage', 'value': '23.1 kmpl'}, {'k...
# 1     Specifications  [{'key': 'Mileage', 'value': '17 kmpl'}, {'key...
# 2     Specifications  [{'key': 'Mileage', 'value': '23.84 kmpl'}, {'...
# 3     Specifications  [{'key': 'Mileage', 'value': '19.1 kmpl'}, {'k...
# 4     Specifications  [{'key': 'Mileage', 'value': '23.65 kmpl'}, {'...
# ...              ...                                                ...
# 1476  Specifications  [{'key': 'Mileage', 'value': '12.55 kmpl'}, {'...
# 1477  Specifications  [{'key': 'Mileage', 'value': '15 kmpl'}, {'key...
# 1478  Specifications  [{'key': 'Mileage', 'value': '19.4 kmpl'}, {'k...
# 1479  Specifications  [{'key': 'Mileage', 'value': '22.54 kmpl'}, {'...
# 1480  Specifications  [{'key': 'Mileage', 'value': '18.9 kmpl'}, {'k...
#
#                                                    data commonIcon
# 0     [{'heading': 'Engine and Transmission', 'subHe...
# 1     [{'heading': 'Engine and Transmission', 'subHe...
# 2     [{'heading': 'Engine and Transmission', 'subHe...
# 3     [{'heading': 'Engine and Transmission', 'subHe...
# 4     [{'heading': 'Engine and Transmission', 'subHe...
# ...                                                 ...        ...
# 1476  [{'heading': 'Engine and Transmission', 'subHe...
# 1477  [{'heading': 'Engine and Transmission', 'subHe...
# 1478  [{'heading': 'Engine and Transmission', 'subHe...
# 1479  [{'heading': 'Engine and Transmission', 'subHe...
# 1480  [{'heading': 'Engine and Transmission', 'subHe...
#
# [1481 rows x 4 columns]

# %%
# Function to extract 'top' key-value pairs and add them as columns
def extract_top(row):
    if isinstance(row['top'], list):
        for item in row['top']:
            row[item['key']] = item['value']
    return row

# Apply the function to the DataFrame
df_new = df_new.apply(extract_top, axis=1)

# Drop the 'top' column after extraction
df_new.drop(columns=['top'], inplace=True)
df_new
# Out:
#        Engine  Max Power     Mileage Seats    Torque Wheel Size commonIcon  \
# 0      998 CC   67.04bhp   23.1 kmpl     5      90Nm        NaN
# 1     1497 CC  121.31bhp     17 kmpl     5     150Nm         16
# 2     1199 CC      84bhp  23.84 kmpl     5     114Nm         14
# 3     1197 CC   81.86bhp   19.1 kmpl     5  113.75Nm         14
# 4     1248 CC    88.5bhp  23.65 kmpl     5     200Nm         16
# ...       ...        ...         ...   ...       ...        ...        ...
# 1476  2982 CC   168.5bhp  12.55 kmpl     7     343Nm         17
# 1477  1586 CC     104.68     15 kmpl     5       145         16
# 1478  1198 CC    86.8bhp   19.4 kmpl     5     109Nm        NaN
# 1479  1396 CC   88.73bhp  22.54 kmpl     5   219.7Nm         16
# 1480  1197 CC      82bhp   18.9 kmpl     5     114Nm         14
#
#                                                    data         heading
# 0     [{'heading': 'Engine and Transmission', 'subHe...  Specifications
# 1     [{'heading': 'Engine and Transmission', 'subHe...  Specifications
# 2     [{'heading': 'Engine and Transmission', 'subHe...  Specifications
# 3     [{'heading': 'Engine and Transmission', 'subHe...  Specifications
# 4     [{'heading': 'Engine and Transmission', 'subHe...  Specifications
# ...                                                 ...             ...
# 1476  [{'heading': 'Engine and Transmission', 'subHe...  Specifications
# 1477  [{'heading': 'Engine and Transmission', 'subHe...  Specifications
# 1478  [{'heading': 'Engine and Transmission', 'subHe...  Specifications
# 1479  [{'heading': 'Engine and Transmission', 'subHe...  Specifications
# 1480  [{'heading': 'Engine and Transmission', 'subHe...  Specifications
#
# [1481 rows x 9 columns]

# %%
# Function to extract 'data' key-value pairs and add them as columns
def extract_data(row):
    if isinstance(row['data'], list):
        for section in row['data']:
            for item in section['list']:
                row[item['key']] = item['value']
    return row

# Apply the function to the DataFrame
df_new = df_new.apply(extract_data, axis=1)

# Drop the 'data' column after extraction
df_new.drop(columns=['data'], inplace=True)

# %%
df4=df_new

# %%
df4
# Out:
#        Acceleration Alloy Wheel Size  BoreX Stroke Cargo Volumn   Color  \
# 0     15.05 Seconds              NaN    73 X 82 mm   235-litres   White
# 1               NaN               16  79 X 76.5 mm   352-litres   White
# 2      14.3 Seconds               14  77 X 85.8 mm   242-litres     Red
# 3      14.2 Seconds               14           NaN   407-litres  Others
# 4        12 Seconds               16  69.6 x 82 mm   353-litres    Gray
# ...             ...              ...           ...          ...     ...
# 1476    9.6 Seconds               17           NaN   296-litres    Blue
# 1477   12.1 seconds               16    78 x 83 mm   505 litres     Red
# 1478   14.5 Seconds              NaN           NaN   175-litres   White
# 1479   11.9 Seconds               16           NaN   295-litres     Red
# 1480   12.9 Seconds               14           NaN   256-liters   White
#
#      Compression Ratio Displacement Drive Type   Engine  \
# 0               11.0:1          998        FWD   998 CC
# 1               11.0:1         1497        FWD  1497 CC
# 2               10.8:1         1199        FWD  1199 CC
# 3                  NaN         1197       FWD   1197 CC
# 4                  NaN         1248        FWD  1248 CC
# ...                ...          ...        ...      ...
# 1476               NaN         2982        4WD  2982 CC
# 1477              9:01         1586        NaN  1586 CC
# 1478               NaN         1198        FWD  1198 CC
# 1479               NaN         1396        FWD  1396 CC
# 1480               NaN         1197        FWD  1197 CC
#
#                    Engine Type  ... Turbo Charger Turning Radius  \
# 0                  K10B Engine  ...            No     4.7 metres
# 1         Ti-VCT Petrol Engine  ...            No     5.3 metres
# 2              Revotron Engine  ...            No     4.9 meters
# 3     Kappa VTVT Petrol Engine  ...            No     4.7 metres
# 4       DDiS 200 Diesel Engine  ...           Yes     5.2 meters
# ...                        ...  ...           ...            ...
# 1476        D-4D Diesel Engine  ...           Yes     5.9 metres
# 1477            In-Line Engine  ...            No          5.3 m
# 1478             i-VTEC Engine  ...            No     4.5 metres
# 1479     U2 CRDI Diesel Engine  ...           Yes     5.2 metres
# 1480  Kappa VTVT Petrol Engine  ...            No     4.8 metres
#
#              Tyre Type Value Configuration Values per Cylinder Wheel Base  \
# 0     Tubeless, Radial                DOHC                 4.0     2425mm
# 1      Tubeless,Radial                DOHC                 4.0     2519mm
# 2             Tubeless                DOHC                 4.0     2400mm
# 3      Tubeless,Radial                DOHC                 4.0     2425mm
# 4      Tubeless,Radial                DOHC                 4.0     2600mm
# ...                ...                 ...                 ...        ...
# 1476   Tubeless,Radial                DOHC                 4.0     2750mm
# 1477  Tubeless, Radial                DOHC                 4.0     2500mm
# 1478   Tubeless,Radial                SOHC                 4.0     2345mm
# 1479          Tubeless                DOHC                 4.0     2570mm
# 1480          Tubeless                DOHC                 4.0     2425mm
#
#      Wheel Size   Width commonIcon         heading
# 0           NaN  1635mm             Specifications
# 1            16  1765mm             Specifications
# 2            14  1647mm             Specifications
# 3            14  1660mm             Specifications
# 4            16  1785mm             Specifications
# ...         ...     ...        ...             ...
# 1476         17  1840mm             Specifications
# 1477         16  1735mm             Specifications
# 1478        NaN  1680mm             Specifications
# 1479         16  1734mm             Specifications
# 1480         14  1660mm             Specifications
#
# [1481 rows x 42 columns]

# %%
# Concatenate horizontally
df_bangalore=pd.concat([dfb, df4], axis=1)

# %%
df_bangalore
# Out:
#       it      ft         bt        km transmission  ownerNo      owner  \
# 0      0  Petrol  Hatchback  1,20,000       Manual        3  3rd Owner
# 1      0  Petrol        SUV    32,706       Manual        2  2nd Owner
# 2      0  Petrol  Hatchback    11,949       Manual        1  1st Owner
# 3      0  Petrol      Sedan    17,794       Manual        1  1st Owner
# 4      0  Diesel        SUV    60,000       Manual        1  1st Owner
# ...   ..     ...        ...       ...          ...      ...        ...
# 1476   0  Diesel        SUV  1,56,039       Manual        2  2nd Owner
# 1477   0  Petrol      Sedan    56,000       Manual        2  2nd Owner
# 1478   0  Petrol  Hatchback    42,000       Manual        2  2nd Owner
# 1479   0  Diesel  Hatchback    93,003       Manual        1  1st Owner
# 1480   0  Petrol  Hatchback    36,000    Automatic        2  2nd Owner
#
#           oem               model  modelYear  ...  Turbo Charger  \
# 0      Maruti      Maruti Celerio       2015  ...             No
# 1        Ford       Ford Ecosport       2018  ...             No
# 2        Tata          Tata Tiago       2018  ...             No
# 3     Hyundai       Hyundai Xcent       2014  ...             No
# 4      Maruti  Maruti SX4 S Cross       2015  ...            Yes
# ...       ...                 ...        ...  ...            ...
# 1476   Toyota     Toyota Fortuner       2012  ...            Yes
# 1477   Maruti          Maruti SX4       2008  ...             No
# 1478    Honda          Honda Brio       2014  ...             No
# 1479  Hyundai         Hyundai i20       2018  ...            Yes
# 1480  Hyundai   Hyundai Grand i10       2017  ...             No
#
#      Turning Radius         Tyre Type Value Configuration Values per Cylinder  \
# 0        4.7 metres  Tubeless, Radial                DOHC                 4.0
# 1        5.3 metres   Tubeless,Radial                DOHC                 4.0
# 2        4.9 meters          Tubeless                DOHC                 4.0
# 3        4.7 metres   Tubeless,Radial                DOHC                 4.0
# 4        5.2 meters   Tubeless,Radial                DOHC                 4.0
# ...             ...               ...                 ...                 ...
# 1476     5.9 metres   Tubeless,Radial                DOHC                 4.0
# 1477          5.3 m  Tubeless, Radial                DOHC                 4.0
# 1478     4.5 metres   Tubeless,Radial                SOHC                 4.0
# 1479     5.2 metres          Tubeless                DOHC                 4.0
# 1480     4.8 metres          Tubeless                DOHC                 4.0
#
#       Wheel Base Wheel Size   Width commonIcon         heading
# 0         2425mm        NaN  1635mm             Specifications
# 1         2519mm         16  1765mm             Specifications
# 2         2400mm         14  1647mm             Specifications
# 3         2425mm         14  1660mm             Specifications
# 4         2600mm         16  1785mm             Specifications
# ...          ...        ...     ...        ...             ...
# 1476      2750mm         17  1840mm             Specifications
# 1477      2500mm         16  1735mm             Specifications
# 1478      2345mm        NaN  1680mm             Specifications
# 1479      2570mm         16  1734mm             Specifications
# 1480      2425mm         14  1660mm             Specifications
#
# [1481 rows x 79 columns]

# %%
df5=df["car_links"]

# %%
df_bangalore=pd.concat([df_bangalore,df5],axis=1)

# %%
df_bangalore
# Out:
#       it      ft         bt        km transmission  ownerNo      owner  \
# 0      0  Petrol  Hatchback  1,20,000       Manual        3  3rd Owner
# 1      0  Petrol        SUV    32,706       Manual        2  2nd Owner
# 2      0  Petrol  Hatchback    11,949       Manual        1  1st Owner
# 3      0  Petrol      Sedan    17,794       Manual        1  1st Owner
# 4      0  Diesel        SUV    60,000       Manual        1  1st Owner
# ...   ..     ...        ...       ...          ...      ...        ...
# 1476   0  Diesel        SUV  1,56,039       Manual        2  2nd Owner
# 1477   0  Petrol      Sedan    56,000       Manual        2  2nd Owner
# 1478   0  Petrol  Hatchback    42,000       Manual        2  2nd Owner
# 1479   0  Diesel  Hatchback    93,003       Manual        1  1st Owner
# 1480   0  Petrol  Hatchback    36,000    Automatic        2  2nd Owner
#
#           oem               model  modelYear  ...  Turning Radius  \
# 0      Maruti      Maruti Celerio       2015  ...      4.7 metres
# 1        Ford       Ford Ecosport       2018  ...      5.3 metres
# 2        Tata          Tata Tiago       2018  ...      4.9 meters
# 3     Hyundai       Hyundai Xcent       2014  ...      4.7 metres
# 4      Maruti  Maruti SX4 S Cross       2015  ...      5.2 meters
# ...       ...                 ...        ...  ...             ...
# 1476   Toyota     Toyota Fortuner       2012  ...      5.9 metres
# 1477   Maruti          Maruti SX4       2008  ...           5.3 m
# 1478    Honda          Honda Brio       2014  ...      4.5 metres
# 1479  Hyundai         Hyundai i20       2018  ...      5.2 metres
# 1480  Hyundai   Hyundai Grand i10       2017  ...      4.8 metres
#
#              Tyre Type Value Configuration Values per Cylinder Wheel Base  \
# 0     Tubeless, Radial                DOHC                 4.0     2425mm
# 1      Tubeless,Radial                DOHC                 4.0     2519mm
# 2             Tubeless                DOHC                 4.0     2400mm
# 3      Tubeless,Radial                DOHC                 4.0     2425mm
# 4      Tubeless,Radial                DOHC                 4.0     2600mm
# ...                ...                 ...                 ...        ...
# 1476   Tubeless,Radial                DOHC                 4.0     2750mm
# 1477  Tubeless, Radial                DOHC                 4.0     2500mm
# 1478   Tubeless,Radial                SOHC                 4.0     2345mm
# 1479          Tubeless                DOHC                 4.0     2570mm
# 1480          Tubeless                DOHC                 4.0     2425mm
#
#       Wheel Size   Width commonIcon         heading  \
# 0            NaN  1635mm             Specifications
# 1             16  1765mm             Specifications
# 2             14  1647mm             Specifications
# 3             14  1660mm             Specifications
# 4             16  1785mm             Specifications
# ...          ...     ...        ...             ...
# 1476          17  1840mm             Specifications
# 1477          16  1735mm             Specifications
# 1478         NaN  1680mm             Specifications
# 1479          16  1734mm             Specifications
# 1480          14  1660mm             Specifications
#
#                                               car_links
# 0     https://www.cardekho.com/used-car-details/used...
# 1     https://www.cardekho.com/buy-used-car-details/...
# 2     https://www.cardekho.com/used-car-details/used...
# 3     https://www.cardekho.com/buy-used-car-details/...
# 4     https://www.cardekho.com/used-car-details/used...
# ...                                                 ...
# 1476  https://www.cardekho.com/used-car-details/used...
# 1477  https://www.cardekho.com/used-car-details/used...
# 1478  https://www.cardekho.com/used-car-details/used...
# 1479  https://www.cardekho.com/used-car-details/used...
# 1480  https://www.cardekho.com/used-car-details/used...
#
# [1481 rows x 80 columns]

# %%
df_bangalore["city"]="Bangalore"

# %%
df_bangalore
# Out:
#       it      ft         bt        km transmission  ownerNo      owner  \
# 0      0  Petrol  Hatchback  1,20,000       Manual        3  3rd Owner
# 1      0  Petrol        SUV    32,706       Manual        2  2nd Owner
# 2      0  Petrol  Hatchback    11,949       Manual        1  1st Owner
# 3      0  Petrol      Sedan    17,794       Manual        1  1st Owner
# 4      0  Diesel        SUV    60,000       Manual        1  1st Owner
# ...   ..     ...        ...       ...          ...      ...        ...
# 1476   0  Diesel        SUV  1,56,039       Manual        2  2nd Owner
# 1477   0  Petrol      Sedan    56,000       Manual        2  2nd Owner
# 1478   0  Petrol  Hatchback    42,000       Manual        2  2nd Owner
# 1479   0  Diesel  Hatchback    93,003       Manual        1  1st Owner
# 1480   0  Petrol  Hatchback    36,000    Automatic        2  2nd Owner
#
#           oem               model  modelYear  ...         Tyre Type  \
# 0      Maruti      Maruti Celerio       2015  ...  Tubeless, Radial
# 1        Ford       Ford Ecosport       2018  ...   Tubeless,Radial
# 2        Tata          Tata Tiago       2018  ...          Tubeless
# 3     Hyundai       Hyundai Xcent       2014  ...   Tubeless,Radial
# 4      Maruti  Maruti SX4 S Cross       2015  ...   Tubeless,Radial
# ...       ...                 ...        ...  ...               ...
# 1476   Toyota     Toyota Fortuner       2012  ...   Tubeless,Radial
# 1477   Maruti          Maruti SX4       2008  ...  Tubeless, Radial
# 1478    Honda          Honda Brio       2014  ...   Tubeless,Radial
# 1479  Hyundai         Hyundai i20       2018  ...          Tubeless
# 1480  Hyundai   Hyundai Grand i10       2017  ...          Tubeless
#
#      Value Configuration Values per Cylinder Wheel Base Wheel Size   Width  \
# 0                   DOHC                 4.0     2425mm        NaN  1635mm
# 1                   DOHC                 4.0     2519mm         16  1765mm
# 2                   DOHC                 4.0     2400mm         14  1647mm
# 3                   DOHC                 4.0     2425mm         14  1660mm
# 4                   DOHC                 4.0     2600mm         16  1785mm
# ...                  ...                 ...        ...        ...     ...
# 1476                DOHC                 4.0     2750mm         17  1840mm
# 1477                DOHC                 4.0     2500mm         16  1735mm
# 1478                SOHC                 4.0     2345mm        NaN  1680mm
# 1479                DOHC                 4.0     2570mm         16  1734mm
# 1480                DOHC                 4.0     2425mm         14  1660mm
#
#      commonIcon         heading  \
# 0                Specifications
# 1                Specifications
# 2                Specifications
# 3                Specifications
# 4                Specifications
# ...         ...             ...
# 1476             Specifications
# 1477             Specifications
# 1478             Specifications
# 1479             Specifications
# 1480             Specifications
#
#                                               car_links       city
# 0     https://www.cardekho.com/used-car-details/used...  Bangalore
# 1     https://www.cardekho.com/buy-used-car-details/...  Bangalore
# 2     https://www.cardekho.com/used-car-details/used...  Bangalore
# 3     https://www.cardekho.com/buy-used-car-details/...  Bangalore
# 4     https://www.cardekho.com/used-car-details/used...  Bangalore
# ...                                                 ...        ...
# 1476  https://www.cardekho.com/used-car-details/used...  Bangalore
# 1477  https://www.cardekho.com/used-car-details/used...  Bangalore
# 1478  https://www.cardekho.com/used-car-details/used...  Bangalore
# 1479  https://www.cardekho.com/used-car-details/used...  Bangalore
# 1480  https://www.cardekho.com/used-car-details/used...  Bangalore
#
# [1481 rows x 81 columns]

# %%
path="D:\CHITRA\CARDEHO\\unclean_bangalore.csv"
df_bangalore.to_csv(path, index=False)
