# %%
import pandas as pd
import json

# %%
df=pd.read_excel("C:/Users/ASUS/Downloads/chennai_cars.xlsx")

# %%
df
# Out:
#                                          new_car_detail  \
# 0     {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 1     {'it': 0, 'ft': 'Petrol', 'bt': 'Minivans', 'k...
# 2     {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 3     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 4     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# ...                                                 ...
# 1414  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 1415  {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
# 1416  {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 1417  {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
# 1418  {'it': 0, 'ft': 'Diesel', 'bt': 'Sedan', 'km':...
#
#                                        new_car_overview  \
# 0     {'heading': 'Car overview', 'top': [{'key': 'R...
# 1     {'heading': 'Car overview', 'top': [{'key': 'R...
# 2     {'heading': 'Car overview', 'top': [{'key': 'R...
# 3     {'heading': 'Car overview', 'top': [{'key': 'R...
# 4     {'heading': 'Car overview', 'top': [{'key': 'R...
# ...                                                 ...
# 1414  {'heading': 'Car overview', 'top': [{'key': 'R...
# 1415  {'heading': 'Car overview', 'top': [{'key': 'R...
# 1416  {'heading': 'Car overview', 'top': [{'key': 'R...
# 1417  {'heading': 'Car overview', 'top': [{'key': 'R...
# 1418  {'heading': 'Car overview', 'top': [{'key': 'R...
#
#                                         new_car_feature  \
# 0     {'heading': 'Features', 'top': [{'value': 'Pow...
# 1     {'heading': 'Features', 'top': [{'value': 'Low...
# 2     {'heading': 'Features', 'top': [{'value': 'Pow...
# 3     {'heading': 'Features', 'top': [{'value': 'Pow...
# 4     {'heading': 'Features', 'top': [{'value': 'Pow...
# ...                                                 ...
# 1414  {'heading': 'Features', 'top': [{'value': 'Pow...
# 1415  {'heading': 'Features', 'top': [{'value': 'Pow...
# 1416  {'heading': 'Features', 'top': [{'value': 'Pow...
# 1417  {'heading': 'Features', 'top': [{'value': 'Pow...
# 1418  {'heading': 'Features', 'top': [{'value': 'Pow...
#
#                                           new_car_specs  \
# 0     {'heading': 'Specifications', 'top': [{'key': ...
# 1     {'heading': 'Specifications', 'top': [{'key': ...
# 2     {'heading': 'Specifications', 'top': [{'key': ...
# 3     {'heading': 'Specifications', 'top': [{'key': ...
# 4     {'heading': 'Specifications', 'top': [{'key': ...
# ...                                                 ...
# 1414  {'heading': 'Specifications', 'top': [{'key': ...
# 1415  {'heading': 'Specifications', 'top': [{'key': ...
# 1416  {'heading': 'Specifications', 'top': [{'key': ...
# 1417  {'heading': 'Specifications', 'top': [{'key': ...
# 1418  {'heading': 'Specifications', 'top': [{'key': ...
#
#                                               car_links
# 0     https://www.cardekho.com/used-car-details/used...
# 1     https://www.cardekho.com/buy-used-car-details/...
# 2     https://www.cardekho.com/used-car-details/used...
# 3     https://www.cardekho.com/buy-used-car-details/...
# 4     https://www.cardekho.com/used-car-details/used...
# ...                                                 ...
# 1414  https://www.cardekho.com/used-car-details/used...
# 1415  https://www.cardekho.com/used-car-details/used...
# 1416  https://www.cardekho.com/used-car-details/used...
# 1417  https://www.cardekho.com/used-car-details/used...
# 1418  https://www.cardekho.com/used-car-details/used...
#
# [1419 rows x 5 columns]

# %%
df.new_car_detail=df["new_car_detail"].apply(lambda x:json.loads(x.replace("'",'"').replace("None","1")))
df_new=pd.DataFrame(df.new_car_detail.to_list())

# %%
df_new
# Out:
#       it      ft         bt      km transmission  ownerNo      owner  \
# 0      0  Petrol        SUV  20,000    Automatic        1  1st Owner
# 1      0  Petrol   Minivans  20,687       Manual        1  1st Owner
# 2      0  Petrol        SUV  30,000       Manual        1  1st Owner
# 3      0  Petrol  Hatchback  59,247       Manual        1  1st Owner
# 4      0  Petrol  Hatchback  50,000       Manual        1  1st Owner
# ...   ..     ...        ...     ...          ...      ...        ...
# 1414   0  Petrol  Hatchback  42,891    Automatic        1  1st Owner
# 1415   0  Diesel        SUV  59,100       Manual        1  1st Owner
# 1416   0  Petrol        SUV  55,913    Automatic        1  1st Owner
# 1417   0  Diesel        SUV  65,000    Automatic        1  1st Owner
# 1418   0  Diesel      Sedan  60,000    Automatic        1  1st Owner
#
#              oem              model  modelYear  centralVariantId  \
# 0            Kia          Kia Sonet       2022              8654
# 1         Maruti        Maruti Eeco       2015              4025
# 2         Nissan     Nissan Magnite       2021              8135
# 3        Hyundai        Hyundai i10       2015              1579
# 4          Honda         Honda Jazz       2015              1341
# ...          ...                ...        ...               ...
# 1414      Maruti       Maruti Swift       2018              6190
# 1415     Renault     Renault Duster       2018              5050
# 1416        Tata         Tata Nexon       2018              6364
# 1417  Volkswagen  Volkswagen Tiguan       2017              5849
# 1418         BMW    BMW 3 Series GT       2019              6630
#
#                         variantName         price priceActual priceSaving  \
# 0     Turbo DCT Anniversary Edition  ₹ 11.50 Lakh
# 1            7 Seater Standard BSIV   ₹ 4.15 Lakh
# 2             Turbo XV Premium BSVI   ₹ 7.50 Lakh
# 3                       Sportz 1.1L   ₹ 3.98 Lakh
# 4                     1.2 VX i VTEC   ₹ 5.50 Lakh
# ...                             ...           ...         ...         ...
# 1414                        AMT VXI   ₹ 6.20 Lakh
# 1415                85PS Diesel RxZ   ₹ 8.90 Lakh
# 1416          1.2 Revotron XZA Plus   ₹ 8.01 Lakh
# 1417               2.0 TDI Highline  ₹ 20.50 Lakh
# 1418                          Sport  ₹ 35.75 Lakh
#
#       priceFixedText                                       trendingText
# 0                  1  {'imgUrl': 'https://stimg.cardekho.com/used-ca...
# 1                  1  {'imgUrl': 'https://stimg.cardekho.com/used-ca...
# 2                  1  {'imgUrl': 'https://stimg.cardekho.com/used-ca...
# 3                  1  {'imgUrl': 'https://stimg.cardekho.com/used-ca...
# 4                  1  {'imgUrl': 'https://stimg.cardekho.com/used-ca...
# ...              ...                                                ...
# 1414               1  {'imgUrl': 'https://stimg.cardekho.com/used-ca...
# 1415               1  {'imgUrl': 'https://stimg.cardekho.com/used-ca...
# 1416               1  {'imgUrl': 'https://stimg.cardekho.com/used-ca...
# 1417               1  {'imgUrl': 'https://stimg.cardekho.com/used-ca...
# 1418               1  {'imgUrl': 'https://stimg.cardekho.com/used-ca...
#
# [1419 rows x 17 columns]

# %%
# Function to safely load JSON if it's a string
def safe_load(x):
    if isinstance(x, str):
        return json.loads(x.replace("'", '"').replace("None", "1"))
    return x  # If it's already a dict, return as is

# Apply the safe_load function
df["new_car_detail"] = df["new_car_detail"].apply(safe_load)

# Expand the main dictionary into columns
df_expanded = pd.DataFrame(df["new_car_detail"].to_list())

# Expand the nested dictionary into columns
df_nested_expanded = df_expanded["trendingText"].apply(pd.Series)

# Combine the original and nested DataFrame
df11 = pd.concat([df_expanded.drop(columns=["trendingText"]), df_nested_expanded], axis=1)

# %%
df11
# Out:
#       it      ft         bt      km transmission  ownerNo      owner  \
# 0      0  Petrol        SUV  20,000    Automatic        1  1st Owner
# 1      0  Petrol   Minivans  20,687       Manual        1  1st Owner
# 2      0  Petrol        SUV  30,000       Manual        1  1st Owner
# 3      0  Petrol  Hatchback  59,247       Manual        1  1st Owner
# 4      0  Petrol  Hatchback  50,000       Manual        1  1st Owner
# ...   ..     ...        ...     ...          ...      ...        ...
# 1414   0  Petrol  Hatchback  42,891    Automatic        1  1st Owner
# 1415   0  Diesel        SUV  59,100       Manual        1  1st Owner
# 1416   0  Petrol        SUV  55,913    Automatic        1  1st Owner
# 1417   0  Diesel        SUV  65,000    Automatic        1  1st Owner
# 1418   0  Diesel      Sedan  60,000    Automatic        1  1st Owner
#
#              oem              model  modelYear  centralVariantId  \
# 0            Kia          Kia Sonet       2022              8654
# 1         Maruti        Maruti Eeco       2015              4025
# 2         Nissan     Nissan Magnite       2021              8135
# 3        Hyundai        Hyundai i10       2015              1579
# 4          Honda         Honda Jazz       2015              1341
# ...          ...                ...        ...               ...
# 1414      Maruti       Maruti Swift       2018              6190
# 1415     Renault     Renault Duster       2018              5050
# 1416        Tata         Tata Nexon       2018              6364
# 1417  Volkswagen  Volkswagen Tiguan       2017              5849
# 1418         BMW    BMW 3 Series GT       2019              6630
#
#                         variantName         price priceActual priceSaving  \
# 0     Turbo DCT Anniversary Edition  ₹ 11.50 Lakh
# 1            7 Seater Standard BSIV   ₹ 4.15 Lakh
# 2             Turbo XV Premium BSVI   ₹ 7.50 Lakh
# 3                       Sportz 1.1L   ₹ 3.98 Lakh
# 4                     1.2 VX i VTEC   ₹ 5.50 Lakh
# ...                             ...           ...         ...         ...
# 1414                        AMT VXI   ₹ 6.20 Lakh
# 1415                85PS Diesel RxZ   ₹ 8.90 Lakh
# 1416          1.2 Revotron XZA Plus   ₹ 8.01 Lakh
# 1417               2.0 TDI Highline  ₹ 20.50 Lakh
# 1418                          Sport  ₹ 35.75 Lakh
#
#       priceFixedText                                             imgUrl  \
# 0                  1  https://stimg.cardekho.com/used-cars/common/ic...
# 1                  1  https://stimg.cardekho.com/used-cars/common/ic...
# 2                  1  https://stimg.cardekho.com/used-cars/common/ic...
# 3                  1  https://stimg.cardekho.com/used-cars/common/ic...
# 4                  1  https://stimg.cardekho.com/used-cars/common/ic...
# ...              ...                                                ...
# 1414               1  https://stimg.cardekho.com/used-cars/common/ic...
# 1415               1  https://stimg.cardekho.com/used-cars/common/ic...
# 1416               1  https://stimg.cardekho.com/used-cars/common/ic...
# 1417               1  https://stimg.cardekho.com/used-cars/common/ic...
# 1418               1  https://stimg.cardekho.com/used-cars/common/ic...
#
#             heading                                 desc
# 0     Trending Car!  High chances of sale in next 6 days
# 1     Trending Car!  High chances of sale in next 6 days
# 2     Trending Car!  High chances of sale in next 6 days
# 3     Trending Car!  High chances of sale in next 6 days
# 4     Trending Car!  High chances of sale in next 6 days
# ...             ...                                  ...
# 1414  Trending Car!  High chances of sale in next 6 days
# 1415  Trending Car!  High chances of sale in next 6 days
# 1416  Trending Car!  High chances of sale in next 6 days
# 1417  Trending Car!  High chances of sale in next 6 days
# 1418  Trending Car!  High chances of sale in next 6 days
#
# [1419 rows x 19 columns]

# %%
#next overview

# %%
df["new_car_overview"]
# Out:
# 0       {'heading': 'Car overview', 'top': [{'key': 'R...
# 1       {'heading': 'Car overview', 'top': [{'key': 'R...
# 2       {'heading': 'Car overview', 'top': [{'key': 'R...
# 3       {'heading': 'Car overview', 'top': [{'key': 'R...
# 4       {'heading': 'Car overview', 'top': [{'key': 'R...
#                               ...
# 1414    {'heading': 'Car overview', 'top': [{'key': 'R...
# 1415    {'heading': 'Car overview', 'top': [{'key': 'R...
# 1416    {'heading': 'Car overview', 'top': [{'key': 'R...
# 1417    {'heading': 'Car overview', 'top': [{'key': 'R...
# 1418    {'heading': 'Car overview', 'top': [{'key': 'R...
# Name: new_car_overview, Length: 1419, dtype: object

# %%
def extract_key_value_pairs(dict_list):
    if isinstance(dict_list, list):
        extracted_data = {}
        for item in dict_list:
            if isinstance(item, dict):
                key = item.get('key')
                value = item.get('value')
                if key:  # Only add if the key exists
                    extracted_data[key] = value
        return pd.Series(extracted_data)
    return pd.Series()  # Return an empty Series if dict_list is not a list

# Apply the extraction function to the 'top' column
df2 = df['new_car_overview'].apply(lambda x: x['top'] if isinstance(x, dict) else None).apply(extract_key_value_pairs)

# %%
df2
# Out:
#      Registration Year     Insurance Validity Fuel Type    Seats  Kms Driven  \
# 0                 2022  Third Party insurance    Petrol  5 Seats  20,000 Kms
# 1             Feb 2015          Comprehensive    Petrol  7 Seats  20,687 Kms
# 2                 2021  Third Party insurance    Petrol  5 Seats  30,000 Kms
# 3             May 2015          Comprehensive    Petrol  5 Seats  59,247 Kms
# 4                 2015  Third Party insurance    Petrol  5 Seats  50,000 Kms
# ...                ...                    ...       ...      ...         ...
# 1414          Jun 2018  Third Party insurance    Petrol  5 Seats  42,891 Kms
# 1415          Feb 2019  Third Party insurance    Diesel  5 Seats  59,100 Kms
# 1416          Aug 2018          Not Available    Petrol  5 Seats  55,913 Kms
# 1417          Aug 2017          Comprehensive    Diesel  5 Seats  65,000 Kms
# 1418          Oct 2019          Comprehensive    Diesel  5 Seats  60,000 Kms
#
#        RTO    Ownership Engine Displacement Transmission  Year of Manufacture
# 0     TN02  First Owner              998 cc    Automatic                 2022
# 1     TN04  First Owner             1196 cc       Manual                 2015
# 2     TN22  First Owner              999 cc       Manual                 2021
# 3     TN11  First Owner             1086 cc       Manual                 2015
# 4     KA03  First Owner             1199 cc       Manual                 2015
# ...    ...          ...                 ...          ...                  ...
# 1414  TN09  First Owner             1197 cc    Automatic                 2018
# 1415  TN11  First Owner             1461 cc       Manual                 2018
# 1416  TN11  First Owner             1198 cc    Automatic                 2018
# 1417  TN22  First Owner             1968 cc    Automatic                 2017
# 1418  TN87  First Owner             1995 cc    Automatic                 2019
#
# [1419 rows x 10 columns]

# %%
# Concatenate horizontally
dfc= pd.concat([df11, df2], axis=1)

# %%
dfc
# Out:
#       it      ft         bt      km transmission  ownerNo      owner  \
# 0      0  Petrol        SUV  20,000    Automatic        1  1st Owner
# 1      0  Petrol   Minivans  20,687       Manual        1  1st Owner
# 2      0  Petrol        SUV  30,000       Manual        1  1st Owner
# 3      0  Petrol  Hatchback  59,247       Manual        1  1st Owner
# 4      0  Petrol  Hatchback  50,000       Manual        1  1st Owner
# ...   ..     ...        ...     ...          ...      ...        ...
# 1414   0  Petrol  Hatchback  42,891    Automatic        1  1st Owner
# 1415   0  Diesel        SUV  59,100       Manual        1  1st Owner
# 1416   0  Petrol        SUV  55,913    Automatic        1  1st Owner
# 1417   0  Diesel        SUV  65,000    Automatic        1  1st Owner
# 1418   0  Diesel      Sedan  60,000    Automatic        1  1st Owner
#
#              oem              model  modelYear  ...  Registration Year  \
# 0            Kia          Kia Sonet       2022  ...               2022
# 1         Maruti        Maruti Eeco       2015  ...           Feb 2015
# 2         Nissan     Nissan Magnite       2021  ...               2021
# 3        Hyundai        Hyundai i10       2015  ...           May 2015
# 4          Honda         Honda Jazz       2015  ...               2015
# ...          ...                ...        ...  ...                ...
# 1414      Maruti       Maruti Swift       2018  ...           Jun 2018
# 1415     Renault     Renault Duster       2018  ...           Feb 2019
# 1416        Tata         Tata Nexon       2018  ...           Aug 2018
# 1417  Volkswagen  Volkswagen Tiguan       2017  ...           Aug 2017
# 1418         BMW    BMW 3 Series GT       2019  ...           Oct 2019
#
#          Insurance Validity Fuel Type    Seats  Kms Driven   RTO    Ownership  \
# 0     Third Party insurance    Petrol  5 Seats  20,000 Kms  TN02  First Owner
# 1             Comprehensive    Petrol  7 Seats  20,687 Kms  TN04  First Owner
# 2     Third Party insurance    Petrol  5 Seats  30,000 Kms  TN22  First Owner
# 3             Comprehensive    Petrol  5 Seats  59,247 Kms  TN11  First Owner
# 4     Third Party insurance    Petrol  5 Seats  50,000 Kms  KA03  First Owner
# ...                     ...       ...      ...         ...   ...          ...
# 1414  Third Party insurance    Petrol  5 Seats  42,891 Kms  TN09  First Owner
# 1415  Third Party insurance    Diesel  5 Seats  59,100 Kms  TN11  First Owner
# 1416          Not Available    Petrol  5 Seats  55,913 Kms  TN11  First Owner
# 1417          Comprehensive    Diesel  5 Seats  65,000 Kms  TN22  First Owner
# 1418          Comprehensive    Diesel  5 Seats  60,000 Kms  TN87  First Owner
#
#      Engine Displacement Transmission Year of Manufacture
# 0                 998 cc    Automatic                2022
# 1                1196 cc       Manual                2015
# 2                 999 cc       Manual                2021
# 3                1086 cc       Manual                2015
# 4                1199 cc       Manual                2015
# ...                  ...          ...                 ...
# 1414             1197 cc    Automatic                2018
# 1415             1461 cc       Manual                2018
# 1416             1198 cc    Automatic                2018
# 1417             1968 cc    Automatic                2017
# 1418             1995 cc    Automatic                2019
#
# [1419 rows x 29 columns]

# %%
#car features

# %%
df.head()
# Out:
#                                       new_car_detail  \
# 0  {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 1  {'it': 0, 'ft': 'Petrol', 'bt': 'Minivans', 'k...
# 2  {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 3  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 4  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
#
#                                     new_car_overview  \
# 0  {'heading': 'Car overview', 'top': [{'key': 'R...
# 1  {'heading': 'Car overview', 'top': [{'key': 'R...
# 2  {'heading': 'Car overview', 'top': [{'key': 'R...
# 3  {'heading': 'Car overview', 'top': [{'key': 'R...
# 4  {'heading': 'Car overview', 'top': [{'key': 'R...
#
#                                      new_car_feature  \
# 0  {'heading': 'Features', 'top': [{'value': 'Pow...
# 1  {'heading': 'Features', 'top': [{'value': 'Low...
# 2  {'heading': 'Features', 'top': [{'value': 'Pow...
# 3  {'heading': 'Features', 'top': [{'value': 'Pow...
# 4  {'heading': 'Features', 'top': [{'value': 'Pow...
#
#                                        new_car_specs  \
# 0  {'heading': 'Specifications', 'top': [{'key': ...
# 1  {'heading': 'Specifications', 'top': [{'key': ...
# 2  {'heading': 'Specifications', 'top': [{'key': ...
# 3  {'heading': 'Specifications', 'top': [{'key': ...
# 4  {'heading': 'Specifications', 'top': [{'key': ...
#
#                                            car_links
# 0  https://www.cardekho.com/used-car-details/used...
# 1  https://www.cardekho.com/buy-used-car-details/...
# 2  https://www.cardekho.com/used-car-details/used...
# 3  https://www.cardekho.com/buy-used-car-details/...
# 4  https://www.cardekho.com/used-car-details/used...

# %%
df.new_car_feature=df["new_car_feature"].apply(lambda x:json.loads(x.replace("'",'"').replace("None","1")))
df_new=pd.DataFrame(df.new_car_feature.to_list())

# %%
df_new
# Out:
#        heading                                                top  \
# 0     Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 1     Features  [{'value': 'Low Fuel Warning Light'}, {'value'...
# 2     Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 3     Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 4     Features  [{'value': 'Power Steering'}, {'value': 'Power...
# ...        ...                                                ...
# 1414  Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 1415  Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 1416  Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 1417  Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 1418  Features  [{'value': 'Power Steering'}, {'value': 'Power...
#
#                                                    data  \
# 0     [{'heading': 'Comfort & Convenience', 'subHead...
# 1     [{'heading': 'Comfort & Convenience', 'subHead...
# 2     [{'heading': 'Comfort & Convenience', 'subHead...
# 3     [{'heading': 'Comfort & Convenience', 'subHead...
# 4     [{'heading': 'Comfort & Convenience', 'subHead...
# ...                                                 ...
# 1414  [{'heading': 'Comfort & Convenience', 'subHead...
# 1415  [{'heading': 'Comfort & Convenience', 'subHead...
# 1416  [{'heading': 'Comfort & Convenience', 'subHead...
# 1417  [{'heading': 'Comfort & Convenience', 'subHead...
# 1418  [{'heading': 'Comfort & Convenience', 'subHead...
#
#                                              commonIcon
# 0     https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1     https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 2     https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 3     https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 4     https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# ...                                                 ...
# 1414  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1415  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1416  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1417  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1418  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
#
# [1419 rows x 4 columns]

# %%
import pandas as pd
import numpy as np


# Ensure 'top' column contains lists; replace non-lists with empty lists
df_new['top'] = df_new['top'].apply(lambda x: x if isinstance(x, list) else [])

# Extract feature values and concatenate them into a single string per row
df_new['Features'] = df_new['top'].apply(lambda x: ', '.join([item['value'] for item in x]))

# Drop the original 'top' column if no longer needed
df_new = df_new.drop(columns=['top'])

df_new
# Out:
#        heading                                               data  \
# 0     Features  [{'heading': 'Comfort & Convenience', 'subHead...
# 1     Features  [{'heading': 'Comfort & Convenience', 'subHead...
# 2     Features  [{'heading': 'Comfort & Convenience', 'subHead...
# 3     Features  [{'heading': 'Comfort & Convenience', 'subHead...
# 4     Features  [{'heading': 'Comfort & Convenience', 'subHead...
# ...        ...                                                ...
# 1414  Features  [{'heading': 'Comfort & Convenience', 'subHead...
# 1415  Features  [{'heading': 'Comfort & Convenience', 'subHead...
# 1416  Features  [{'heading': 'Comfort & Convenience', 'subHead...
# 1417  Features  [{'heading': 'Comfort & Convenience', 'subHead...
# 1418  Features  [{'heading': 'Comfort & Convenience', 'subHead...
#
#                                              commonIcon  \
# 0     https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1     https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 2     https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 3     https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 4     https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# ...                                                 ...
# 1414  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1415  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1416  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1417  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1418  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
#
#                                                Features
# 0     Power Steering, Power Windows Front, Air Condi...
# 1     Low Fuel Warning Light, Accessory Power Outlet...
# 2     Power Steering, Power Windows Front, Air Condi...
# 3     Power Steering, Power Windows Front, Air Condi...
# 4     Power Steering, Power Windows Front, Air Condi...
# ...                                                 ...
# 1414  Power Steering, Power Windows Front, Air Condi...
# 1415  Power Steering, Power Windows Front, Air Condi...
# 1416  Power Steering, Power Windows Front, Air Condi...
# 1417  Power Steering, Power Windows Front, Air Condi...
# 1418  Power Steering, Power Windows Front, Air Condi...
#
# [1419 rows x 4 columns]

# %%
# Function to extract features and create columns
def extract_features(data):
    features_dict = {}
    for category in data:
        sub_heading = category['subHeading']
        features = [item['value'] for item in category['list']]
        features_dict[sub_heading] = ', '.join(features)
    return features_dict

# Apply the function to the 'data' column and convert to DataFrame
features_df = pd.json_normalize(df_new['data'].apply(extract_features))

# Concatenate with the original DataFrame if needed
df3 = pd.concat([df_new.drop(columns=['data']), features_df], axis=1)

# %%
df3
# Out:
#        heading                                         commonIcon  \
# 0     Features  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1     Features  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 2     Features  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 3     Features  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 4     Features  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# ...        ...                                                ...
# 1414  Features  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1415  Features  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1416  Features  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1417  Features  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1418  Features  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
#
#                                                Features  \
# 0     Power Steering, Power Windows Front, Air Condi...
# 1     Low Fuel Warning Light, Accessory Power Outlet...
# 2     Power Steering, Power Windows Front, Air Condi...
# 3     Power Steering, Power Windows Front, Air Condi...
# 4     Power Steering, Power Windows Front, Air Condi...
# ...                                                 ...
# 1414  Power Steering, Power Windows Front, Air Condi...
# 1415  Power Steering, Power Windows Front, Air Condi...
# 1416  Power Steering, Power Windows Front, Air Condi...
# 1417  Power Steering, Power Windows Front, Air Condi...
# 1418  Power Steering, Power Windows Front, Air Condi...
#
#                                                 Comfort  \
# 0     Power Steering, Power Windows Front, Power Win...
# 1     Low Fuel Warning Light, Accessory Power Outlet...
# 2     Power Steering, Power Windows Front, Power Win...
# 3     Power Steering, Power Windows Front, Power Win...
# 4     Power Steering, Power Windows Front, Power Win...
# ...                                                 ...
# 1414  Power Steering, Power Windows Front, Power Win...
# 1415  Power Steering, Power Windows Front, Power Win...
# 1416  Power Steering, Power Windows Front, Power Win...
# 1417  Power Steering, Power Windows Front, Power Win...
# 1418  Power Steering, Power Windows Front, Power Win...
#
#                                                Interior  \
# 0     Air Conditioner, Heater, Adjustable Steering, ...
# 1     Heater, Digital Odometer, Electronic Multi Tri...
# 2     Air Conditioner, Heater, Adjustable Steering, ...
# 3     Air Conditioner, Heater, Adjustable Steering, ...
# 4     Air Conditioner, Heater, Adjustable Steering, ...
# ...                                                 ...
# 1414  Air Conditioner, Heater, Adjustable Steering, ...
# 1415  Air Conditioner, Heater, Adjustable Steering, ...
# 1416  Air Conditioner, Heater, Adjustable Steering, ...
# 1417  Air Conditioner, Heater, Adjustable Steering, ...
# 1418  Air Conditioner, Heater, Adjustable Steering, ...
#
#                                                Exterior  \
# 0     Adjustable Head Lights, Fog Lights Front, Powe...
# 1     Adjustable Head Lights, Manually Adjustable Ex...
# 2     Adjustable Head Lights, Fog Lights Front, Powe...
# 3     Adjustable Head Lights, Fog Lights Front, Manu...
# 4     Adjustable Head Lights, Fog Lights Front, Powe...
# ...                                                 ...
# 1414  Adjustable Head Lights, Power Adjustable Exter...
# 1415  Adjustable Head Lights, Fog Lights Front, Powe...
# 1416  Adjustable Head Lights, Fog Lights Front, Powe...
# 1417  Adjustable Head Lights, Fog Lights Front, Fog ...
# 1418  Adjustable Head Lights, Fog Lights Front, Powe...
#
#                                                  Safety  \
# 0     Anti Lock Braking System, Brake Assist, Center...
# 1     Anti Lock Braking System, Child Safety Locks, ...
# 2     Anti Lock Braking System, Brake Assist, Center...
# 3     Centeral Locking, Power Door Locks, Child Safe...
# 4     Anti Lock Braking System, Centeral Locking, Po...
# ...                                                 ...
# 1414  Anti Lock Braking System, Brake Assist, Center...
# 1415  Anti Lock Braking System, Brake Assist, Center...
# 1416  Anti Lock Braking System, Centeral Locking, Po...
# 1417  Anti Lock Braking System, Brake Assist, Center...
# 1418  Anti Lock Braking System, Brake Assist, Center...
#
#                                           Entertainment
# 0     Radio, Speakers Front, Speakers Rear, Integrat...
# 1                                                   NaN
# 2     Radio, Speakers Front, Speakers Rear, Integrat...
# 3     Cd Player, Radio, Speakers Front, Speakers Rea...
# 4     Cd Player, Dvd Player, Radio, Speakers Front, ...
# ...                                                 ...
# 1414  Cd Player, Radio, Speakers Front, Speakers Rea...
# 1415  Cd Player, Radio, Speakers Front, Speakers Rea...
# 1416  Radio, Speakers Front, Speakers Rear, Integrat...
# 1417  Cd Player, Radio, Speakers Front, Speakers Rea...
# 1418  Cd Player, Cd Changer, Dvd Player, Radio, Audi...
#
# [1419 rows x 8 columns]

# %%
# Concatenate horizontally
dfc=pd.concat([dfc, df3], axis=1)

# %%
dfc
# Out:
#       it      ft         bt      km transmission  ownerNo      owner  \
# 0      0  Petrol        SUV  20,000    Automatic        1  1st Owner
# 1      0  Petrol   Minivans  20,687       Manual        1  1st Owner
# 2      0  Petrol        SUV  30,000       Manual        1  1st Owner
# 3      0  Petrol  Hatchback  59,247       Manual        1  1st Owner
# 4      0  Petrol  Hatchback  50,000       Manual        1  1st Owner
# ...   ..     ...        ...     ...          ...      ...        ...
# 1414   0  Petrol  Hatchback  42,891    Automatic        1  1st Owner
# 1415   0  Diesel        SUV  59,100       Manual        1  1st Owner
# 1416   0  Petrol        SUV  55,913    Automatic        1  1st Owner
# 1417   0  Diesel        SUV  65,000    Automatic        1  1st Owner
# 1418   0  Diesel      Sedan  60,000    Automatic        1  1st Owner
#
#              oem              model  modelYear  ...  Transmission  \
# 0            Kia          Kia Sonet       2022  ...     Automatic
# 1         Maruti        Maruti Eeco       2015  ...        Manual
# 2         Nissan     Nissan Magnite       2021  ...        Manual
# 3        Hyundai        Hyundai i10       2015  ...        Manual
# 4          Honda         Honda Jazz       2015  ...        Manual
# ...          ...                ...        ...  ...           ...
# 1414      Maruti       Maruti Swift       2018  ...     Automatic
# 1415     Renault     Renault Duster       2018  ...        Manual
# 1416        Tata         Tata Nexon       2018  ...     Automatic
# 1417  Volkswagen  Volkswagen Tiguan       2017  ...     Automatic
# 1418         BMW    BMW 3 Series GT       2019  ...     Automatic
#
#      Year of Manufacture   heading  \
# 0                   2022  Features
# 1                   2015  Features
# 2                   2021  Features
# 3                   2015  Features
# 4                   2015  Features
# ...                  ...       ...
# 1414                2018  Features
# 1415                2018  Features
# 1416                2018  Features
# 1417                2017  Features
# 1418                2019  Features
#
#                                              commonIcon  \
# 0     https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1     https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 2     https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 3     https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 4     https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# ...                                                 ...
# 1414  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1415  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1416  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1417  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1418  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
#
#                                                Features  \
# 0     Power Steering, Power Windows Front, Air Condi...
# 1     Low Fuel Warning Light, Accessory Power Outlet...
# 2     Power Steering, Power Windows Front, Air Condi...
# 3     Power Steering, Power Windows Front, Air Condi...
# 4     Power Steering, Power Windows Front, Air Condi...
# ...                                                 ...
# 1414  Power Steering, Power Windows Front, Air Condi...
# 1415  Power Steering, Power Windows Front, Air Condi...
# 1416  Power Steering, Power Windows Front, Air Condi...
# 1417  Power Steering, Power Windows Front, Air Condi...
# 1418  Power Steering, Power Windows Front, Air Condi...
#
#                                                 Comfort  \
# 0     Power Steering, Power Windows Front, Power Win...
# 1     Low Fuel Warning Light, Accessory Power Outlet...
# 2     Power Steering, Power Windows Front, Power Win...
# 3     Power Steering, Power Windows Front, Power Win...
# 4     Power Steering, Power Windows Front, Power Win...
# ...                                                 ...
# 1414  Power Steering, Power Windows Front, Power Win...
# 1415  Power Steering, Power Windows Front, Power Win...
# 1416  Power Steering, Power Windows Front, Power Win...
# 1417  Power Steering, Power Windows Front, Power Win...
# 1418  Power Steering, Power Windows Front, Power Win...
#
#                                                Interior  \
# 0     Air Conditioner, Heater, Adjustable Steering, ...
# 1     Heater, Digital Odometer, Electronic Multi Tri...
# 2     Air Conditioner, Heater, Adjustable Steering, ...
# 3     Air Conditioner, Heater, Adjustable Steering, ...
# 4     Air Conditioner, Heater, Adjustable Steering, ...
# ...                                                 ...
# 1414  Air Conditioner, Heater, Adjustable Steering, ...
# 1415  Air Conditioner, Heater, Adjustable Steering, ...
# 1416  Air Conditioner, Heater, Adjustable Steering, ...
# 1417  Air Conditioner, Heater, Adjustable Steering, ...
# 1418  Air Conditioner, Heater, Adjustable Steering, ...
#
#                                                Exterior  \
# 0     Adjustable Head Lights, Fog Lights Front, Powe...
# 1     Adjustable Head Lights, Manually Adjustable Ex...
# 2     Adjustable Head Lights, Fog Lights Front, Powe...
# 3     Adjustable Head Lights, Fog Lights Front, Manu...
# 4     Adjustable Head Lights, Fog Lights Front, Powe...
# ...                                                 ...
# 1414  Adjustable Head Lights, Power Adjustable Exter...
# 1415  Adjustable Head Lights, Fog Lights Front, Powe...
# 1416  Adjustable Head Lights, Fog Lights Front, Powe...
# 1417  Adjustable Head Lights, Fog Lights Front, Fog ...
# 1418  Adjustable Head Lights, Fog Lights Front, Powe...
#
#                                                  Safety  \
# 0     Anti Lock Braking System, Brake Assist, Center...
# 1     Anti Lock Braking System, Child Safety Locks, ...
# 2     Anti Lock Braking System, Brake Assist, Center...
# 3     Centeral Locking, Power Door Locks, Child Safe...
# 4     Anti Lock Braking System, Centeral Locking, Po...
# ...                                                 ...
# 1414  Anti Lock Braking System, Brake Assist, Center...
# 1415  Anti Lock Braking System, Brake Assist, Center...
# 1416  Anti Lock Braking System, Centeral Locking, Po...
# 1417  Anti Lock Braking System, Brake Assist, Center...
# 1418  Anti Lock Braking System, Brake Assist, Center...
#
#                                           Entertainment
# 0     Radio, Speakers Front, Speakers Rear, Integrat...
# 1                                                   NaN
# 2     Radio, Speakers Front, Speakers Rear, Integrat...
# 3     Cd Player, Radio, Speakers Front, Speakers Rea...
# 4     Cd Player, Dvd Player, Radio, Speakers Front, ...
# ...                                                 ...
# 1414  Cd Player, Radio, Speakers Front, Speakers Rea...
# 1415  Cd Player, Radio, Speakers Front, Speakers Rea...
# 1416  Radio, Speakers Front, Speakers Rear, Integrat...
# 1417  Cd Player, Radio, Speakers Front, Speakers Rea...
# 1418  Cd Player, Cd Changer, Dvd Player, Radio, Audi...
#
# [1419 rows x 37 columns]

# %%
#car specification

# %%
df.head()
# Out:
#                                       new_car_detail  \
# 0  {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 1  {'it': 0, 'ft': 'Petrol', 'bt': 'Minivans', 'k...
# 2  {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 3  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 4  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
#
#                                     new_car_overview  \
# 0  {'heading': 'Car overview', 'top': [{'key': 'R...
# 1  {'heading': 'Car overview', 'top': [{'key': 'R...
# 2  {'heading': 'Car overview', 'top': [{'key': 'R...
# 3  {'heading': 'Car overview', 'top': [{'key': 'R...
# 4  {'heading': 'Car overview', 'top': [{'key': 'R...
#
#                                      new_car_feature  \
# 0  {'heading': 'Features', 'top': [{'value': 'Pow...
# 1  {'heading': 'Features', 'top': [{'value': 'Low...
# 2  {'heading': 'Features', 'top': [{'value': 'Pow...
# 3  {'heading': 'Features', 'top': [{'value': 'Pow...
# 4  {'heading': 'Features', 'top': [{'value': 'Pow...
#
#                                        new_car_specs  \
# 0  {'heading': 'Specifications', 'top': [{'key': ...
# 1  {'heading': 'Specifications', 'top': [{'key': ...
# 2  {'heading': 'Specifications', 'top': [{'key': ...
# 3  {'heading': 'Specifications', 'top': [{'key': ...
# 4  {'heading': 'Specifications', 'top': [{'key': ...
#
#                                            car_links
# 0  https://www.cardekho.com/used-car-details/used...
# 1  https://www.cardekho.com/buy-used-car-details/...
# 2  https://www.cardekho.com/used-car-details/used...
# 3  https://www.cardekho.com/buy-used-car-details/...
# 4  https://www.cardekho.com/used-car-details/used...

# %%
import pandas as pd
import json

# Function to safely convert JSON strings to dictionaries
def safe_json_loads(x):
    if isinstance(x, str):  # Check if the data is a string
        try:
            # Replace single quotes with double quotes and handle 'None'
            return json.loads(x.replace("'", '"').replace("None", "1"))
        except json.JSONDecodeError:
            # Handle JSON parsing errors
            print(f"Error decoding JSON for: {x}")
            return None
    elif isinstance(x, dict):
        # If already a dictionary, return it as is
        return x
    else:
        # Handle unexpected data types
        print(f"Unexpected data type: {type(x)}")
        return None

# Apply the function to safely transform the data
df['new_car_specs'] = df['new_car_specs'].apply(safe_json_loads)

# Convert the list of dictionaries to a DataFrame
df_new = pd.DataFrame(df['new_car_specs'].tolist())

# %%
df_new
# Out:
#              heading                                                top  \
# 0     Specifications  [{'key': 'Engine', 'value': '998 CC'}, {'key':...
# 1     Specifications  [{'key': 'Mileage', 'value': '15.37 kmpl'}, {'...
# 2     Specifications  [{'key': 'Mileage', 'value': '20 kmpl'}, {'key...
# 3     Specifications  [{'key': 'Mileage', 'value': '19.81 kmpl'}, {'...
# 4     Specifications  [{'key': 'Mileage', 'value': '18.7 kmpl'}, {'k...
# ...              ...                                                ...
# 1414  Specifications  [{'key': 'Mileage', 'value': '22 kmpl'}, {'key...
# 1415  Specifications  [{'key': 'Mileage', 'value': '19.87 kmpl'}, {'...
# 1416  Specifications  [{'key': 'Mileage', 'value': '17 kmpl'}, {'key...
# 1417  Specifications  [{'key': 'Mileage', 'value': '16.65 kmpl'}, {'...
# 1418  Specifications  [{'key': 'Mileage', 'value': '21.76 kmpl'}, {'...
#
#                                                    data commonIcon
# 0     [{'heading': 'Engine and Transmission', 'subHe...
# 1     [{'heading': 'Engine and Transmission', 'subHe...
# 2     [{'heading': 'Engine and Transmission', 'subHe...
# 3     [{'heading': 'Engine and Transmission', 'subHe...
# 4     [{'heading': 'Engine and Transmission', 'subHe...
# ...                                                 ...        ...
# 1414  [{'heading': 'Engine and Transmission', 'subHe...
# 1415  [{'heading': 'Engine and Transmission', 'subHe...
# 1416  [{'heading': 'Engine and Transmission', 'subHe...
# 1417  [{'heading': 'Engine and Transmission', 'subHe...
# 1418  [{'heading': 'Engine and Transmission', 'subHe...
#
# [1419 rows x 4 columns]

# %%
# Function to extract 'top' key-value pairs and add them as columns
def extract_top(row):
    if isinstance(row['top'], list):
        for item in row['top']:
            row[item['key']] = item['value']
    return row

# Apply the function to the DataFrame
df_new = df_new.apply(extract_top, axis=1)

# Drop the 'top' column after extraction
df_new.drop(columns=['top'], inplace=True)

# %%
df_new
# Out:
#        Engine  Max Power     Mileage Seats   Torque Wheel Size commonIcon  \
# 0      998 CC  118.36bhp         NaN     5    172nm         16
# 1     1196 CC      73bhp  15.37 kmpl     7    101Nm        NaN
# 2      999 CC   98.63bhp     20 kmpl     5    160Nm         16
# 3     1086 CC   68.05bhp  19.81 kmpl     5  99.04Nm        NaN
# 4     1199 CC    88.7bhp   18.7 kmpl     5    110Nm         15
# ...       ...        ...         ...   ...      ...        ...        ...
# 1414  1197 CC   81.80bhp     22 kmpl     5    113Nm        NaN
# 1415  1461 CC    83.8bhp  19.87 kmpl     5    200Nm         16
# 1416  1198 CC   108.5bhp     17 kmpl     5    170Nm         16
# 1417  1968 CC     141bhp  16.65 kmpl     5    340Nm         18
# 1418  1995 CC     188bhp  21.76 kmpl     5    400Nm         18
#
#                                                    data         heading
# 0     [{'heading': 'Engine and Transmission', 'subHe...  Specifications
# 1     [{'heading': 'Engine and Transmission', 'subHe...  Specifications
# 2     [{'heading': 'Engine and Transmission', 'subHe...  Specifications
# 3     [{'heading': 'Engine and Transmission', 'subHe...  Specifications
# 4     [{'heading': 'Engine and Transmission', 'subHe...  Specifications
# ...                                                 ...             ...
# 1414  [{'heading': 'Engine and Transmission', 'subHe...  Specifications
# 1415  [{'heading': 'Engine and Transmission', 'subHe...  Specifications
# 1416  [{'heading': 'Engine and Transmission', 'subHe...  Specifications
# 1417  [{'heading': 'Engine and Transmission', 'subHe...  Specifications
# 1418  [{'heading': 'Engine and Transmission', 'subHe...  Specifications
#
# [1419 rows x 9 columns]

# %%
# Function to extract 'data' key-value pairs and add them as columns
def extract_data(row):
    if isinstance(row['data'], list):
        for section in row['data']:
            for item in section['list']:
                row[item['key']] = item['value']
    return row

# Apply the function to the DataFrame
df_new = df_new.apply(extract_data, axis=1)

# Drop the 'data' column after extraction
df_new.drop(columns=['data'], inplace=True)

# %%
df4=df_new

# %%
df4
# Out:
#       Acceleration Alloy Wheel Size  BoreX Stroke Cargo Volumn   Color  \
# 0              NaN               16           NaN          392   Black
# 1     15.7 Seconds              NaN           NaN   540-liters    Grey
# 2             11.7               16   72.2 x 81.3          336  Others
# 3     14.3 Seconds              NaN           NaN   225-litres  Silver
# 4     13.7 Seconds               15           NaN   354-litres  Others
# ...            ...              ...           ...          ...     ...
# 1414           NaN              NaN           NaN   268-litres    Blue
# 1415  13.9 Seconds               16           NaN   475-litres  Orange
# 1416           NaN               16       77x85.8          350   White
# 1417           NaN               18  74.5 x 81 mm          615    Grey
# 1418   7.7 Seconds               18           NaN          520   White
#
#      Compression Ratio Displacement Drive Type   Engine  \
# 0                  NaN          998        FWD   998 CC
# 1                9.9:1         1196        RWD  1196 CC
# 2                  NaN          999        NaN   999 CC
# 3                  NaN         1086        FWD  1086 CC
# 4                  NaN         1199        FWD  1199 CC
# ...                ...          ...        ...      ...
# 1414               NaN         1197        NaN  1197 CC
# 1415               NaN         1461        FWD  1461 CC
# 1416               NaN         1198        FWD  1198 CC
# 1417               NaN         1968        AWD  1968 CC
# 1418               NaN         1995        RWD  1995 CC
#
#                                    Engine Type  ... Turbo Charger  \
# 0                     Smartstream G1.0 T - GDi  ...           Yes
# 1                               In-Line Engine  ...            No
# 2                        HRA0 1.0 TURBO PETROL  ...           Yes
# 3                                 IRDE2 Engine  ...            No
# 4                         i-VTEC Petrol Engine  ...            No
# ...                                        ...  ...           ...
# 1414                               VTVT Engine  ...            No
# 1415                     dCi THP Diesel Engine  ...           Yes
# 1416         Revotron 1.2L Turbocharged engine  ...           Yes
# 1417              Common Rail Direct Injection  ...           Yes
# 1418  TwinPower Turbo 4-Cylinder Diesel Engine  ...           Yes
#
#      Turning Radius              Tyre Type Value Configuration  \
# 0               NaN       Tubeless, Radial                 NaN
# 1        4.5 metres         Tubeless Tyres                DOHC
# 2               5.0        Tubeless,Radial                SOHC
# 3        4.7 metres               Tubeless                SOHC
# 4        5.1 meters        Tubeless,Radial                SOHC
# ...             ...                    ...                 ...
# 1414     4.8 Meters               Tubeless                 NaN
# 1415     5.2 metres        Tubeless,Radial                DOHC
# 1416           5.1m  Tubeless Radial Tyres                DOHC
# 1417     5.75meters  Tubeless Radial Tyres                DOHC
# 1418     5.5 metres               Run-Flat                DOHC
#
#      Values per Cylinder Wheel Base Wheel Size   Width commonIcon  \
# 0                    4.0       2500         16    1790
# 1                    4.0     2350mm        NaN  1475mm
# 2                    4.0       2500         16    1758
# 3                    3.0     2380mm        NaN  1595mm
# 4                    4.0     2530mm         15  1694mm
# ...                  ...        ...        ...     ...        ...
# 1414                 4.0     2450mm        NaN  1735mm
# 1415                 4.0     2673mm         16  1822mm
# 1416                 4.0     2498mm         16  1811mm
# 1417                 4.0     2677mm         18  1839mm
# 1418                 4.0    2920 mm         18  1828mm
#
#              heading
# 0     Specifications
# 1     Specifications
# 2     Specifications
# 3     Specifications
# 4     Specifications
# ...              ...
# 1414  Specifications
# 1415  Specifications
# 1416  Specifications
# 1417  Specifications
# 1418  Specifications
#
# [1419 rows x 42 columns]

# %%
# Concatenate horizontally
df_chennai=pd.concat([dfc, df4], axis=1)

# %%
df_chennai
# Out:
#       it      ft         bt      km transmission  ownerNo      owner  \
# 0      0  Petrol        SUV  20,000    Automatic        1  1st Owner
# 1      0  Petrol   Minivans  20,687       Manual        1  1st Owner
# 2      0  Petrol        SUV  30,000       Manual        1  1st Owner
# 3      0  Petrol  Hatchback  59,247       Manual        1  1st Owner
# 4      0  Petrol  Hatchback  50,000       Manual        1  1st Owner
# ...   ..     ...        ...     ...          ...      ...        ...
# 1414   0  Petrol  Hatchback  42,891    Automatic        1  1st Owner
# 1415   0  Diesel        SUV  59,100       Manual        1  1st Owner
# 1416   0  Petrol        SUV  55,913    Automatic        1  1st Owner
# 1417   0  Diesel        SUV  65,000    Automatic        1  1st Owner
# 1418   0  Diesel      Sedan  60,000    Automatic        1  1st Owner
#
#              oem              model  modelYear  ...  Turbo Charger  \
# 0            Kia          Kia Sonet       2022  ...            Yes
# 1         Maruti        Maruti Eeco       2015  ...             No
# 2         Nissan     Nissan Magnite       2021  ...            Yes
# 3        Hyundai        Hyundai i10       2015  ...             No
# 4          Honda         Honda Jazz       2015  ...             No
# ...          ...                ...        ...  ...            ...
# 1414      Maruti       Maruti Swift       2018  ...             No
# 1415     Renault     Renault Duster       2018  ...            Yes
# 1416        Tata         Tata Nexon       2018  ...            Yes
# 1417  Volkswagen  Volkswagen Tiguan       2017  ...            Yes
# 1418         BMW    BMW 3 Series GT       2019  ...            Yes
#
#      Turning Radius              Tyre Type Value Configuration  \
# 0               NaN       Tubeless, Radial                 NaN
# 1        4.5 metres         Tubeless Tyres                DOHC
# 2               5.0        Tubeless,Radial                SOHC
# 3        4.7 metres               Tubeless                SOHC
# 4        5.1 meters        Tubeless,Radial                SOHC
# ...             ...                    ...                 ...
# 1414     4.8 Meters               Tubeless                 NaN
# 1415     5.2 metres        Tubeless,Radial                DOHC
# 1416           5.1m  Tubeless Radial Tyres                DOHC
# 1417     5.75meters  Tubeless Radial Tyres                DOHC
# 1418     5.5 metres               Run-Flat                DOHC
#
#      Values per Cylinder  Wheel Base Wheel Size   Width commonIcon  \
# 0                    4.0        2500         16    1790
# 1                    4.0      2350mm        NaN  1475mm
# 2                    4.0        2500         16    1758
# 3                    3.0      2380mm        NaN  1595mm
# 4                    4.0      2530mm         15  1694mm
# ...                  ...         ...        ...     ...        ...
# 1414                 4.0      2450mm        NaN  1735mm
# 1415                 4.0      2673mm         16  1822mm
# 1416                 4.0      2498mm         16  1811mm
# 1417                 4.0      2677mm         18  1839mm
# 1418                 4.0     2920 mm         18  1828mm
#
#              heading
# 0     Specifications
# 1     Specifications
# 2     Specifications
# 3     Specifications
# 4     Specifications
# ...              ...
# 1414  Specifications
# 1415  Specifications
# 1416  Specifications
# 1417  Specifications
# 1418  Specifications
#
# [1419 rows x 79 columns]

# %%
df.head()
# Out:
#                                       new_car_detail  \
# 0  {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 1  {'it': 0, 'ft': 'Petrol', 'bt': 'Minivans', 'k...
# 2  {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 3  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 4  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
#
#                                     new_car_overview  \
# 0  {'heading': 'Car overview', 'top': [{'key': 'R...
# 1  {'heading': 'Car overview', 'top': [{'key': 'R...
# 2  {'heading': 'Car overview', 'top': [{'key': 'R...
# 3  {'heading': 'Car overview', 'top': [{'key': 'R...
# 4  {'heading': 'Car overview', 'top': [{'key': 'R...
#
#                                      new_car_feature  \
# 0  {'heading': 'Features', 'top': [{'value': 'Pow...
# 1  {'heading': 'Features', 'top': [{'value': 'Low...
# 2  {'heading': 'Features', 'top': [{'value': 'Pow...
# 3  {'heading': 'Features', 'top': [{'value': 'Pow...
# 4  {'heading': 'Features', 'top': [{'value': 'Pow...
#
#                                        new_car_specs  \
# 0  {'heading': 'Specifications', 'top': [{'key': ...
# 1  {'heading': 'Specifications', 'top': [{'key': ...
# 2  {'heading': 'Specifications', 'top': [{'key': ...
# 3  {'heading': 'Specifications', 'top': [{'key': ...
# 4  {'heading': 'Specifications', 'top': [{'key': ...
#
#                                            car_links
# 0  https://www.cardekho.com/used-car-details/used...
# 1  https://www.cardekho.com/buy-used-car-details/...
# 2  https://www.cardekho.com/used-car-details/used...
# 3  https://www.cardekho.com/buy-used-car-details/...
# 4  https://www.cardekho.com/used-car-details/used...

# %%
df5=df["car_links"]

# %%
df5
# Out:
# 0       https://www.cardekho.com/used-car-details/used...
# 1       https://www.cardekho.com/buy-used-car-details/...
# 2       https://www.cardekho.com/used-car-details/used...
# 3       https://www.cardekho.com/buy-used-car-details/...
# 4       https://www.cardekho.com/used-car-details/used...
#                               ...
# 1414    https://www.cardekho.com/used-car-details/used...
# 1415    https://www.cardekho.com/used-car-details/used...
# 1416    https://www.cardekho.com/used-car-details/used...
# 1417    https://www.cardekho.com/used-car-details/used...
# 1418    https://www.cardekho.com/used-car-details/used...
# Name: car_links, Length: 1419, dtype: object

# %%
df_chennai=pd.concat([df_chennai,df5],axis=1)

# %%
df_chennai
# Out:
#       it      ft         bt      km transmission  ownerNo      owner  \
# 0      0  Petrol        SUV  20,000    Automatic        1  1st Owner
# 1      0  Petrol   Minivans  20,687       Manual        1  1st Owner
# 2      0  Petrol        SUV  30,000       Manual        1  1st Owner
# 3      0  Petrol  Hatchback  59,247       Manual        1  1st Owner
# 4      0  Petrol  Hatchback  50,000       Manual        1  1st Owner
# ...   ..     ...        ...     ...          ...      ...        ...
# 1414   0  Petrol  Hatchback  42,891    Automatic        1  1st Owner
# 1415   0  Diesel        SUV  59,100       Manual        1  1st Owner
# 1416   0  Petrol        SUV  55,913    Automatic        1  1st Owner
# 1417   0  Diesel        SUV  65,000    Automatic        1  1st Owner
# 1418   0  Diesel      Sedan  60,000    Automatic        1  1st Owner
#
#              oem              model  modelYear  ...  Turning Radius  \
# 0            Kia          Kia Sonet       2022  ...             NaN
# 1         Maruti        Maruti Eeco       2015  ...      4.5 metres
# 2         Nissan     Nissan Magnite       2021  ...             5.0
# 3        Hyundai        Hyundai i10       2015  ...      4.7 metres
# 4          Honda         Honda Jazz       2015  ...      5.1 meters
# ...          ...                ...        ...  ...             ...
# 1414      Maruti       Maruti Swift       2018  ...      4.8 Meters
# 1415     Renault     Renault Duster       2018  ...      5.2 metres
# 1416        Tata         Tata Nexon       2018  ...            5.1m
# 1417  Volkswagen  Volkswagen Tiguan       2017  ...      5.75meters
# 1418         BMW    BMW 3 Series GT       2019  ...      5.5 metres
#
#                   Tyre Type Value Configuration Values per Cylinder  \
# 0          Tubeless, Radial                 NaN                 4.0
# 1            Tubeless Tyres                DOHC                 4.0
# 2           Tubeless,Radial                SOHC                 4.0
# 3                  Tubeless                SOHC                 3.0
# 4           Tubeless,Radial                SOHC                 4.0
# ...                     ...                 ...                 ...
# 1414               Tubeless                 NaN                 4.0
# 1415        Tubeless,Radial                DOHC                 4.0
# 1416  Tubeless Radial Tyres                DOHC                 4.0
# 1417  Tubeless Radial Tyres                DOHC                 4.0
# 1418               Run-Flat                DOHC                 4.0
#
#      Wheel Base  Wheel Size   Width commonIcon         heading  \
# 0          2500          16    1790             Specifications
# 1        2350mm         NaN  1475mm             Specifications
# 2          2500          16    1758             Specifications
# 3        2380mm         NaN  1595mm             Specifications
# 4        2530mm          15  1694mm             Specifications
# ...         ...         ...     ...        ...             ...
# 1414     2450mm         NaN  1735mm             Specifications
# 1415     2673mm          16  1822mm             Specifications
# 1416     2498mm          16  1811mm             Specifications
# 1417     2677mm          18  1839mm             Specifications
# 1418    2920 mm          18  1828mm             Specifications
#
#                                               car_links
# 0     https://www.cardekho.com/used-car-details/used...
# 1     https://www.cardekho.com/buy-used-car-details/...
# 2     https://www.cardekho.com/used-car-details/used...
# 3     https://www.cardekho.com/buy-used-car-details/...
# 4     https://www.cardekho.com/used-car-details/used...
# ...                                                 ...
# 1414  https://www.cardekho.com/used-car-details/used...
# 1415  https://www.cardekho.com/used-car-details/used...
# 1416  https://www.cardekho.com/used-car-details/used...
# 1417  https://www.cardekho.com/used-car-details/used...
# 1418  https://www.cardekho.com/used-car-details/used...
#
# [1419 rows x 80 columns]

# %%
df_chennai["city"]="Chennai"

# %%
df_chennai
# Out:
#       it      ft         bt      km transmission  ownerNo      owner  \
# 0      0  Petrol        SUV  20,000    Automatic        1  1st Owner
# 1      0  Petrol   Minivans  20,687       Manual        1  1st Owner
# 2      0  Petrol        SUV  30,000       Manual        1  1st Owner
# 3      0  Petrol  Hatchback  59,247       Manual        1  1st Owner
# 4      0  Petrol  Hatchback  50,000       Manual        1  1st Owner
# ...   ..     ...        ...     ...          ...      ...        ...
# 1414   0  Petrol  Hatchback  42,891    Automatic        1  1st Owner
# 1415   0  Diesel        SUV  59,100       Manual        1  1st Owner
# 1416   0  Petrol        SUV  55,913    Automatic        1  1st Owner
# 1417   0  Diesel        SUV  65,000    Automatic        1  1st Owner
# 1418   0  Diesel      Sedan  60,000    Automatic        1  1st Owner
#
#              oem              model  modelYear  ...              Tyre Type  \
# 0            Kia          Kia Sonet       2022  ...       Tubeless, Radial
# 1         Maruti        Maruti Eeco       2015  ...         Tubeless Tyres
# 2         Nissan     Nissan Magnite       2021  ...        Tubeless,Radial
# 3        Hyundai        Hyundai i10       2015  ...               Tubeless
# 4          Honda         Honda Jazz       2015  ...        Tubeless,Radial
# ...          ...                ...        ...  ...                    ...
# 1414      Maruti       Maruti Swift       2018  ...               Tubeless
# 1415     Renault     Renault Duster       2018  ...        Tubeless,Radial
# 1416        Tata         Tata Nexon       2018  ...  Tubeless Radial Tyres
# 1417  Volkswagen  Volkswagen Tiguan       2017  ...  Tubeless Radial Tyres
# 1418         BMW    BMW 3 Series GT       2019  ...               Run-Flat
#
#      Value Configuration Values per Cylinder Wheel Base Wheel Size   Width  \
# 0                    NaN                 4.0       2500         16    1790
# 1                   DOHC                 4.0     2350mm        NaN  1475mm
# 2                   SOHC                 4.0       2500         16    1758
# 3                   SOHC                 3.0     2380mm        NaN  1595mm
# 4                   SOHC                 4.0     2530mm         15  1694mm
# ...                  ...                 ...        ...        ...     ...
# 1414                 NaN                 4.0     2450mm        NaN  1735mm
# 1415                DOHC                 4.0     2673mm         16  1822mm
# 1416                DOHC                 4.0     2498mm         16  1811mm
# 1417                DOHC                 4.0     2677mm         18  1839mm
# 1418                DOHC                 4.0    2920 mm         18  1828mm
#
#      commonIcon         heading  \
# 0                Specifications
# 1                Specifications
# 2                Specifications
# 3                Specifications
# 4                Specifications
# ...         ...             ...
# 1414             Specifications
# 1415             Specifications
# 1416             Specifications
# 1417             Specifications
# 1418             Specifications
#
#                                               car_links     city
# 0     https://www.cardekho.com/used-car-details/used...  Chennai
# 1     https://www.cardekho.com/buy-used-car-details/...  Chennai
# 2     https://www.cardekho.com/used-car-details/used...  Chennai
# 3     https://www.cardekho.com/buy-used-car-details/...  Chennai
# 4     https://www.cardekho.com/used-car-details/used...  Chennai
# ...                                                 ...      ...
# 1414  https://www.cardekho.com/used-car-details/used...  Chennai
# 1415  https://www.cardekho.com/used-car-details/used...  Chennai
# 1416  https://www.cardekho.com/used-car-details/used...  Chennai
# 1417  https://www.cardekho.com/used-car-details/used...  Chennai
# 1418  https://www.cardekho.com/used-car-details/used...  Chennai
#
# [1419 rows x 81 columns]

# %%
path="D:\CHITRA\CARDEHO\\unclean_chennai.csv"
df_chennai.to_csv(path, index=False)
