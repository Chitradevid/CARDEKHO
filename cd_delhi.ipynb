# %%
#DELHI CARS

# %%
import pandas as pd
import json

# %%
df=pd.read_excel("C:/Users/ASUS/Downloads/delhi_cars.xlsx")

# %%
df
# Out:
#                                          new_car_detail  \
# 0     {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
# 1     {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 2     {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 3     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 4     {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# ...                                                 ...
# 1480  {'it': 0, 'ft': 'Petrol', 'bt': 'Sedan', 'km':...
# 1481  {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 1482  {'it': 0, 'ft': 'Petrol', 'bt': 'Sedan', 'km':...
# 1483  {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
# 1484  {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
#
#                                        new_car_overview  \
# 0     {'heading': 'Car overview', 'top': [{'key': 'R...
# 1     {'heading': 'Car overview', 'top': [{'key': 'R...
# 2     {'heading': 'Car overview', 'top': [{'key': 'R...
# 3     {'heading': 'Car overview', 'top': [{'key': 'R...
# 4     {'heading': 'Car overview', 'top': [{'key': 'R...
# ...                                                 ...
# 1480  {'heading': 'Car overview', 'top': [{'key': 'R...
# 1481  {'heading': 'Car overview', 'top': [{'key': 'R...
# 1482  {'heading': 'Car overview', 'top': [{'key': 'R...
# 1483  {'heading': 'Car overview', 'top': [{'key': 'R...
# 1484  {'heading': 'Car overview', 'top': [{'key': 'I...
#
#                                         new_car_feature  \
# 0     {'heading': 'Features', 'top': [{'value': 'Pow...
# 1     {'heading': 'Features', 'top': [{'value': 'Pow...
# 2     {'heading': 'Features', 'top': [{'value': 'Pow...
# 3     {'heading': 'Features', 'top': [{'value': 'Pow...
# 4     {'heading': 'Features', 'top': [{'value': 'Pow...
# ...                                                 ...
# 1480  {'heading': 'Features', 'top': [{'value': 'Pow...
# 1481  {'heading': 'Features', 'top': [{'value': 'Pow...
# 1482  {'heading': 'Features', 'top': [{'value': 'Pow...
# 1483  {'heading': 'Features', 'top': [{'value': 'Pow...
# 1484  {'heading': 'Features', 'top': [{'value': 'Pow...
#
#                                           new_car_specs  \
# 0     {'heading': 'Specifications', 'top': [{'key': ...
# 1     {'heading': 'Specifications', 'top': [{'key': ...
# 2     {'heading': 'Specifications', 'top': [{'key': ...
# 3     {'heading': 'Specifications', 'top': [{'key': ...
# 4     {'heading': 'Specifications', 'top': [{'key': ...
# ...                                                 ...
# 1480  {'heading': 'Specifications', 'top': [{'key': ...
# 1481  {'heading': 'Specifications', 'top': [{'key': ...
# 1482  {'heading': 'Specifications', 'top': [{'key': ...
# 1483  {'heading': 'Specifications', 'top': [{'key': ...
# 1484  {'heading': 'Specifications', 'top': [{'key': ...
#
#                                               car_links
# 0     https://www.cardekho.com/used-car-details/used...
# 1     https://www.cardekho.com/buy-used-car-details/...
# 2     https://www.cardekho.com/used-car-details/used...
# 3     https://www.cardekho.com/buy-used-car-details/...
# 4     https://www.cardekho.com/used-car-details/used...
# ...                                                 ...
# 1480  https://www.cardekho.com/used-car-details/used...
# 1481  https://www.cardekho.com/used-car-details/used...
# 1482  https://www.cardekho.com/used-car-details/used...
# 1483  https://www.cardekho.com/used-car-details/used...
# 1484  https://www.cardekho.com/used-car-details/used...
#
# [1485 rows x 5 columns]

# %%
# Function to safely load JSON if it's a string
def safe_load(x):
    if isinstance(x, str):
        return json.loads(x.replace("'", '"').replace("None", "1"))
    return x  # If it's already a dict, return as is

# Apply the safe_load function
df["new_car_detail"] = df["new_car_detail"].apply(safe_load)

# Expand the main dictionary into columns
df_expanded = pd.DataFrame(df["new_car_detail"].to_list())

# Expand the nested dictionary into columns
df_nested_expanded = df_expanded["trendingText"].apply(pd.Series)

# Combine the original and nested DataFrame
df11 = pd.concat([df_expanded.drop(columns=["trendingText"]), df_nested_expanded], axis=1)

# %%
df11
# Out:
#       it      ft         bt      km transmission  ownerNo      owner  \
# 0      0  Diesel        SUV  10,000    Automatic        1  1st Owner
# 1      0  Petrol        SUV  57,437       Manual        2  2nd Owner
# 2      0  Petrol        SUV   8,000    Automatic        1  1st Owner
# 3      0  Petrol  Hatchback  28,151       Manual        2  2nd Owner
# 4      0  Petrol        SUV  60,000       Manual        1  1st Owner
# ...   ..     ...        ...     ...          ...      ...        ...
# 1480   0  Petrol      Sedan  60,000    Automatic        1  1st Owner
# 1481   0  Petrol        SUV  20,000       Manual        1  1st Owner
# 1482   0  Petrol      Sedan  60,000       Manual        1  1st Owner
# 1483   0  Diesel        SUV  38,000       Manual        1  1st Owner
# 1484   0  Diesel        SUV   7,000    Automatic        0  0th Owner
#
#                 oem              model  modelYear  centralVariantId  \
# 0               Kia         Kia Seltos       2022              7121
# 1           Hyundai      Hyundai Creta       2016              1449
# 2     Mercedes-Benz  Mercedes-Benz GLC       2020              6837
# 3            Maruti       Maruti Swift       2018             10403
# 4           Hyundai      Hyundai Creta       2017              5362
# ...             ...                ...        ...               ...
# 1480          Honda         Honda City       2019              5627
# 1481            Kia          Kia Sonet       2021              8000
# 1482        Hyundai      Hyundai Verna       2011              1832
# 1483        Hyundai      Hyundai Creta       2019              6440
# 1484             MG         MG Gloster       2023              9298
#
#                variantName         price priceActual priceSaving  \
# 0       GTX Plus Diesel AT     ₹ 19 Lakh
# 1               1.6 VTVT S   ₹ 7.62 Lakh
# 2                      200     ₹ 56 Lakh
# 3                      VXI   ₹ 5.23 Lakh
# 4          1.6 VTVT E Plus   ₹ 7.65 Lakh
# ...                    ...           ...         ...         ...
# 1480          i-VTEC CVT V      ₹ 9 Lakh
# 1481         HTK Plus BSVI   ₹ 9.50 Lakh
# 1482           1.6 SX VTVT   ₹ 4.18 Lakh
# 1483  1.6 SX Option Diesel  ₹ 11.95 Lakh
# 1484       Savvy 6 Str 4x4  ₹ 46.40 Lakh
#
#       priceFixedText                                             imgUrl  \
# 0                  1  https://stimg.cardekho.com/used-cars/common/ic...
# 1                  1  https://stimg.cardekho.com/used-cars/common/ic...
# 2                  1  https://stimg.cardekho.com/used-cars/common/ic...
# 3                  1  https://stimg.cardekho.com/used-cars/common/ic...
# 4                  1  https://stimg.cardekho.com/used-cars/common/ic...
# ...              ...                                                ...
# 1480               1  https://stimg.cardekho.com/used-cars/common/ic...
# 1481               1  https://stimg.cardekho.com/used-cars/common/ic...
# 1482               1  https://stimg.cardekho.com/used-cars/common/ic...
# 1483               1  https://stimg.cardekho.com/used-cars/common/ic...
# 1484               1  https://stimg.cardekho.com/used-cars/common/ic...
#
#             heading                                 desc
# 0     Trending Car!  High chances of sale in next 6 days
# 1     Trending Car!  High chances of sale in next 6 days
# 2     Trending Car!  High chances of sale in next 6 days
# 3     Trending Car!  High chances of sale in next 6 days
# 4     Trending Car!  High chances of sale in next 6 days
# ...             ...                                  ...
# 1480  Trending Car!  High chances of sale in next 6 days
# 1481  Trending Car!  High chances of sale in next 6 days
# 1482  Trending Car!  High chances of sale in next 6 days
# 1483  Trending Car!  High chances of sale in next 6 days
# 1484  Trending Car!  High chances of sale in next 6 days
#
# [1485 rows x 19 columns]

# %%
#overview

# %%
df["new_car_overview"]
# Out:
# 0       {'heading': 'Car overview', 'top': [{'key': 'R...
# 1       {'heading': 'Car overview', 'top': [{'key': 'R...
# 2       {'heading': 'Car overview', 'top': [{'key': 'R...
# 3       {'heading': 'Car overview', 'top': [{'key': 'R...
# 4       {'heading': 'Car overview', 'top': [{'key': 'R...
#                               ...
# 1480    {'heading': 'Car overview', 'top': [{'key': 'R...
# 1481    {'heading': 'Car overview', 'top': [{'key': 'R...
# 1482    {'heading': 'Car overview', 'top': [{'key': 'R...
# 1483    {'heading': 'Car overview', 'top': [{'key': 'R...
# 1484    {'heading': 'Car overview', 'top': [{'key': 'I...
# Name: new_car_overview, Length: 1485, dtype: object

# %%
import pandas as pd
import json

# Function to safely load JSON if it's a string
def safe_load(x):
    if isinstance(x, str):
        try:
            return json.loads(x.replace("'", '"').replace("None", "1"))
        except json.JSONDecodeError:
            return None  # Return None if JSON loading fails
    return x  # If it's already a list or dict, return as is

# Apply the safe_load function to the 'new_car_overview' column
df["new_car_overview"] = df["new_car_overview"].apply(safe_load)

# Function to extract key-value pairs from the list of dictionaries
def extract_key_value_pairs(dict_list):
    if isinstance(dict_list, list):  # Check if the item is a list
        extracted_data = {}
        for item in dict_list:
            if isinstance(item, dict):  # Ensure each item is a dictionary
                key = item.get('key')
                value = item.get('value')
                if key:  # Only add if the key exists
                    extracted_data[key] = value
        return pd.Series(extracted_data)
    return pd.Series()  # Return an empty Series if dict_list is not a list

# Expand the 'new_car_overview' column into a new DataFrame
df_expanded = df["new_car_overview"].apply(extract_key_value_pairs)

# %%
def extract_key_value_pairs(dict_list):
    if isinstance(dict_list, list):
        extracted_data = {}
        for item in dict_list:
            if isinstance(item, dict):
                key = item.get('key')
                value = item.get('value')
                if key:  # Only add if the key exists
                    extracted_data[key] = value
        return pd.Series(extracted_data)
    return pd.Series()  # Return an empty Series if dict_list is not a list

# Apply the extraction function to the 'top' column
df2 = df['new_car_overview'].apply(lambda x: x['top'] if isinstance(x, dict) else None).apply(extract_key_value_pairs)

# %%
df2
# Out:
#      Registration Year     Insurance Validity Fuel Type    Seats  Kms Driven  \
# 0                 2022  Third Party insurance    Diesel  5 Seats  10,000 Kms
# 1             May 2016               Zero Dep    Petrol  5 Seats  57,437 Kms
# 2             Dec 2020          Comprehensive    Petrol  5 Seats   8,000 Kms
# 3             Jan 2019          Comprehensive    Petrol  5 Seats  28,151 Kms
# 4                 2017  Third Party insurance    Petrol  5 Seats  60,000 Kms
# ...                ...                    ...       ...      ...         ...
# 1480              2019  Third Party insurance    Petrol  5 Seats  60,000 Kms
# 1481              2021  Third Party insurance    Petrol  5 Seats  20,000 Kms
# 1482              2011  Third Party insurance    Petrol  5 Seats  60,000 Kms
# 1483          Oct 2019  Third Party insurance    Diesel  5 Seats  38,000 Kms
# 1484               NaN  Third Party insurance    Diesel  6 Seats   7,000 Kms
#
#          Ownership Engine Displacement Transmission  Year of Manufacture   RTO
# 0      First Owner             1493 cc    Automatic                 2022   NaN
# 1     Second Owner             1591 cc       Manual                 2016  HR51
# 2      First Owner             1991 cc    Automatic                 2020  DL01
# 3     Second Owner             1197 cc       Manual                 2018  DL4C
# 4      First Owner             1591 cc       Manual                 2017  DL8C
# ...            ...                 ...          ...                  ...   ...
# 1480   First Owner             1497 cc    Automatic                 2019  DL4C
# 1481   First Owner             1197 cc       Manual                 2021   NaN
# 1482   First Owner             1591 cc       Manual                 2011   NaN
# 1483   First Owner             1582 cc       Manual                 2019  HR26
# 1484           NaN             1996 cc    Automatic                 2023   NaN
#
# [1485 rows x 10 columns]

# %%
# Concatenate horizontally
dfd= pd.concat([df11, df2], axis=1)

# %%
dfd
# Out:
#       it      ft         bt      km transmission  ownerNo      owner  \
# 0      0  Diesel        SUV  10,000    Automatic        1  1st Owner
# 1      0  Petrol        SUV  57,437       Manual        2  2nd Owner
# 2      0  Petrol        SUV   8,000    Automatic        1  1st Owner
# 3      0  Petrol  Hatchback  28,151       Manual        2  2nd Owner
# 4      0  Petrol        SUV  60,000       Manual        1  1st Owner
# ...   ..     ...        ...     ...          ...      ...        ...
# 1480   0  Petrol      Sedan  60,000    Automatic        1  1st Owner
# 1481   0  Petrol        SUV  20,000       Manual        1  1st Owner
# 1482   0  Petrol      Sedan  60,000       Manual        1  1st Owner
# 1483   0  Diesel        SUV  38,000       Manual        1  1st Owner
# 1484   0  Diesel        SUV   7,000    Automatic        0  0th Owner
#
#                 oem              model  modelYear  ...  Registration Year  \
# 0               Kia         Kia Seltos       2022  ...               2022
# 1           Hyundai      Hyundai Creta       2016  ...           May 2016
# 2     Mercedes-Benz  Mercedes-Benz GLC       2020  ...           Dec 2020
# 3            Maruti       Maruti Swift       2018  ...           Jan 2019
# 4           Hyundai      Hyundai Creta       2017  ...               2017
# ...             ...                ...        ...  ...                ...
# 1480          Honda         Honda City       2019  ...               2019
# 1481            Kia          Kia Sonet       2021  ...               2021
# 1482        Hyundai      Hyundai Verna       2011  ...               2011
# 1483        Hyundai      Hyundai Creta       2019  ...           Oct 2019
# 1484             MG         MG Gloster       2023  ...                NaN
#
#          Insurance Validity Fuel Type    Seats  Kms Driven     Ownership  \
# 0     Third Party insurance    Diesel  5 Seats  10,000 Kms   First Owner
# 1                  Zero Dep    Petrol  5 Seats  57,437 Kms  Second Owner
# 2             Comprehensive    Petrol  5 Seats   8,000 Kms   First Owner
# 3             Comprehensive    Petrol  5 Seats  28,151 Kms  Second Owner
# 4     Third Party insurance    Petrol  5 Seats  60,000 Kms   First Owner
# ...                     ...       ...      ...         ...           ...
# 1480  Third Party insurance    Petrol  5 Seats  60,000 Kms   First Owner
# 1481  Third Party insurance    Petrol  5 Seats  20,000 Kms   First Owner
# 1482  Third Party insurance    Petrol  5 Seats  60,000 Kms   First Owner
# 1483  Third Party insurance    Diesel  5 Seats  38,000 Kms   First Owner
# 1484  Third Party insurance    Diesel  6 Seats   7,000 Kms           NaN
#
#      Engine Displacement Transmission Year of Manufacture   RTO
# 0                1493 cc    Automatic                2022   NaN
# 1                1591 cc       Manual                2016  HR51
# 2                1991 cc    Automatic                2020  DL01
# 3                1197 cc       Manual                2018  DL4C
# 4                1591 cc       Manual                2017  DL8C
# ...                  ...          ...                 ...   ...
# 1480             1497 cc    Automatic                2019  DL4C
# 1481             1197 cc       Manual                2021   NaN
# 1482             1591 cc       Manual                2011   NaN
# 1483             1582 cc       Manual                2019  HR26
# 1484             1996 cc    Automatic                2023   NaN
#
# [1485 rows x 29 columns]

# %%
#car features

# %%
df.new_car_feature=df["new_car_feature"].apply(lambda x:json.loads(x.replace("'",'"').replace("None","1")))
df_new=pd.DataFrame(df.new_car_feature.to_list())

# %%
df_new
# Out:
#        heading                                                top  \
# 0     Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 1     Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 2     Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 3     Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 4     Features  [{'value': 'Power Steering'}, {'value': 'Power...
# ...        ...                                                ...
# 1480  Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 1481  Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 1482  Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 1483  Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 1484  Features  [{'value': 'Power Steering'}, {'value': 'Power...
#
#                                                    data  \
# 0     [{'heading': 'Comfort & Convenience', 'subHead...
# 1     [{'heading': 'Comfort & Convenience', 'subHead...
# 2     [{'heading': 'Comfort & Convenience', 'subHead...
# 3     [{'heading': 'Comfort & Convenience', 'subHead...
# 4     [{'heading': 'Comfort & Convenience', 'subHead...
# ...                                                 ...
# 1480  [{'heading': 'Comfort & Convenience', 'subHead...
# 1481  [{'heading': 'Comfort & Convenience', 'subHead...
# 1482  [{'heading': 'Comfort & Convenience', 'subHead...
# 1483  [{'heading': 'Comfort & Convenience', 'subHead...
# 1484  [{'heading': 'Comfort & Convenience', 'subHead...
#
#                                              commonIcon
# 0     https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1     https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 2     https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 3     https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 4     https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# ...                                                 ...
# 1480  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1481  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1482  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1483  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1484  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
#
# [1485 rows x 4 columns]

# %%
import pandas as pd
import numpy as np


# Ensure 'top' column contains lists; replace non-lists with empty lists
df_new['top'] = df_new['top'].apply(lambda x: x if isinstance(x, list) else [])

# Extract feature values and concatenate them into a single string per row
df_new['Features'] = df_new['top'].apply(lambda x: ', '.join([item['value'] for item in x]))

# Drop the original 'top' column if no longer needed
df_new = df_new.drop(columns=['top'])

df_new
# Out:
#        heading                                               data  \
# 0     Features  [{'heading': 'Comfort & Convenience', 'subHead...
# 1     Features  [{'heading': 'Comfort & Convenience', 'subHead...
# 2     Features  [{'heading': 'Comfort & Convenience', 'subHead...
# 3     Features  [{'heading': 'Comfort & Convenience', 'subHead...
# 4     Features  [{'heading': 'Comfort & Convenience', 'subHead...
# ...        ...                                                ...
# 1480  Features  [{'heading': 'Comfort & Convenience', 'subHead...
# 1481  Features  [{'heading': 'Comfort & Convenience', 'subHead...
# 1482  Features  [{'heading': 'Comfort & Convenience', 'subHead...
# 1483  Features  [{'heading': 'Comfort & Convenience', 'subHead...
# 1484  Features  [{'heading': 'Comfort & Convenience', 'subHead...
#
#                                              commonIcon  \
# 0     https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1     https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 2     https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 3     https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 4     https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# ...                                                 ...
# 1480  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1481  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1482  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1483  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1484  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
#
#                                                Features
# 0     Power Steering, Power Windows Front, Air Condi...
# 1     Power Steering, Power Windows Front, Air Condi...
# 2     Power Steering, Power Windows Front, Air Condi...
# 3     Power Steering, Power Windows Front, Air Condi...
# 4     Power Steering, Power Windows Front, Air Condi...
# ...                                                 ...
# 1480  Power Steering, Power Windows Front, Air Condi...
# 1481  Power Steering, Power Windows Front, Air Condi...
# 1482  Power Steering, Power Windows Front, Air Condi...
# 1483  Power Steering, Power Windows Front, Air Condi...
# 1484  Power Steering, Power Windows Front, Air Condi...
#
# [1485 rows x 4 columns]

# %%
# Function to extract features and create columns
def extract_features(data):
    features_dict = {}
    for category in data:
        sub_heading = category['subHeading']
        features = [item['value'] for item in category['list']]
        features_dict[sub_heading] = ', '.join(features)
    return features_dict

# Apply the function to the 'data' column and convert to DataFrame
features_df = pd.json_normalize(df_new['data'].apply(extract_features))

# Concatenate with the original DataFrame if needed
df3 = pd.concat([df_new.drop(columns=['data']), features_df], axis=1)
df3
# Out:
#        heading                                         commonIcon  \
# 0     Features  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1     Features  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 2     Features  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 3     Features  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 4     Features  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# ...        ...                                                ...
# 1480  Features  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1481  Features  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1482  Features  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1483  Features  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1484  Features  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
#
#                                                Features  \
# 0     Power Steering, Power Windows Front, Air Condi...
# 1     Power Steering, Power Windows Front, Air Condi...
# 2     Power Steering, Power Windows Front, Air Condi...
# 3     Power Steering, Power Windows Front, Air Condi...
# 4     Power Steering, Power Windows Front, Air Condi...
# ...                                                 ...
# 1480  Power Steering, Power Windows Front, Air Condi...
# 1481  Power Steering, Power Windows Front, Air Condi...
# 1482  Power Steering, Power Windows Front, Air Condi...
# 1483  Power Steering, Power Windows Front, Air Condi...
# 1484  Power Steering, Power Windows Front, Air Condi...
#
#                                                 Comfort  \
# 0     Power Steering, Power Windows Front, Power Win...
# 1     Power Steering, Power Windows Front, Power Win...
# 2     Power Steering, Power Windows Front, Power Win...
# 3     Power Steering, Power Windows Front, Power Win...
# 4     Power Steering, Power Windows Front, Power Win...
# ...                                                 ...
# 1480  Power Steering, Power Windows Front, Power Win...
# 1481  Power Steering, Power Windows Front, Power Win...
# 1482  Power Steering, Power Windows Front, Power Win...
# 1483  Power Steering, Power Windows Front, Power Win...
# 1484  Power Steering, Power Windows Front, Power Win...
#
#                                                Interior  \
# 0     Air Conditioner, Heater, Adjustable Steering, ...
# 1     Air Conditioner, Heater, Adjustable Steering, ...
# 2     Air Conditioner, Heater, Adjustable Steering, ...
# 3     Air Conditioner, Heater, Adjustable Steering, ...
# 4     Air Conditioner, Heater, Adjustable Steering, ...
# ...                                                 ...
# 1480  Air Conditioner, Heater, Adjustable Steering, ...
# 1481  Air Conditioner, Heater, Adjustable Steering, ...
# 1482  Air Conditioner, Heater, Adjustable Steering, ...
# 1483  Air Conditioner, Heater, Adjustable Steering, ...
# 1484  Air Conditioner, Heater, Adjustable Steering, ...
#
#                                                Exterior  \
# 0     Adjustable Head Lights, Fog Lights Front, Powe...
# 1     Adjustable Head Lights, Fog Lights Front, Powe...
# 2     Adjustable Head Lights, Fog Lights Front, Powe...
# 3     Adjustable Head Lights, Power Adjustable Exter...
# 4     Adjustable Head Lights, Power Adjustable Exter...
# ...                                                 ...
# 1480  Adjustable Head Lights, Fog Lights Front, Powe...
# 1481  Adjustable Head Lights, Fog Lights Front, Powe...
# 1482  Adjustable Head Lights, Fog Lights Front, Powe...
# 1483  Adjustable Head Lights, Fog Lights Front, Powe...
# 1484  Adjustable Head Lights, Fog Lights Front, Fog ...
#
#                                                  Safety  \
# 0     Anti Lock Braking System, Brake Assist, Center...
# 1     Anti Lock Braking System, Centeral Locking, Po...
# 2     Anti Lock Braking System, Brake Assist, Center...
# 3     Anti Lock Braking System, Brake Assist, Center...
# 4     Anti Lock Braking System, Centeral Locking, Po...
# ...                                                 ...
# 1480  Anti Lock Braking System, Centeral Locking, Po...
# 1481  Anti Lock Braking System, Centeral Locking, Po...
# 1482  Anti Lock Braking System, Centeral Locking, Po...
# 1483  Anti Lock Braking System, Centeral Locking, Po...
# 1484  Anti Lock Braking System, Brake Assist, Center...
#
#                                           Entertainment
# 0     Radio, Speakers Front, Speakers Rear, Integrat...
# 1     Cd Player, Radio, Speakers Front, Speakers Rea...
# 2     Radio, Speakers Front, Speakers Rear, Integrat...
# 3     Radio, Speakers Front, Speakers Rear, Usb Auxi...
# 4     Cd Player, Radio, Speakers Front, Speakers Rea...
# ...                                                 ...
# 1480  Radio, Speakers Front, Speakers Rear, Integrat...
# 1481  Radio, Speakers Front, Speakers Rear, Integrat...
# 1482  Cd Player, Radio, Audio System Remote Control,...
# 1483  Radio, Speakers Front, Speakers Rear, Usb Auxi...
# 1484  Radio, Speakers Front, Speakers Rear, Integrat...
#
# [1485 rows x 8 columns]

# %%
# Concatenate horizontally
dfd=pd.concat([dfd, df3], axis=1)

# %%
dfd
# Out:
#       it      ft         bt      km transmission  ownerNo      owner  \
# 0      0  Diesel        SUV  10,000    Automatic        1  1st Owner
# 1      0  Petrol        SUV  57,437       Manual        2  2nd Owner
# 2      0  Petrol        SUV   8,000    Automatic        1  1st Owner
# 3      0  Petrol  Hatchback  28,151       Manual        2  2nd Owner
# 4      0  Petrol        SUV  60,000       Manual        1  1st Owner
# ...   ..     ...        ...     ...          ...      ...        ...
# 1480   0  Petrol      Sedan  60,000    Automatic        1  1st Owner
# 1481   0  Petrol        SUV  20,000       Manual        1  1st Owner
# 1482   0  Petrol      Sedan  60,000       Manual        1  1st Owner
# 1483   0  Diesel        SUV  38,000       Manual        1  1st Owner
# 1484   0  Diesel        SUV   7,000    Automatic        0  0th Owner
#
#                 oem              model  modelYear  ...  Year of Manufacture  \
# 0               Kia         Kia Seltos       2022  ...                 2022
# 1           Hyundai      Hyundai Creta       2016  ...                 2016
# 2     Mercedes-Benz  Mercedes-Benz GLC       2020  ...                 2020
# 3            Maruti       Maruti Swift       2018  ...                 2018
# 4           Hyundai      Hyundai Creta       2017  ...                 2017
# ...             ...                ...        ...  ...                  ...
# 1480          Honda         Honda City       2019  ...                 2019
# 1481            Kia          Kia Sonet       2021  ...                 2021
# 1482        Hyundai      Hyundai Verna       2011  ...                 2011
# 1483        Hyundai      Hyundai Creta       2019  ...                 2019
# 1484             MG         MG Gloster       2023  ...                 2023
#
#        RTO   heading                                         commonIcon  \
# 0      NaN  Features  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1     HR51  Features  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 2     DL01  Features  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 3     DL4C  Features  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 4     DL8C  Features  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# ...    ...       ...                                                ...
# 1480  DL4C  Features  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1481   NaN  Features  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1482   NaN  Features  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1483  HR26  Features  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1484   NaN  Features  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
#
#                                                Features  \
# 0     Power Steering, Power Windows Front, Air Condi...
# 1     Power Steering, Power Windows Front, Air Condi...
# 2     Power Steering, Power Windows Front, Air Condi...
# 3     Power Steering, Power Windows Front, Air Condi...
# 4     Power Steering, Power Windows Front, Air Condi...
# ...                                                 ...
# 1480  Power Steering, Power Windows Front, Air Condi...
# 1481  Power Steering, Power Windows Front, Air Condi...
# 1482  Power Steering, Power Windows Front, Air Condi...
# 1483  Power Steering, Power Windows Front, Air Condi...
# 1484  Power Steering, Power Windows Front, Air Condi...
#
#                                                 Comfort  \
# 0     Power Steering, Power Windows Front, Power Win...
# 1     Power Steering, Power Windows Front, Power Win...
# 2     Power Steering, Power Windows Front, Power Win...
# 3     Power Steering, Power Windows Front, Power Win...
# 4     Power Steering, Power Windows Front, Power Win...
# ...                                                 ...
# 1480  Power Steering, Power Windows Front, Power Win...
# 1481  Power Steering, Power Windows Front, Power Win...
# 1482  Power Steering, Power Windows Front, Power Win...
# 1483  Power Steering, Power Windows Front, Power Win...
# 1484  Power Steering, Power Windows Front, Power Win...
#
#                                                Interior  \
# 0     Air Conditioner, Heater, Adjustable Steering, ...
# 1     Air Conditioner, Heater, Adjustable Steering, ...
# 2     Air Conditioner, Heater, Adjustable Steering, ...
# 3     Air Conditioner, Heater, Adjustable Steering, ...
# 4     Air Conditioner, Heater, Adjustable Steering, ...
# ...                                                 ...
# 1480  Air Conditioner, Heater, Adjustable Steering, ...
# 1481  Air Conditioner, Heater, Adjustable Steering, ...
# 1482  Air Conditioner, Heater, Adjustable Steering, ...
# 1483  Air Conditioner, Heater, Adjustable Steering, ...
# 1484  Air Conditioner, Heater, Adjustable Steering, ...
#
#                                                Exterior  \
# 0     Adjustable Head Lights, Fog Lights Front, Powe...
# 1     Adjustable Head Lights, Fog Lights Front, Powe...
# 2     Adjustable Head Lights, Fog Lights Front, Powe...
# 3     Adjustable Head Lights, Power Adjustable Exter...
# 4     Adjustable Head Lights, Power Adjustable Exter...
# ...                                                 ...
# 1480  Adjustable Head Lights, Fog Lights Front, Powe...
# 1481  Adjustable Head Lights, Fog Lights Front, Powe...
# 1482  Adjustable Head Lights, Fog Lights Front, Powe...
# 1483  Adjustable Head Lights, Fog Lights Front, Powe...
# 1484  Adjustable Head Lights, Fog Lights Front, Fog ...
#
#                                                  Safety  \
# 0     Anti Lock Braking System, Brake Assist, Center...
# 1     Anti Lock Braking System, Centeral Locking, Po...
# 2     Anti Lock Braking System, Brake Assist, Center...
# 3     Anti Lock Braking System, Brake Assist, Center...
# 4     Anti Lock Braking System, Centeral Locking, Po...
# ...                                                 ...
# 1480  Anti Lock Braking System, Centeral Locking, Po...
# 1481  Anti Lock Braking System, Centeral Locking, Po...
# 1482  Anti Lock Braking System, Centeral Locking, Po...
# 1483  Anti Lock Braking System, Centeral Locking, Po...
# 1484  Anti Lock Braking System, Brake Assist, Center...
#
#                                           Entertainment
# 0     Radio, Speakers Front, Speakers Rear, Integrat...
# 1     Cd Player, Radio, Speakers Front, Speakers Rea...
# 2     Radio, Speakers Front, Speakers Rear, Integrat...
# 3     Radio, Speakers Front, Speakers Rear, Usb Auxi...
# 4     Cd Player, Radio, Speakers Front, Speakers Rea...
# ...                                                 ...
# 1480  Radio, Speakers Front, Speakers Rear, Integrat...
# 1481  Radio, Speakers Front, Speakers Rear, Integrat...
# 1482  Cd Player, Radio, Audio System Remote Control,...
# 1483  Radio, Speakers Front, Speakers Rear, Usb Auxi...
# 1484  Radio, Speakers Front, Speakers Rear, Integrat...
#
# [1485 rows x 37 columns]

# %%
import pandas as pd
import json

# Function to safely convert JSON strings to dictionaries
def safe_json_loads(x):
    if isinstance(x, str):  # Check if the data is a string
        try:
            # Replace single quotes with double quotes and handle 'None'
            return json.loads(x.replace("'", '"').replace("None", "1"))
        except json.JSONDecodeError:
            # Handle JSON parsing errors
            print(f"Error decoding JSON for: {x}")
            return None
    elif isinstance(x, dict):
        # If already a dictionary, return it as is
        return x
    else:
        # Handle unexpected data types
        print(f"Unexpected data type: {type(x)}")
        return None

# Apply the function to safely transform the data
df['new_car_specs'] = df['new_car_specs'].apply(safe_json_loads)

# Convert the list of dictionaries to a DataFrame
df_new = pd.DataFrame(df['new_car_specs'].tolist())
df_new
# Out:
#              heading                                                top  \
# 0     Specifications  [{'key': 'Mileage', 'value': '18 kmpl'}, {'key...
# 1     Specifications  [{'key': 'Mileage', 'value': '15.29 kmpl'}, {'...
# 2     Specifications  [{'key': 'Mileage', 'value': '12.74 kmpl'}, {'...
# 3     Specifications  [{'key': 'Mileage', 'value': '22.38 kmpl'}, {'...
# 4     Specifications  [{'key': 'Mileage', 'value': '15.29 kmpl'}, {'...
# ...              ...                                                ...
# 1480  Specifications  [{'key': 'Mileage', 'value': '18 kmpl'}, {'key...
# 1481  Specifications  [{'key': 'Mileage', 'value': '18.4 kmpl'}, {'k...
# 1482  Specifications  [{'key': 'Mileage', 'value': '17.01 kmpl'}, {'...
# 1483  Specifications  [{'key': 'Mileage', 'value': '20.5 kmpl'}, {'k...
# 1484  Specifications  [{'key': 'Mileage', 'value': '12.04 kmpl'}, {'...
#
#                                                    data commonIcon
# 0     [{'heading': 'Engine and Transmission', 'subHe...
# 1     [{'heading': 'Engine and Transmission', 'subHe...
# 2     [{'heading': 'Engine and Transmission', 'subHe...
# 3     [{'heading': 'Engine and Transmission', 'subHe...
# 4     [{'heading': 'Engine and Transmission', 'subHe...
# ...                                                 ...        ...
# 1480  [{'heading': 'Engine and Transmission', 'subHe...
# 1481  [{'heading': 'Engine and Transmission', 'subHe...
# 1482  [{'heading': 'Engine and Transmission', 'subHe...
# 1483  [{'heading': 'Engine and Transmission', 'subHe...
# 1484  [{'heading': 'Engine and Transmission', 'subHe...
#
# [1485 rows x 4 columns]

# %%
# Function to extract 'top' key-value pairs and add them as columns
def extract_top(row):
    if isinstance(row['top'], list):
        for item in row['top']:
            row[item['key']] = item['value']
    return row

# Apply the function to the DataFrame
df_new = df_new.apply(extract_top, axis=1)

# Drop the 'top' column after extraction
df_new.drop(columns=['top'], inplace=True)
df_new
# Out:
#        Engine  Max Power     Mileage Seats    Torque Wheel Size commonIcon  \
# 0     1493 CC  113.43bhp     18 kmpl     5     250Nm         17
# 1     1591 CC   121.3bhp  15.29 kmpl     5     151Nm        NaN
# 2     1991 CC     197bhp  12.74 kmpl     5     320nm         19
# 3     1197 CC   88.50bhp  22.38 kmpl     5     113Nm        NaN
# 4     1591 CC   121.3bhp  15.29 kmpl     5     151Nm        NaN
# ...       ...        ...         ...   ...       ...        ...        ...
# 1480  1497 CC   117.6bhp     18 kmpl     5     145Nm         15
# 1481  1197 CC   81.86bhp   18.4 kmpl     5     115Nm        NaN
# 1482  1591 CC   121.3bhp  17.01 kmpl     5   154.9Nm         16
# 1483  1582 CC   126.2bhp   20.5 kmpl     5  259.87NM         17
# 1484  1996 CC  212.55bhp  12.04 kmpl     6   478.5Nm         19
#
#                                                    data         heading
# 0     [{'heading': 'Engine and Transmission', 'subHe...  Specifications
# 1     [{'heading': 'Engine and Transmission', 'subHe...  Specifications
# 2     [{'heading': 'Engine and Transmission', 'subHe...  Specifications
# 3     [{'heading': 'Engine and Transmission', 'subHe...  Specifications
# 4     [{'heading': 'Engine and Transmission', 'subHe...  Specifications
# ...                                                 ...             ...
# 1480  [{'heading': 'Engine and Transmission', 'subHe...  Specifications
# 1481  [{'heading': 'Engine and Transmission', 'subHe...  Specifications
# 1482  [{'heading': 'Engine and Transmission', 'subHe...  Specifications
# 1483  [{'heading': 'Engine and Transmission', 'subHe...  Specifications
# 1484  [{'heading': 'Engine and Transmission', 'subHe...  Specifications
#
# [1485 rows x 9 columns]

# %%
# Function to extract 'data' key-value pairs and add them as columns
def extract_data(row):
    if isinstance(row['data'], list):
        for section in row['data']:
            for item in section['list']:
                row[item['key']] = item['value']
    return row

# Apply the function to the DataFrame
df_new = df_new.apply(extract_data, axis=1)

# Drop the 'data' column after extraction
df_new.drop(columns=['data'], inplace=True)

# %%
df4=df_new

# %%
df4
# Out:
#       Acceleration Alloy Wheel Size      BoreX Stroke Cargo Volumn   Color  \
# 0              NaN               17               NaN          433    Gray
# 1     10.5 Seconds              NaN               NaN   400-litres   White
# 2              NaN               19               NaN   550-litres    Grey
# 3              NaN              NaN               NaN          268  Silver
# 4     10.5 Seconds              NaN               NaN   400-litres   White
# ...            ...              ...               ...          ...     ...
# 1480    10 Seconds               15    73.0 X 89.4 mm          510  Others
# 1481           NaN              NaN               NaN          392  Others
# 1482  10.5 Seconds               16  77.0mm X 85.44mm    465-litre  Others
# 1483       10.83 s               17               NaN          400  Silver
# 1484           NaN               19               NaN          NaN    Grey
#
#      Compression Ratio Displacement Drive Type   Engine  \
# 0                  NaN         1493        FWD  1493 CC
# 1                  NaN         1591        FWD  1591 CC
# 2                  NaN         1991        AWD  1991 CC
# 3                  NaN         1197        NaN  1197 CC
# 4                  NaN         1591        FWD  1591 CC
# ...                ...          ...        ...      ...
# 1480            10.3:1         1497        FWD  1497 CC
# 1481               NaN         1197        FWD  1197 CC
# 1482            10.5;1         1591        FWD  1591 CC
# 1483               NaN         1582        FWD  1582 CC
# 1484               NaN         1996        4x4  1996 CC
#
#                  Engine Type  ... Turbo Charger Turning Radius  \
# 0             1.5 L CRDi VGT  ...           Yes            NaN
# 1         VTVT Petrol Engine  ...            No     5.3 metres
# 2        M 264 petrol engine  ...            No            NaN
# 3          K Series Dual jet  ...           NaN            4.8
# 4         VTVT Petrol Engine  ...            No     5.3 metres
# ...                      ...  ...           ...            ...
# 1480           i VTEC Engine  ...            No     5.3 metres
# 1481        SMARTSTREAM G1.2  ...            No            NaN
# 1482      VTVT Petrol Engine  ...            No     5.2 metres
# 1483      U2 CRDI VGT Engine  ...           Yes     5.3 metres
# 1484  DIESEL 2.0L TWIN TURBO  ...          Twin            NaN
#
#              Tyre Type Value Configuration Values per Cylinder Wheel Base  \
# 0     Tubeless, Radial                 NaN                 4.0     2610mm
# 1             Tubeless                DOHC                 4.0     2590mm
# 2      Tubeless,Radial                 NaN                 4.0     2873mm
# 3     Radial, Tubeless                 NaN                 4.0       2450
# 4             Tubeless                DOHC                 4.0     2590mm
# ...                ...                 ...                 ...        ...
# 1480   Tubeless,Radial                SOHC                 4.0     2600mm
# 1481  Tubeless, Radial                 NaN                 4.0       2500
# 1482   Tubeless,Radial                DOHC                 4.0     2570mm
# 1483          Tubeless                DOHC                 4.0     2590mm
# 1484  Tubeless, Radial                 NaN                 4.0     2950mm
#
#      Wheel Size   Width commonIcon         heading
# 0            17  1800mm             Specifications
# 1           NaN  1780mm             Specifications
# 2            19  1890mm             Specifications
# 3           NaN    1735             Specifications
# 4           NaN  1780mm             Specifications
# ...         ...     ...        ...             ...
# 1480         15  1695mm             Specifications
# 1481        NaN    1790             Specifications
# 1482         16  1700mm             Specifications
# 1483         17  1780mm             Specifications
# 1484         19  1926mm             Specifications
#
# [1485 rows x 42 columns]

# %%
# Concatenate horizontally
df_delhi=pd.concat([dfd, df4], axis=1)

# %%
df_delhi
# Out:
#       it      ft         bt      km transmission  ownerNo      owner  \
# 0      0  Diesel        SUV  10,000    Automatic        1  1st Owner
# 1      0  Petrol        SUV  57,437       Manual        2  2nd Owner
# 2      0  Petrol        SUV   8,000    Automatic        1  1st Owner
# 3      0  Petrol  Hatchback  28,151       Manual        2  2nd Owner
# 4      0  Petrol        SUV  60,000       Manual        1  1st Owner
# ...   ..     ...        ...     ...          ...      ...        ...
# 1480   0  Petrol      Sedan  60,000    Automatic        1  1st Owner
# 1481   0  Petrol        SUV  20,000       Manual        1  1st Owner
# 1482   0  Petrol      Sedan  60,000       Manual        1  1st Owner
# 1483   0  Diesel        SUV  38,000       Manual        1  1st Owner
# 1484   0  Diesel        SUV   7,000    Automatic        0  0th Owner
#
#                 oem              model  modelYear  ...  Turbo Charger  \
# 0               Kia         Kia Seltos       2022  ...            Yes
# 1           Hyundai      Hyundai Creta       2016  ...             No
# 2     Mercedes-Benz  Mercedes-Benz GLC       2020  ...             No
# 3            Maruti       Maruti Swift       2018  ...            NaN
# 4           Hyundai      Hyundai Creta       2017  ...             No
# ...             ...                ...        ...  ...            ...
# 1480          Honda         Honda City       2019  ...             No
# 1481            Kia          Kia Sonet       2021  ...             No
# 1482        Hyundai      Hyundai Verna       2011  ...             No
# 1483        Hyundai      Hyundai Creta       2019  ...            Yes
# 1484             MG         MG Gloster       2023  ...           Twin
#
#      Turning Radius         Tyre Type Value Configuration Values per Cylinder  \
# 0               NaN  Tubeless, Radial                 NaN                 4.0
# 1        5.3 metres          Tubeless                DOHC                 4.0
# 2               NaN   Tubeless,Radial                 NaN                 4.0
# 3               4.8  Radial, Tubeless                 NaN                 4.0
# 4        5.3 metres          Tubeless                DOHC                 4.0
# ...             ...               ...                 ...                 ...
# 1480     5.3 metres   Tubeless,Radial                SOHC                 4.0
# 1481            NaN  Tubeless, Radial                 NaN                 4.0
# 1482     5.2 metres   Tubeless,Radial                DOHC                 4.0
# 1483     5.3 metres          Tubeless                DOHC                 4.0
# 1484            NaN  Tubeless, Radial                 NaN                 4.0
#
#       Wheel Base Wheel Size   Width commonIcon         heading
# 0         2610mm         17  1800mm             Specifications
# 1         2590mm        NaN  1780mm             Specifications
# 2         2873mm         19  1890mm             Specifications
# 3           2450        NaN    1735             Specifications
# 4         2590mm        NaN  1780mm             Specifications
# ...          ...        ...     ...        ...             ...
# 1480      2600mm         15  1695mm             Specifications
# 1481        2500        NaN    1790             Specifications
# 1482      2570mm         16  1700mm             Specifications
# 1483      2590mm         17  1780mm             Specifications
# 1484      2950mm         19  1926mm             Specifications
#
# [1485 rows x 79 columns]

# %%
df5=df["car_links"]

# %%
df_delhi=pd.concat([df_delhi,df5],axis=1)

# %%
df_delhi
# Out:
#       it      ft         bt      km transmission  ownerNo      owner  \
# 0      0  Diesel        SUV  10,000    Automatic        1  1st Owner
# 1      0  Petrol        SUV  57,437       Manual        2  2nd Owner
# 2      0  Petrol        SUV   8,000    Automatic        1  1st Owner
# 3      0  Petrol  Hatchback  28,151       Manual        2  2nd Owner
# 4      0  Petrol        SUV  60,000       Manual        1  1st Owner
# ...   ..     ...        ...     ...          ...      ...        ...
# 1480   0  Petrol      Sedan  60,000    Automatic        1  1st Owner
# 1481   0  Petrol        SUV  20,000       Manual        1  1st Owner
# 1482   0  Petrol      Sedan  60,000       Manual        1  1st Owner
# 1483   0  Diesel        SUV  38,000       Manual        1  1st Owner
# 1484   0  Diesel        SUV   7,000    Automatic        0  0th Owner
#
#                 oem              model  modelYear  ...  Turning Radius  \
# 0               Kia         Kia Seltos       2022  ...             NaN
# 1           Hyundai      Hyundai Creta       2016  ...      5.3 metres
# 2     Mercedes-Benz  Mercedes-Benz GLC       2020  ...             NaN
# 3            Maruti       Maruti Swift       2018  ...             4.8
# 4           Hyundai      Hyundai Creta       2017  ...      5.3 metres
# ...             ...                ...        ...  ...             ...
# 1480          Honda         Honda City       2019  ...      5.3 metres
# 1481            Kia          Kia Sonet       2021  ...             NaN
# 1482        Hyundai      Hyundai Verna       2011  ...      5.2 metres
# 1483        Hyundai      Hyundai Creta       2019  ...      5.3 metres
# 1484             MG         MG Gloster       2023  ...             NaN
#
#              Tyre Type Value Configuration Values per Cylinder Wheel Base  \
# 0     Tubeless, Radial                 NaN                 4.0     2610mm
# 1             Tubeless                DOHC                 4.0     2590mm
# 2      Tubeless,Radial                 NaN                 4.0     2873mm
# 3     Radial, Tubeless                 NaN                 4.0       2450
# 4             Tubeless                DOHC                 4.0     2590mm
# ...                ...                 ...                 ...        ...
# 1480   Tubeless,Radial                SOHC                 4.0     2600mm
# 1481  Tubeless, Radial                 NaN                 4.0       2500
# 1482   Tubeless,Radial                DOHC                 4.0     2570mm
# 1483          Tubeless                DOHC                 4.0     2590mm
# 1484  Tubeless, Radial                 NaN                 4.0     2950mm
#
#       Wheel Size   Width commonIcon         heading  \
# 0             17  1800mm             Specifications
# 1            NaN  1780mm             Specifications
# 2             19  1890mm             Specifications
# 3            NaN    1735             Specifications
# 4            NaN  1780mm             Specifications
# ...          ...     ...        ...             ...
# 1480          15  1695mm             Specifications
# 1481         NaN    1790             Specifications
# 1482          16  1700mm             Specifications
# 1483          17  1780mm             Specifications
# 1484          19  1926mm             Specifications
#
#                                               car_links
# 0     https://www.cardekho.com/used-car-details/used...
# 1     https://www.cardekho.com/buy-used-car-details/...
# 2     https://www.cardekho.com/used-car-details/used...
# 3     https://www.cardekho.com/buy-used-car-details/...
# 4     https://www.cardekho.com/used-car-details/used...
# ...                                                 ...
# 1480  https://www.cardekho.com/used-car-details/used...
# 1481  https://www.cardekho.com/used-car-details/used...
# 1482  https://www.cardekho.com/used-car-details/used...
# 1483  https://www.cardekho.com/used-car-details/used...
# 1484  https://www.cardekho.com/used-car-details/used...
#
# [1485 rows x 80 columns]

# %%
df_delhi["city"]="Delhi"

# %%
df_delhi
# Out:
#       it      ft         bt      km transmission  ownerNo      owner  \
# 0      0  Diesel        SUV  10,000    Automatic        1  1st Owner
# 1      0  Petrol        SUV  57,437       Manual        2  2nd Owner
# 2      0  Petrol        SUV   8,000    Automatic        1  1st Owner
# 3      0  Petrol  Hatchback  28,151       Manual        2  2nd Owner
# 4      0  Petrol        SUV  60,000       Manual        1  1st Owner
# ...   ..     ...        ...     ...          ...      ...        ...
# 1480   0  Petrol      Sedan  60,000    Automatic        1  1st Owner
# 1481   0  Petrol        SUV  20,000       Manual        1  1st Owner
# 1482   0  Petrol      Sedan  60,000       Manual        1  1st Owner
# 1483   0  Diesel        SUV  38,000       Manual        1  1st Owner
# 1484   0  Diesel        SUV   7,000    Automatic        0  0th Owner
#
#                 oem              model  modelYear  ...         Tyre Type  \
# 0               Kia         Kia Seltos       2022  ...  Tubeless, Radial
# 1           Hyundai      Hyundai Creta       2016  ...          Tubeless
# 2     Mercedes-Benz  Mercedes-Benz GLC       2020  ...   Tubeless,Radial
# 3            Maruti       Maruti Swift       2018  ...  Radial, Tubeless
# 4           Hyundai      Hyundai Creta       2017  ...          Tubeless
# ...             ...                ...        ...  ...               ...
# 1480          Honda         Honda City       2019  ...   Tubeless,Radial
# 1481            Kia          Kia Sonet       2021  ...  Tubeless, Radial
# 1482        Hyundai      Hyundai Verna       2011  ...   Tubeless,Radial
# 1483        Hyundai      Hyundai Creta       2019  ...          Tubeless
# 1484             MG         MG Gloster       2023  ...  Tubeless, Radial
#
#      Value Configuration Values per Cylinder Wheel Base Wheel Size   Width  \
# 0                    NaN                 4.0     2610mm         17  1800mm
# 1                   DOHC                 4.0     2590mm        NaN  1780mm
# 2                    NaN                 4.0     2873mm         19  1890mm
# 3                    NaN                 4.0       2450        NaN    1735
# 4                   DOHC                 4.0     2590mm        NaN  1780mm
# ...                  ...                 ...        ...        ...     ...
# 1480                SOHC                 4.0     2600mm         15  1695mm
# 1481                 NaN                 4.0       2500        NaN    1790
# 1482                DOHC                 4.0     2570mm         16  1700mm
# 1483                DOHC                 4.0     2590mm         17  1780mm
# 1484                 NaN                 4.0     2950mm         19  1926mm
#
#      commonIcon         heading  \
# 0                Specifications
# 1                Specifications
# 2                Specifications
# 3                Specifications
# 4                Specifications
# ...         ...             ...
# 1480             Specifications
# 1481             Specifications
# 1482             Specifications
# 1483             Specifications
# 1484             Specifications
#
#                                               car_links   city
# 0     https://www.cardekho.com/used-car-details/used...  Delhi
# 1     https://www.cardekho.com/buy-used-car-details/...  Delhi
# 2     https://www.cardekho.com/used-car-details/used...  Delhi
# 3     https://www.cardekho.com/buy-used-car-details/...  Delhi
# 4     https://www.cardekho.com/used-car-details/used...  Delhi
# ...                                                 ...    ...
# 1480  https://www.cardekho.com/used-car-details/used...  Delhi
# 1481  https://www.cardekho.com/used-car-details/used...  Delhi
# 1482  https://www.cardekho.com/used-car-details/used...  Delhi
# 1483  https://www.cardekho.com/used-car-details/used...  Delhi
# 1484  https://www.cardekho.com/used-car-details/used...  Delhi
#
# [1485 rows x 81 columns]

# %%
path="D:\CHITRA\CARDEHO\\unclean_delhi.csv"
df_delhi.to_csv(path, index=False)
