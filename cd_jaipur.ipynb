# %%
import pandas as pd
import json

# %%
df=pd.read_excel("C:/Users/ASUS/Downloads/jaipur_cars.xlsx")

# %%
df
# Out:
#                                          new_car_detail  \
# 0     {'it': 0, 'ft': 'Diesel', 'bt': 'Hatchback', '...
# 1     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 2     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 3     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 4     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# ...                                                 ...
# 1115  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 1116  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 1117  {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 1118  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 1119  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
#
#                                        new_car_overview  \
# 0     {'heading': 'Car overview', 'top': [{'key': 'R...
# 1     {'heading': 'Car overview', 'top': [{'key': 'R...
# 2     {'heading': 'Car overview', 'top': [{'key': 'R...
# 3     {'heading': 'Car overview', 'top': [{'key': 'R...
# 4     {'heading': 'Car overview', 'top': [{'key': 'R...
# ...                                                 ...
# 1115  {'heading': 'Car overview', 'top': [{'key': 'R...
# 1116  {'heading': 'Car overview', 'top': [{'key': 'R...
# 1117  {'heading': 'Car overview', 'top': [{'key': 'R...
# 1118  {'heading': 'Car overview', 'top': [{'key': 'R...
# 1119  {'heading': 'Car overview', 'top': [{'key': 'R...
#
#                                         new_car_feature  \
# 0     {'heading': 'Features', 'top': [{'value': 'Pow...
# 1     {'heading': 'Features', 'top': [{'value': 'Pow...
# 2     {'heading': 'Features', 'top': [{'value': 'Pow...
# 3     {'heading': 'Features', 'top': [{'value': 'Pow...
# 4     {'heading': 'Features', 'top': [{'value': 'Pow...
# ...                                                 ...
# 1115  {'heading': 'Features', 'top': [{'value': 'Pow...
# 1116  {'heading': 'Features', 'top': [{'value': 'Low...
# 1117  {'heading': 'Features', 'top': [{'value': 'Pow...
# 1118  {'heading': 'Features', 'top': [{'value': 'Low...
# 1119  {'heading': 'Features', 'top': [{'value': 'Pow...
#
#                                           new_car_specs  \
# 0     {'heading': 'Specifications', 'top': [{'key': ...
# 1     {'heading': 'Specifications', 'top': [{'key': ...
# 2     {'heading': 'Specifications', 'top': [{'key': ...
# 3     {'heading': 'Specifications', 'top': [{'key': ...
# 4     {'heading': 'Specifications', 'top': [{'key': ...
# ...                                                 ...
# 1115  {'heading': 'Specifications', 'top': [{'key': ...
# 1116  {'heading': 'Specifications', 'top': [{'key': ...
# 1117  {'heading': 'Specifications', 'top': [{'key': ...
# 1118  {'heading': 'Specifications', 'top': [{'key': ...
# 1119  {'heading': 'Specifications', 'top': [{'key': ...
#
#                                               car_links
# 0     https://www.cardekho.com/used-car-details/used...
# 1     https://www.cardekho.com/buy-used-car-details/...
# 2     https://www.cardekho.com/used-car-details/used...
# 3     https://www.cardekho.com/buy-used-car-details/...
# 4     https://www.cardekho.com/used-car-details/used...
# ...                                                 ...
# 1115  https://www.cardekho.com/used-car-details/used...
# 1116  https://www.cardekho.com/used-car-details/used...
# 1117  https://www.cardekho.com/used-car-details/used...
# 1118  https://www.cardekho.com/used-car-details/used...
# 1119  https://www.cardekho.com/used-car-details/used...
#
# [1120 rows x 5 columns]

# %%
# Function to safely load JSON if it's a string
def safe_load(x):
    if isinstance(x, str):
        return json.loads(x.replace("'", '"').replace("None", "1"))
    return x  # If it's already a dict, return as is

# Apply the safe_load function
df["new_car_detail"] = df["new_car_detail"].apply(safe_load)

# Expand the main dictionary into columns
df_expanded = pd.DataFrame(df["new_car_detail"].to_list())

# Expand the nested dictionary into columns
df_nested_expanded = df_expanded["trendingText"].apply(pd.Series)

# Combine the original and nested DataFrame
df11 = pd.concat([df_expanded.drop(columns=["trendingText"]), df_nested_expanded], axis=1)

# %%
df11
# Out:
#       it      ft         bt        km transmission  ownerNo      owner  \
# 0      0  Diesel  Hatchback  1,20,000       Manual        2  2nd Owner
# 1      0  Petrol  Hatchback    66,951       Manual        1  1st Owner
# 2      0  Petrol  Hatchback    80,000    Automatic        2  2nd Owner
# 3      0  Petrol  Hatchback    44,392       Manual        1  1st Owner
# 4      0  Petrol  Hatchback    40,000    Automatic        1  1st Owner
# ...   ..     ...        ...       ...          ...      ...        ...
# 1115   0  Petrol  Hatchback  1,20,000       Manual        1  1st Owner
# 1116   0  Petrol  Hatchback    70,000       Manual        1  1st Owner
# 1117   0  Petrol        SUV    20,000       Manual        1  1st Owner
# 1118   0  Petrol  Hatchback    40,000       Manual        1  1st Owner
# 1119   0  Petrol  Hatchback    80,000       Manual        1  1st Owner
#
#             oem              model  modelYear  centralVariantId  \
# 0       Hyundai        Hyundai i20       2015              1487
# 1        Maruti       Maruti Swift       2012             10403
# 2        Maruti     Maruti Celerio       2016              3982
# 3       Hyundai  Hyundai Grand i10       2017              5602
# 4        Maruti     Maruti Wagon R       2016              4319
# ...         ...                ...        ...               ...
# 1115  Chevrolet     Chevrolet Beat       2011               438
# 1116     Maruti        Maruti Alto       2007              3917
# 1117    Renault      Renault Kiger       2022              8350
# 1118     Maruti        Maruti Alto       2009              3904
# 1119     Maruti      Maruti Baleno       2018              3962
#
#                variantName        price priceActual priceSaving  \
# 0            Asta 1.4 CRDi  ₹ 5.10 Lakh
# 1                      VXI  ₹ 3.81 Lakh
# 2                   VXI AT  ₹ 3.20 Lakh
# 3     1.2 Kappa Magna BSIV  ₹ 4.20 Lakh
# 4                  AMT VXI  ₹ 3.50 Lakh
# ...                    ...          ...         ...         ...
# 1115                    LT  ₹ 1.08 Lakh
# 1116                   STD  ₹ 1.05 Lakh
# 1117                   RXZ  ₹ 8.50 Lakh
# 1118                   Std     ₹ 1 Lakh
# 1119             1.2 Delta     ₹ 5 Lakh
#
#       priceFixedText                                             imgUrl  \
# 0                  1  https://stimg.cardekho.com/used-cars/common/ic...
# 1                  1  https://stimg.cardekho.com/used-cars/common/ic...
# 2                  1  https://stimg.cardekho.com/used-cars/common/ic...
# 3                  1  https://stimg.cardekho.com/used-cars/common/ic...
# 4                  1  https://stimg.cardekho.com/used-cars/common/ic...
# ...              ...                                                ...
# 1115               1  https://stimg.cardekho.com/used-cars/common/ic...
# 1116               1  https://stimg.cardekho.com/used-cars/common/ic...
# 1117               1  https://stimg.cardekho.com/used-cars/common/ic...
# 1118               1  https://stimg.cardekho.com/used-cars/common/ic...
# 1119               1  https://stimg.cardekho.com/used-cars/common/ic...
#
#             heading                                 desc
# 0     Trending Car!  High chances of sale in next 6 days
# 1     Trending Car!  High chances of sale in next 6 days
# 2     Trending Car!  High chances of sale in next 6 days
# 3     Trending Car!  High chances of sale in next 6 days
# 4     Trending Car!  High chances of sale in next 6 days
# ...             ...                                  ...
# 1115  Trending Car!  High chances of sale in next 6 days
# 1116  Trending Car!  High chances of sale in next 6 days
# 1117  Trending Car!  High chances of sale in next 6 days
# 1118  Trending Car!  High chances of sale in next 6 days
# 1119  Trending Car!  High chances of sale in next 6 days
#
# [1120 rows x 19 columns]

# %%
#overview

# %%
import pandas as pd
import json

# Function to safely load JSON if it's a string
def safe_load(x):
    if isinstance(x, str):
        try:
            return json.loads(x.replace("'", '"').replace("None", "1"))
        except json.JSONDecodeError:
            return None  # Return None if JSON loading fails
    return x  # If it's already a list or dict, return as is

# Apply the safe_load function to the 'new_car_overview' column
df["new_car_overview"] = df["new_car_overview"].apply(safe_load)

# Function to extract key-value pairs from the list of dictionaries
def extract_key_value_pairs(dict_list):
    if isinstance(dict_list, list):  # Check if the item is a list
        extracted_data = {}
        for item in dict_list:
            if isinstance(item, dict):  # Ensure each item is a dictionary
                key = item.get('key')
                value = item.get('value')
                if key:  # Only add if the key exists
                    extracted_data[key] = value
        return pd.Series(extracted_data)
    return pd.Series()  # Return an empty Series if dict_list is not a list

# Expand the 'new_car_overview' column into a new DataFrame
df_expanded = df["new_car_overview"].apply(extract_key_value_pairs)

# %%
def extract_key_value_pairs(dict_list):
    if isinstance(dict_list, list):
        extracted_data = {}
        for item in dict_list:
            if isinstance(item, dict):
                key = item.get('key')
                value = item.get('value')
                if key:  # Only add if the key exists
                    extracted_data[key] = value
        return pd.Series(extracted_data)
    return pd.Series()  # Return an empty Series if dict_list is not a list

# Apply the extraction function to the 'top' column
df2 = df['new_car_overview'].apply(lambda x: x['top'] if isinstance(x, dict) else None).apply(extract_key_value_pairs)

# %%
df2
# Out:
#      Registration Year     Insurance Validity Fuel Type    Seats  \
# 0                 2015  Third Party insurance    Diesel  5 Seats
# 1             Jan 2012            Third Party    Petrol  5 Seats
# 2                 2016  Third Party insurance    Petrol  5 Seats
# 3             Apr 2017  Third Party insurance    Petrol  5 Seats
# 4                 2016  Third Party insurance    Petrol  5 Seats
# ...                ...                    ...       ...      ...
# 1115              2011  Third Party insurance    Petrol  5 Seats
# 1116              2007  Third Party insurance    Petrol  5 Seats
# 1117              2022  Third Party insurance    Petrol  5 Seats
# 1118              2009  Third Party insurance    Petrol  5 Seats
# 1119              2018  Third Party insurance    Petrol  5 Seats
#
#         Kms Driven   RTO     Ownership Engine Displacement Transmission  \
# 0     1,20,000 Kms  RJ13  Second Owner             1396 cc       Manual
# 1       66,951 Kms  RJ14   First Owner             1197 cc       Manual
# 2       80,000 Kms  RJ14  Second Owner              998 cc    Automatic
# 3       44,392 Kms  RJ14   First Owner             1197 cc       Manual
# 4       40,000 Kms  RJ14   First Owner              998 cc    Automatic
# ...            ...   ...           ...                 ...          ...
# 1115  1,20,000 Kms  RJ14   First Owner             1199 cc       Manual
# 1116    70,000 Kms  RJ30   First Owner              796 cc       Manual
# 1117    20,000 Kms  RJ45   First Owner              999 cc       Manual
# 1118    40,000 Kms   NaN   First Owner              796 cc       Manual
# 1119    80,000 Kms  UP82   First Owner             1197 cc       Manual
#
#       Year of Manufacture
# 0                  2015.0
# 1                  2012.0
# 2                  2016.0
# 3                  2017.0
# 4                  2016.0
# ...                   ...
# 1115               2011.0
# 1116               2007.0
# 1117               2022.0
# 1118               2009.0
# 1119               2018.0
#
# [1120 rows x 10 columns]

# %%
# Concatenate horizontally
dfj= pd.concat([df11, df2], axis=1)

# %%
#features

# %%
df.new_car_feature=df["new_car_feature"].apply(lambda x:json.loads(x.replace("'",'"').replace("None","1")))
df_new=pd.DataFrame(df.new_car_feature.to_list())

# %%
df_new
# Out:
#        heading                                                top  \
# 0     Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 1     Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 2     Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 3     Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 4     Features  [{'value': 'Power Steering'}, {'value': 'Power...
# ...        ...                                                ...
# 1115  Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 1116  Features  [{'value': 'Low Fuel Warning Light'}, {'value'...
# 1117  Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 1118  Features  [{'value': 'Low Fuel Warning Light'}, {'value'...
# 1119  Features  [{'value': 'Power Steering'}, {'value': 'Power...
#
#                                                    data  \
# 0     [{'heading': 'Comfort & Convenience', 'subHead...
# 1     [{'heading': 'Comfort & Convenience', 'subHead...
# 2     [{'heading': 'Comfort & Convenience', 'subHead...
# 3     [{'heading': 'Comfort & Convenience', 'subHead...
# 4     [{'heading': 'Comfort & Convenience', 'subHead...
# ...                                                 ...
# 1115  [{'heading': 'Comfort & Convenience', 'subHead...
# 1116  [{'heading': 'Comfort & Convenience', 'subHead...
# 1117  [{'heading': 'Comfort & Convenience', 'subHead...
# 1118  [{'heading': 'Comfort & Convenience', 'subHead...
# 1119  [{'heading': 'Comfort & Convenience', 'subHead...
#
#                                              commonIcon
# 0     https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1     https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 2     https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 3     https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 4     https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# ...                                                 ...
# 1115  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1116  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1117  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1118  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1119  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
#
# [1120 rows x 4 columns]

# %%
import pandas as pd
import numpy as np


# Ensure 'top' column contains lists; replace non-lists with empty lists
df_new['top'] = df_new['top'].apply(lambda x: x if isinstance(x, list) else [])

# Extract feature values and concatenate them into a single string per row
df_new['Features'] = df_new['top'].apply(lambda x: ', '.join([item['value'] for item in x]))

# Drop the original 'top' column if no longer needed
df_new = df_new.drop(columns=['top'])

df_new
# Out:
#        heading                                               data  \
# 0     Features  [{'heading': 'Comfort & Convenience', 'subHead...
# 1     Features  [{'heading': 'Comfort & Convenience', 'subHead...
# 2     Features  [{'heading': 'Comfort & Convenience', 'subHead...
# 3     Features  [{'heading': 'Comfort & Convenience', 'subHead...
# 4     Features  [{'heading': 'Comfort & Convenience', 'subHead...
# ...        ...                                                ...
# 1115  Features  [{'heading': 'Comfort & Convenience', 'subHead...
# 1116  Features  [{'heading': 'Comfort & Convenience', 'subHead...
# 1117  Features  [{'heading': 'Comfort & Convenience', 'subHead...
# 1118  Features  [{'heading': 'Comfort & Convenience', 'subHead...
# 1119  Features  [{'heading': 'Comfort & Convenience', 'subHead...
#
#                                              commonIcon  \
# 0     https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1     https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 2     https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 3     https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 4     https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# ...                                                 ...
# 1115  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1116  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1117  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1118  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1119  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
#
#                                                Features
# 0     Power Steering, Power Windows Front, Air Condi...
# 1     Power Steering, Power Windows Front, Air Condi...
# 2     Power Steering, Power Windows Front, Air Condi...
# 3     Power Steering, Power Windows Front, Air Condi...
# 4     Power Steering, Power Windows Front, Air Condi...
# ...                                                 ...
# 1115  Power Steering, Power Windows Front, Air Condi...
# 1116  Low Fuel Warning Light, Electronic Multi Tripm...
# 1117  Power Steering, Power Windows Front, Air Condi...
# 1118  Low Fuel Warning Light, Electronic Multi Tripm...
# 1119  Power Steering, Power Windows Front, Air Condi...
#
# [1120 rows x 4 columns]

# %%
# Function to extract features and create columns
def extract_features(data):
    features_dict = {}
    for category in data:
        sub_heading = category['subHeading']
        features = [item['value'] for item in category['list']]
        features_dict[sub_heading] = ', '.join(features)
    return features_dict

# Apply the function to the 'data' column and convert to DataFrame
features_df = pd.json_normalize(df_new['data'].apply(extract_features))

# Concatenate with the original DataFrame if needed
df3 = pd.concat([df_new.drop(columns=['data']), features_df], axis=1)

# %%
df3
# Out:
#        heading                                         commonIcon  \
# 0     Features  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1     Features  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 2     Features  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 3     Features  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 4     Features  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# ...        ...                                                ...
# 1115  Features  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1116  Features  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1117  Features  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1118  Features  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1119  Features  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
#
#                                                Features  \
# 0     Power Steering, Power Windows Front, Air Condi...
# 1     Power Steering, Power Windows Front, Air Condi...
# 2     Power Steering, Power Windows Front, Air Condi...
# 3     Power Steering, Power Windows Front, Air Condi...
# 4     Power Steering, Power Windows Front, Air Condi...
# ...                                                 ...
# 1115  Power Steering, Power Windows Front, Air Condi...
# 1116  Low Fuel Warning Light, Electronic Multi Tripm...
# 1117  Power Steering, Power Windows Front, Air Condi...
# 1118  Low Fuel Warning Light, Electronic Multi Tripm...
# 1119  Power Steering, Power Windows Front, Air Condi...
#
#                                                 Comfort  \
# 0     Power Steering, Power Windows Front, Power Win...
# 1     Power Steering, Power Windows Front, Power Win...
# 2     Power Steering, Power Windows Front, Power Win...
# 3     Power Steering, Power Windows Front, Power Win...
# 4     Power Steering, Power Windows Front, Power Win...
# ...                                                 ...
# 1115  Power Steering, Power Windows Front, Power Win...
# 1116                             Low Fuel Warning Light
# 1117  Power Steering, Power Windows Front, Power Win...
# 1118                             Low Fuel Warning Light
# 1119  Power Steering, Power Windows Front, Power Win...
#
#                                                Interior  \
# 0     Air Conditioner, Heater, Adjustable Steering, ...
# 1     Air Conditioner, Heater, Adjustable Steering, ...
# 2     Air Conditioner, Heater, Digital Odometer, Tac...
# 3     Air Conditioner, Heater, Digital Odometer, Tac...
# 4     Air Conditioner, Heater, Adjustable Steering, ...
# ...                                                 ...
# 1115  Air Conditioner, Heater, Adjustable Steering, ...
# 1116      Electronic Multi Tripmeter, Glove Compartment
# 1117  Air Conditioner, Heater, Adjustable Steering, ...
# 1118      Electronic Multi Tripmeter, Glove Compartment
# 1119  Air Conditioner, Heater, Adjustable Steering, ...
#
#                                                Exterior  \
# 0     Adjustable Head Lights, Fog Lights Front, Powe...
# 1     Adjustable Head Lights, Power Adjustable Exter...
# 2     Adjustable Head Lights, Manually Adjustable Ex...
# 3     Adjustable Head Lights, Power Adjustable Exter...
# 4     Adjustable Head Lights, Fog Lights Front, Powe...
# ...                                                 ...
# 1115  Fog Lights Front, Manually Adjustable Exterior...
# 1116      Manually Adjustable Exterior Rear View Mirror
# 1117  Adjustable Head Lights, Power Adjustable Exter...
# 1118      Manually Adjustable Exterior Rear View Mirror
# 1119  Adjustable Head Lights, Power Adjustable Exter...
#
#                                                  Safety  \
# 0     Anti Lock Braking System, Centeral Locking, Po...
# 1     Anti Lock Braking System, Brake Assist, Center...
# 2     Centeral Locking, Child Safety Locks, Day Nigh...
# 3     Anti Lock Braking System, Centeral Locking, Po...
# 4     Centeral Locking, Power Door Locks, Child Safe...
# ...                                                 ...
# 1115  Centeral Locking, Day Night Rear View Mirror, ...
# 1116  Brake Assist, Halogen Headlamps, Rear Seat Bel...
# 1117  Anti Lock Braking System, Centeral Locking, Po...
# 1118  Brake Assist, Halogen Headlamps, Rear Seat Bel...
# 1119  Anti Lock Braking System, Centeral Locking, Po...
#
#                                           Entertainment
# 0     Cd Player, Radio, Speakers Front, Speakers Rea...
# 1     Radio, Speakers Front, Speakers Rear, Usb Auxi...
# 2                                                   NaN
# 3     Speakers Front, Speakers Rear, Integrated2Din ...
# 4     Cd Player, Radio, Speakers Front, Speakers Rea...
# ...                                                 ...
# 1115    Cd Player, Radio, Speakers Front, Speakers Rear
# 1116                                                NaN
# 1117  Radio, Speakers Front, Speakers Rear, Integrat...
# 1118                     Usb Auxiliary Input, Bluetooth
# 1119  Cd Player, Radio, Speakers Front, Speakers Rea...
#
# [1120 rows x 8 columns]

# %%
# Concatenate horizontally
# Concatenate horizontally
dfj=pd.concat([dfj, df3], axis=1)

# %%
dfj
# Out:
#       it      ft         bt        km transmission  ownerNo      owner  \
# 0      0  Diesel  Hatchback  1,20,000       Manual        2  2nd Owner
# 1      0  Petrol  Hatchback    66,951       Manual        1  1st Owner
# 2      0  Petrol  Hatchback    80,000    Automatic        2  2nd Owner
# 3      0  Petrol  Hatchback    44,392       Manual        1  1st Owner
# 4      0  Petrol  Hatchback    40,000    Automatic        1  1st Owner
# ...   ..     ...        ...       ...          ...      ...        ...
# 1115   0  Petrol  Hatchback  1,20,000       Manual        1  1st Owner
# 1116   0  Petrol  Hatchback    70,000       Manual        1  1st Owner
# 1117   0  Petrol        SUV    20,000       Manual        1  1st Owner
# 1118   0  Petrol  Hatchback    40,000       Manual        1  1st Owner
# 1119   0  Petrol  Hatchback    80,000       Manual        1  1st Owner
#
#             oem              model  modelYear  ...  Transmission  \
# 0       Hyundai        Hyundai i20       2015  ...        Manual
# 1        Maruti       Maruti Swift       2012  ...        Manual
# 2        Maruti     Maruti Celerio       2016  ...     Automatic
# 3       Hyundai  Hyundai Grand i10       2017  ...        Manual
# 4        Maruti     Maruti Wagon R       2016  ...     Automatic
# ...         ...                ...        ...  ...           ...
# 1115  Chevrolet     Chevrolet Beat       2011  ...        Manual
# 1116     Maruti        Maruti Alto       2007  ...        Manual
# 1117    Renault      Renault Kiger       2022  ...        Manual
# 1118     Maruti        Maruti Alto       2009  ...        Manual
# 1119     Maruti      Maruti Baleno       2018  ...        Manual
#
#      Year of Manufacture   heading  \
# 0                 2015.0  Features
# 1                 2012.0  Features
# 2                 2016.0  Features
# 3                 2017.0  Features
# 4                 2016.0  Features
# ...                  ...       ...
# 1115              2011.0  Features
# 1116              2007.0  Features
# 1117              2022.0  Features
# 1118              2009.0  Features
# 1119              2018.0  Features
#
#                                              commonIcon  \
# 0     https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1     https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 2     https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 3     https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 4     https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# ...                                                 ...
# 1115  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1116  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1117  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1118  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1119  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
#
#                                                Features  \
# 0     Power Steering, Power Windows Front, Air Condi...
# 1     Power Steering, Power Windows Front, Air Condi...
# 2     Power Steering, Power Windows Front, Air Condi...
# 3     Power Steering, Power Windows Front, Air Condi...
# 4     Power Steering, Power Windows Front, Air Condi...
# ...                                                 ...
# 1115  Power Steering, Power Windows Front, Air Condi...
# 1116  Low Fuel Warning Light, Electronic Multi Tripm...
# 1117  Power Steering, Power Windows Front, Air Condi...
# 1118  Low Fuel Warning Light, Electronic Multi Tripm...
# 1119  Power Steering, Power Windows Front, Air Condi...
#
#                                                 Comfort  \
# 0     Power Steering, Power Windows Front, Power Win...
# 1     Power Steering, Power Windows Front, Power Win...
# 2     Power Steering, Power Windows Front, Power Win...
# 3     Power Steering, Power Windows Front, Power Win...
# 4     Power Steering, Power Windows Front, Power Win...
# ...                                                 ...
# 1115  Power Steering, Power Windows Front, Power Win...
# 1116                             Low Fuel Warning Light
# 1117  Power Steering, Power Windows Front, Power Win...
# 1118                             Low Fuel Warning Light
# 1119  Power Steering, Power Windows Front, Power Win...
#
#                                                Interior  \
# 0     Air Conditioner, Heater, Adjustable Steering, ...
# 1     Air Conditioner, Heater, Adjustable Steering, ...
# 2     Air Conditioner, Heater, Digital Odometer, Tac...
# 3     Air Conditioner, Heater, Digital Odometer, Tac...
# 4     Air Conditioner, Heater, Adjustable Steering, ...
# ...                                                 ...
# 1115  Air Conditioner, Heater, Adjustable Steering, ...
# 1116      Electronic Multi Tripmeter, Glove Compartment
# 1117  Air Conditioner, Heater, Adjustable Steering, ...
# 1118      Electronic Multi Tripmeter, Glove Compartment
# 1119  Air Conditioner, Heater, Adjustable Steering, ...
#
#                                                Exterior  \
# 0     Adjustable Head Lights, Fog Lights Front, Powe...
# 1     Adjustable Head Lights, Power Adjustable Exter...
# 2     Adjustable Head Lights, Manually Adjustable Ex...
# 3     Adjustable Head Lights, Power Adjustable Exter...
# 4     Adjustable Head Lights, Fog Lights Front, Powe...
# ...                                                 ...
# 1115  Fog Lights Front, Manually Adjustable Exterior...
# 1116      Manually Adjustable Exterior Rear View Mirror
# 1117  Adjustable Head Lights, Power Adjustable Exter...
# 1118      Manually Adjustable Exterior Rear View Mirror
# 1119  Adjustable Head Lights, Power Adjustable Exter...
#
#                                                  Safety  \
# 0     Anti Lock Braking System, Centeral Locking, Po...
# 1     Anti Lock Braking System, Brake Assist, Center...
# 2     Centeral Locking, Child Safety Locks, Day Nigh...
# 3     Anti Lock Braking System, Centeral Locking, Po...
# 4     Centeral Locking, Power Door Locks, Child Safe...
# ...                                                 ...
# 1115  Centeral Locking, Day Night Rear View Mirror, ...
# 1116  Brake Assist, Halogen Headlamps, Rear Seat Bel...
# 1117  Anti Lock Braking System, Centeral Locking, Po...
# 1118  Brake Assist, Halogen Headlamps, Rear Seat Bel...
# 1119  Anti Lock Braking System, Centeral Locking, Po...
#
#                                           Entertainment
# 0     Cd Player, Radio, Speakers Front, Speakers Rea...
# 1     Radio, Speakers Front, Speakers Rear, Usb Auxi...
# 2                                                   NaN
# 3     Speakers Front, Speakers Rear, Integrated2Din ...
# 4     Cd Player, Radio, Speakers Front, Speakers Rea...
# ...                                                 ...
# 1115    Cd Player, Radio, Speakers Front, Speakers Rear
# 1116                                                NaN
# 1117  Radio, Speakers Front, Speakers Rear, Integrat...
# 1118                     Usb Auxiliary Input, Bluetooth
# 1119  Cd Player, Radio, Speakers Front, Speakers Rea...
#
# [1120 rows x 37 columns]

# %%
#specification

# %%
import pandas as pd
import json

# Function to safely convert JSON strings to dictionaries
def safe_json_loads(x):
    if isinstance(x, str):  # Check if the data is a string
        try:
            # Replace single quotes with double quotes and handle 'None'
            return json.loads(x.replace("'", '"').replace("None", "1"))
        except json.JSONDecodeError:
            # Handle JSON parsing errors
            print(f"Error decoding JSON for: {x}")
            return None
    elif isinstance(x, dict):
        # If already a dictionary, return it as is
        return x
    else:
        # Handle unexpected data types
        print(f"Unexpected data type: {type(x)}")
        return None

# Apply the function to safely transform the data
df['new_car_specs'] = df['new_car_specs'].apply(safe_json_loads)

# Convert the list of dictionaries to a DataFrame
df_new = pd.DataFrame(df['new_car_specs'].tolist())
df_new
# Out:
#              heading                                                top  \
# 0     Specifications  [{'key': 'Mileage', 'value': '22.54 kmpl'}, {'...
# 1     Specifications  [{'key': 'Mileage', 'value': '22.38 kmpl'}, {'...
# 2     Specifications  [{'key': 'Mileage', 'value': '23.1 kmpl'}, {'k...
# 3     Specifications  [{'key': 'Mileage', 'value': '18.9 kmpl'}, {'k...
# 4     Specifications  [{'key': 'Mileage', 'value': '20.51 kmpl'}, {'...
# ...              ...                                                ...
# 1115  Specifications  [{'key': 'Mileage', 'value': '18.6 kmpl'}, {'k...
# 1116  Specifications  [{'key': 'Mileage', 'value': '19.7 kmpl'}, {'k...
# 1117  Specifications  [{'key': 'Mileage', 'value': '19.17 kmpl'}, {'...
# 1118  Specifications  [{'key': 'Mileage', 'value': '19.7 kmpl'}, {'k...
# 1119  Specifications  [{'key': 'Mileage', 'value': '21.4 kmpl'}, {'k...
#
#                                                    data commonIcon
# 0     [{'heading': 'Engine and Transmission', 'subHe...
# 1     [{'heading': 'Engine and Transmission', 'subHe...
# 2     [{'heading': 'Engine and Transmission', 'subHe...
# 3     [{'heading': 'Engine and Transmission', 'subHe...
# 4     [{'heading': 'Engine and Transmission', 'subHe...
# ...                                                 ...        ...
# 1115  [{'heading': 'Engine and Transmission', 'subHe...
# 1116  [{'heading': 'Engine and Transmission', 'subHe...
# 1117  [{'heading': 'Engine and Transmission', 'subHe...
# 1118  [{'heading': 'Engine and Transmission', 'subHe...
# 1119  [{'heading': 'Engine and Transmission', 'subHe...
#
# [1120 rows x 4 columns]

# %%
# Function to extract 'top' key-value pairs and add them as columns
def extract_top(row):
    if isinstance(row['top'], list):
        for item in row['top']:
            row[item['key']] = item['value']
    return row

# Apply the function to the DataFrame
df_new = df_new.apply(extract_top, axis=1)

# Drop the 'top' column after extraction
df_new.drop(columns=['top'], inplace=True)
df_new
# Out:
#        Engine Max Power     Mileage Seats    Torque Wheel Size commonIcon  \
# 0     1396 CC  88.73bhp  22.54 kmpl     5   219.7Nm         16
# 1     1197 CC  88.50bhp  22.38 kmpl     5     113Nm        NaN
# 2      998 CC  67.04bhp   23.1 kmpl     5      90Nm        NaN
# 3     1197 CC  81.86bhp   18.9 kmpl     5  113.75nm        NaN
# 4      998 CC     67bhp  20.51 kmpl     5      90Nm        NaN
# ...       ...       ...         ...   ...       ...        ...        ...
# 1115  1199 CC   79.4bhp   18.6 kmpl     5     108Nm         14
# 1116   796 CC   46.3bhp   19.7 kmpl     5      62Nm         12
# 1117   999 CC  71.01bhp  19.17 kmpl     5      96Nm         16
# 1118   796 CC   46.3bhp   19.7 kmpl     5      62Nm         12
# 1119  1197 CC   83.1bhp   21.4 kmpl     5     115Nm        NaN
#
#                                                    data         heading
# 0     [{'heading': 'Engine and Transmission', 'subHe...  Specifications
# 1     [{'heading': 'Engine and Transmission', 'subHe...  Specifications
# 2     [{'heading': 'Engine and Transmission', 'subHe...  Specifications
# 3     [{'heading': 'Engine and Transmission', 'subHe...  Specifications
# 4     [{'heading': 'Engine and Transmission', 'subHe...  Specifications
# ...                                                 ...             ...
# 1115  [{'heading': 'Engine and Transmission', 'subHe...  Specifications
# 1116  [{'heading': 'Engine and Transmission', 'subHe...  Specifications
# 1117  [{'heading': 'Engine and Transmission', 'subHe...  Specifications
# 1118  [{'heading': 'Engine and Transmission', 'subHe...  Specifications
# 1119  [{'heading': 'Engine and Transmission', 'subHe...  Specifications
#
# [1120 rows x 9 columns]

# %%
# Function to extract 'data' key-value pairs and add them as columns
def extract_data(row):
    if isinstance(row['data'], list):
        for section in row['data']:
            for item in section['list']:
                row[item['key']] = item['value']
    return row

# Apply the function to the DataFrame
df_new = df_new.apply(extract_data, axis=1)

# Drop the 'data' column after extraction
df_new.drop(columns=['data'], inplace=True)

# %%
df4=df_new

# %%
df4
# Out:
#        Acceleration Alloy Wheel Size    BoreX Stroke Cargo Volumn   Color  \
# 0      11.9 Seconds               16             NaN   295-litres  Others
# 1               NaN              NaN             NaN          268   White
# 2     15.05 Seconds              NaN      73 X 82 mm   235-litres  Others
# 3      12.9 Seconds              NaN             NaN          256  Silver
# 4      18.6 Seconds              NaN      69 x 72 mm   180-liters  Silver
# ...             ...              ...             ...          ...     ...
# 1115            NaN               14             NaN   170-litres  Others
# 1116   17.7 seconds               12  68.5 x 72.0 mm          NaN  Others
# 1117            NaN               16             NaN          405  Others
# 1118   17.7 seconds               12  68.5 x 72.0 mm          NaN  Others
# 1119  12.36 seconds              NaN             NaN   339-litres  Others
#
#      Compression Ratio Displacement Drive Type   Engine  \
# 0                  NaN         1396        FWD  1396 CC
# 1                  NaN         1197        NaN  1197 CC
# 2               11.0:1          998        FWD   998 CC
# 3                  NaN         1197        FWD  1197 CC
# 4                  NaN          998        FWD   998 CC
# ...                ...          ...        ...      ...
# 1115               NaN         1199        FWD  1199 CC
# 1116               NaN          796        2WD   796 CC
# 1117               NaN          999        NaN   999 CC
# 1118               NaN          796        2WD   796 CC
# 1119               NaN         1197        FWD  1197 CC
#
#                    Engine Type  ... Turbo Charger Turning Radius  \
# 0        U2 CRDI Diesel Engine  ...           Yes     5.2 metres
# 1            K Series Dual jet  ...           NaN            4.8
# 2                  K10B Engine  ...            No     4.7 metres
# 3     Kappa VTVT Petrol Engine  ...            No     4.8 metres
# 4           K10B Petrol Engine  ...            No     4.6 metres
# ...                        ...  ...           ...            ...
# 1115           Smartech Engine  ...            No     4.85metres
# 1116            In-Line Engine  ...            No           4.6m
# 1117               1.0L energy  ...           NaN            NaN
# 1118            In-Line Engine  ...            No           4.6m
# 1119         VVT Petrol Engine  ...            No     4.9 meters
#
#              Tyre Type Value Configuration Values per Cylinder Wheel Base  \
# 0             Tubeless                DOHC                 4.0     2570mm
# 1     Radial, Tubeless                 NaN                 4.0       2450
# 2     Tubeless, Radial                DOHC                 4.0     2425mm
# 3             Tubeless                DOHC                 4.0     2425mm
# 4       Tubeless Tyres                DOHC                 4.0     2400mm
# ...                ...                 ...                 ...        ...
# 1115   Tubeless,Radial                DOHC                 4.0     2375mm
# 1116   Tubeless,Radial                SOHC                 4.0     2360mm
# 1117  Tubeless, Radial                 NaN                 4.0       2500
# 1118   Tubeless,Radial                SOHC                 4.0     2360mm
# 1119   Tubeless,Radial                DOHC                 4.0     2520mm
#
#      Wheel Size   Width commonIcon         heading
# 0            16  1734mm             Specifications
# 1           NaN    1735             Specifications
# 2           NaN  1635mm             Specifications
# 3           NaN  1660mm             Specifications
# 4           NaN  1495mm             Specifications
# ...         ...     ...        ...             ...
# 1115         14  1595mm             Specifications
# 1116         12  1475mm             Specifications
# 1117         16    1750             Specifications
# 1118         12  1475mm             Specifications
# 1119        NaN  1745mm             Specifications
#
# [1120 rows x 42 columns]

# %%
# Concatenate horizontally
df_jaipur=pd.concat([dfj, df4], axis=1)

# %%
df_jaipur
# Out:
#       it      ft         bt        km transmission  ownerNo      owner  \
# 0      0  Diesel  Hatchback  1,20,000       Manual        2  2nd Owner
# 1      0  Petrol  Hatchback    66,951       Manual        1  1st Owner
# 2      0  Petrol  Hatchback    80,000    Automatic        2  2nd Owner
# 3      0  Petrol  Hatchback    44,392       Manual        1  1st Owner
# 4      0  Petrol  Hatchback    40,000    Automatic        1  1st Owner
# ...   ..     ...        ...       ...          ...      ...        ...
# 1115   0  Petrol  Hatchback  1,20,000       Manual        1  1st Owner
# 1116   0  Petrol  Hatchback    70,000       Manual        1  1st Owner
# 1117   0  Petrol        SUV    20,000       Manual        1  1st Owner
# 1118   0  Petrol  Hatchback    40,000       Manual        1  1st Owner
# 1119   0  Petrol  Hatchback    80,000       Manual        1  1st Owner
#
#             oem              model  modelYear  ...  Turbo Charger  \
# 0       Hyundai        Hyundai i20       2015  ...            Yes
# 1        Maruti       Maruti Swift       2012  ...            NaN
# 2        Maruti     Maruti Celerio       2016  ...             No
# 3       Hyundai  Hyundai Grand i10       2017  ...             No
# 4        Maruti     Maruti Wagon R       2016  ...             No
# ...         ...                ...        ...  ...            ...
# 1115  Chevrolet     Chevrolet Beat       2011  ...             No
# 1116     Maruti        Maruti Alto       2007  ...             No
# 1117    Renault      Renault Kiger       2022  ...            NaN
# 1118     Maruti        Maruti Alto       2009  ...             No
# 1119     Maruti      Maruti Baleno       2018  ...             No
#
#      Turning Radius         Tyre Type Value Configuration Values per Cylinder  \
# 0        5.2 metres          Tubeless                DOHC                 4.0
# 1               4.8  Radial, Tubeless                 NaN                 4.0
# 2        4.7 metres  Tubeless, Radial                DOHC                 4.0
# 3        4.8 metres          Tubeless                DOHC                 4.0
# 4        4.6 metres    Tubeless Tyres                DOHC                 4.0
# ...             ...               ...                 ...                 ...
# 1115     4.85metres   Tubeless,Radial                DOHC                 4.0
# 1116           4.6m   Tubeless,Radial                SOHC                 4.0
# 1117            NaN  Tubeless, Radial                 NaN                 4.0
# 1118           4.6m   Tubeless,Radial                SOHC                 4.0
# 1119     4.9 meters   Tubeless,Radial                DOHC                 4.0
#
#       Wheel Base Wheel Size   Width commonIcon         heading
# 0         2570mm         16  1734mm             Specifications
# 1           2450        NaN    1735             Specifications
# 2         2425mm        NaN  1635mm             Specifications
# 3         2425mm        NaN  1660mm             Specifications
# 4         2400mm        NaN  1495mm             Specifications
# ...          ...        ...     ...        ...             ...
# 1115      2375mm         14  1595mm             Specifications
# 1116      2360mm         12  1475mm             Specifications
# 1117        2500         16    1750             Specifications
# 1118      2360mm         12  1475mm             Specifications
# 1119      2520mm        NaN  1745mm             Specifications
#
# [1120 rows x 79 columns]

# %%
df5=df["car_links"]

# %%
df_jaipur=pd.concat([df_jaipur,df5],axis=1)

# %%
df_jaipur
# Out:
#       it      ft         bt        km transmission  ownerNo      owner  \
# 0      0  Diesel  Hatchback  1,20,000       Manual        2  2nd Owner
# 1      0  Petrol  Hatchback    66,951       Manual        1  1st Owner
# 2      0  Petrol  Hatchback    80,000    Automatic        2  2nd Owner
# 3      0  Petrol  Hatchback    44,392       Manual        1  1st Owner
# 4      0  Petrol  Hatchback    40,000    Automatic        1  1st Owner
# ...   ..     ...        ...       ...          ...      ...        ...
# 1115   0  Petrol  Hatchback  1,20,000       Manual        1  1st Owner
# 1116   0  Petrol  Hatchback    70,000       Manual        1  1st Owner
# 1117   0  Petrol        SUV    20,000       Manual        1  1st Owner
# 1118   0  Petrol  Hatchback    40,000       Manual        1  1st Owner
# 1119   0  Petrol  Hatchback    80,000       Manual        1  1st Owner
#
#             oem              model  modelYear  ...  Turning Radius  \
# 0       Hyundai        Hyundai i20       2015  ...      5.2 metres
# 1        Maruti       Maruti Swift       2012  ...             4.8
# 2        Maruti     Maruti Celerio       2016  ...      4.7 metres
# 3       Hyundai  Hyundai Grand i10       2017  ...      4.8 metres
# 4        Maruti     Maruti Wagon R       2016  ...      4.6 metres
# ...         ...                ...        ...  ...             ...
# 1115  Chevrolet     Chevrolet Beat       2011  ...      4.85metres
# 1116     Maruti        Maruti Alto       2007  ...            4.6m
# 1117    Renault      Renault Kiger       2022  ...             NaN
# 1118     Maruti        Maruti Alto       2009  ...            4.6m
# 1119     Maruti      Maruti Baleno       2018  ...      4.9 meters
#
#              Tyre Type Value Configuration Values per Cylinder Wheel Base  \
# 0             Tubeless                DOHC                 4.0     2570mm
# 1     Radial, Tubeless                 NaN                 4.0       2450
# 2     Tubeless, Radial                DOHC                 4.0     2425mm
# 3             Tubeless                DOHC                 4.0     2425mm
# 4       Tubeless Tyres                DOHC                 4.0     2400mm
# ...                ...                 ...                 ...        ...
# 1115   Tubeless,Radial                DOHC                 4.0     2375mm
# 1116   Tubeless,Radial                SOHC                 4.0     2360mm
# 1117  Tubeless, Radial                 NaN                 4.0       2500
# 1118   Tubeless,Radial                SOHC                 4.0     2360mm
# 1119   Tubeless,Radial                DOHC                 4.0     2520mm
#
#       Wheel Size   Width commonIcon         heading  \
# 0             16  1734mm             Specifications
# 1            NaN    1735             Specifications
# 2            NaN  1635mm             Specifications
# 3            NaN  1660mm             Specifications
# 4            NaN  1495mm             Specifications
# ...          ...     ...        ...             ...
# 1115          14  1595mm             Specifications
# 1116          12  1475mm             Specifications
# 1117          16    1750             Specifications
# 1118          12  1475mm             Specifications
# 1119         NaN  1745mm             Specifications
#
#                                               car_links
# 0     https://www.cardekho.com/used-car-details/used...
# 1     https://www.cardekho.com/buy-used-car-details/...
# 2     https://www.cardekho.com/used-car-details/used...
# 3     https://www.cardekho.com/buy-used-car-details/...
# 4     https://www.cardekho.com/used-car-details/used...
# ...                                                 ...
# 1115  https://www.cardekho.com/used-car-details/used...
# 1116  https://www.cardekho.com/used-car-details/used...
# 1117  https://www.cardekho.com/used-car-details/used...
# 1118  https://www.cardekho.com/used-car-details/used...
# 1119  https://www.cardekho.com/used-car-details/used...
#
# [1120 rows x 80 columns]

# %%
df_jaipur["city"]="Jaipur"

# %%
df_jaipur
# Out:
#       it      ft         bt        km transmission  ownerNo      owner  \
# 0      0  Diesel  Hatchback  1,20,000       Manual        2  2nd Owner
# 1      0  Petrol  Hatchback    66,951       Manual        1  1st Owner
# 2      0  Petrol  Hatchback    80,000    Automatic        2  2nd Owner
# 3      0  Petrol  Hatchback    44,392       Manual        1  1st Owner
# 4      0  Petrol  Hatchback    40,000    Automatic        1  1st Owner
# ...   ..     ...        ...       ...          ...      ...        ...
# 1115   0  Petrol  Hatchback  1,20,000       Manual        1  1st Owner
# 1116   0  Petrol  Hatchback    70,000       Manual        1  1st Owner
# 1117   0  Petrol        SUV    20,000       Manual        1  1st Owner
# 1118   0  Petrol  Hatchback    40,000       Manual        1  1st Owner
# 1119   0  Petrol  Hatchback    80,000       Manual        1  1st Owner
#
#             oem              model  modelYear  ...         Tyre Type  \
# 0       Hyundai        Hyundai i20       2015  ...          Tubeless
# 1        Maruti       Maruti Swift       2012  ...  Radial, Tubeless
# 2        Maruti     Maruti Celerio       2016  ...  Tubeless, Radial
# 3       Hyundai  Hyundai Grand i10       2017  ...          Tubeless
# 4        Maruti     Maruti Wagon R       2016  ...    Tubeless Tyres
# ...         ...                ...        ...  ...               ...
# 1115  Chevrolet     Chevrolet Beat       2011  ...   Tubeless,Radial
# 1116     Maruti        Maruti Alto       2007  ...   Tubeless,Radial
# 1117    Renault      Renault Kiger       2022  ...  Tubeless, Radial
# 1118     Maruti        Maruti Alto       2009  ...   Tubeless,Radial
# 1119     Maruti      Maruti Baleno       2018  ...   Tubeless,Radial
#
#      Value Configuration Values per Cylinder Wheel Base Wheel Size   Width  \
# 0                   DOHC                 4.0     2570mm         16  1734mm
# 1                    NaN                 4.0       2450        NaN    1735
# 2                   DOHC                 4.0     2425mm        NaN  1635mm
# 3                   DOHC                 4.0     2425mm        NaN  1660mm
# 4                   DOHC                 4.0     2400mm        NaN  1495mm
# ...                  ...                 ...        ...        ...     ...
# 1115                DOHC                 4.0     2375mm         14  1595mm
# 1116                SOHC                 4.0     2360mm         12  1475mm
# 1117                 NaN                 4.0       2500         16    1750
# 1118                SOHC                 4.0     2360mm         12  1475mm
# 1119                DOHC                 4.0     2520mm        NaN  1745mm
#
#      commonIcon         heading  \
# 0                Specifications
# 1                Specifications
# 2                Specifications
# 3                Specifications
# 4                Specifications
# ...         ...             ...
# 1115             Specifications
# 1116             Specifications
# 1117             Specifications
# 1118             Specifications
# 1119             Specifications
#
#                                               car_links    city
# 0     https://www.cardekho.com/used-car-details/used...  Jaipur
# 1     https://www.cardekho.com/buy-used-car-details/...  Jaipur
# 2     https://www.cardekho.com/used-car-details/used...  Jaipur
# 3     https://www.cardekho.com/buy-used-car-details/...  Jaipur
# 4     https://www.cardekho.com/used-car-details/used...  Jaipur
# ...                                                 ...     ...
# 1115  https://www.cardekho.com/used-car-details/used...  Jaipur
# 1116  https://www.cardekho.com/used-car-details/used...  Jaipur
# 1117  https://www.cardekho.com/used-car-details/used...  Jaipur
# 1118  https://www.cardekho.com/used-car-details/used...  Jaipur
# 1119  https://www.cardekho.com/used-car-details/used...  Jaipur
#
# [1120 rows x 81 columns]

# %%
path="D:\CHITRA\CARDEHO\\unclean_jaipur.csv"
df_jaipur.to_csv(path, index=False)
