# %%
import pandas as pd
import json

# %%
df=pd.read_excel("C:/Users/ASUS/Downloads/kolkata_cars.xlsx")

# %%
df
# Out:
#                                          new_car_detail  \
# 0     {'it': 0, 'ft': 'Petrol', 'bt': 'Sedan', 'km':...
# 1     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 2     {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 3     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 4     {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
# ...                                                 ...
# 1376  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 1377  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 1378  {'it': 0, 'ft': 'Petrol', 'bt': 'Sedan', 'km':...
# 1379  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 1380  {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
#
#                                        new_car_overview  \
# 0     {'heading': 'Car overview', 'top': [{'key': 'R...
# 1     {'heading': 'Car overview', 'top': [{'key': 'R...
# 2     {'heading': 'Car overview', 'top': [{'key': 'R...
# 3     {'heading': 'Car overview', 'top': [{'key': 'R...
# 4     {'heading': 'Car overview', 'top': [{'key': 'R...
# ...                                                 ...
# 1376  {'heading': 'Car overview', 'top': [{'key': 'R...
# 1377  {'heading': 'Car overview', 'top': [{'key': 'R...
# 1378  {'heading': 'Car overview', 'top': [{'key': 'R...
# 1379  {'heading': 'Car overview', 'top': [{'key': 'R...
# 1380  {'heading': 'Car overview', 'top': [{'key': 'R...
#
#                                         new_car_feature  \
# 0     {'heading': 'Features', 'top': [{'value': 'Pow...
# 1     {'heading': 'Features', 'top': [{'value': 'Pow...
# 2     {'heading': 'Features', 'top': [{'value': 'Pow...
# 3     {'heading': 'Features', 'top': [{'value': 'Pow...
# 4     {'heading': 'Features', 'top': [{'value': 'Pow...
# ...                                                 ...
# 1376  {'heading': 'Features', 'top': [{'value': 'Pow...
# 1377  {'heading': 'Features', 'top': [{'value': 'Pow...
# 1378  {'heading': 'Features', 'top': [{'value': 'Pow...
# 1379  {'heading': 'Features', 'top': [{'value': 'Pow...
# 1380  {'heading': 'Features', 'top': [{'value': 'Pow...
#
#                                           new_car_specs  \
# 0     {'heading': 'Specifications', 'top': [{'key': ...
# 1     {'heading': 'Specifications', 'top': [{'key': ...
# 2     {'heading': 'Specifications', 'top': [{'key': ...
# 3     {'heading': 'Specifications', 'top': [{'key': ...
# 4     {'heading': 'Specifications', 'top': [{'key': ...
# ...                                                 ...
# 1376  {'heading': 'Specifications', 'top': [{'key': ...
# 1377  {'heading': 'Specifications', 'top': [{'key': ...
# 1378  {'heading': 'Specifications', 'top': [{'key': ...
# 1379  {'heading': 'Specifications', 'top': [{'key': ...
# 1380  {'heading': 'Specifications', 'top': [{'key': ...
#
#                                               car_links
# 0     https://www.cardekho.com/used-car-details/used...
# 1     https://www.cardekho.com/buy-used-car-details/...
# 2     https://www.cardekho.com/used-car-details/used...
# 3     https://www.cardekho.com/buy-used-car-details/...
# 4     https://www.cardekho.com/used-car-details/used...
# ...                                                 ...
# 1376  https://www.cardekho.com/used-car-details/used...
# 1377  https://www.cardekho.com/used-car-details/used...
# 1378  https://www.cardekho.com/used-car-details/used...
# 1379  https://www.cardekho.com/used-car-details/used...
# 1380  https://www.cardekho.com/used-car-details/used...
#
# [1381 rows x 5 columns]

# %%
# Function to safely load JSON if it's a string
def safe_load(x):
    if isinstance(x, str):
        return json.loads(x.replace("'", '"').replace("None", "1"))
    return x  # If it's already a dict, return as is

# Apply the safe_load function
df["new_car_detail"] = df["new_car_detail"].apply(safe_load)

# Expand the main dictionary into columns
df_expanded = pd.DataFrame(df["new_car_detail"].to_list())

# Expand the nested dictionary into columns
df_nested_expanded = df_expanded["trendingText"].apply(pd.Series)

# Combine the original and nested DataFrame
df11 = pd.concat([df_expanded.drop(columns=["trendingText"]), df_nested_expanded], axis=1)

# %%
df11
# Out:
#       it      ft         bt        km transmission  ownerNo      owner  \
# 0      0  Petrol      Sedan    70,000    Automatic        3  3rd Owner
# 1      0  Petrol  Hatchback    23,981       Manual        1  1st Owner
# 2      0  Petrol        SUV     7,100    Automatic        1  1st Owner
# 3      0  Petrol  Hatchback    71,574       Manual        2  2nd Owner
# 4      0  Diesel        SUV    50,000    Automatic        2  2nd Owner
# ...   ..     ...        ...       ...          ...      ...        ...
# 1376   0  Petrol  Hatchback    10,000       Manual        1  1st Owner
# 1377   0  Petrol  Hatchback  1,20,000       Manual        1  1st Owner
# 1378   0  Petrol      Sedan    50,000    Automatic        3  3rd Owner
# 1379   0  Petrol  Hatchback    40,000       Manual        1  1st Owner
# 1380   0  Diesel        SUV  1,20,000       Manual        2  2nd Owner
#
#                 oem                  model  modelYear  centralVariantId  \
# 0            Toyota           Toyota Camry       2014              2123
# 1            Datsun          Datsun RediGO       2017              5236
# 2           Renault          Renault Kiger       2021              8352
# 3           Hyundai            Hyundai i20       2011              1642
# 4              Audi                Audi Q3       2014                99
# ...             ...                    ...        ...               ...
# 1376         Maruti         Maruti Celerio       2022              8682
# 1377         Maruti        Maruti Alto 800       2014              3943
# 1378  Mercedes-Benz  Mercedes-Benz C-Class       2011              4672
# 1379         Maruti            Maruti Ritz       2012              4144
# 1380        Renault         Renault Duster       2017              5048
#
#                  variantName        price priceActual priceSaving  \
# 0                     Hybrid  ₹ 9.75 Lakh
# 1                   T Option  ₹ 2.66 Lakh
# 2                    RXT AMT  ₹ 5.95 Lakh
# 3                 1.2 Sportz  ₹ 2.23 Lakh
# 4     35 TDI Quattro Premium    ₹ 12 Lakh
# ...                      ...          ...         ...         ...
# 1376                ZXI BSVI  ₹ 5.10 Lakh
# 1377                     LXI  ₹ 1.80 Lakh
# 1378      C 200 CGI Elegance  ₹ 5.50 Lakh
# 1379                     ZXi  ₹ 1.40 Lakh
# 1380    110PS Diesel RxZ AWD     ₹ 5 Lakh
#
#       priceFixedText                                             imgUrl  \
# 0                  1  https://stimg.cardekho.com/used-cars/common/ic...
# 1                  1  https://stimg.cardekho.com/used-cars/common/ic...
# 2                  1  https://stimg.cardekho.com/used-cars/common/ic...
# 3                  1  https://stimg.cardekho.com/used-cars/common/ic...
# 4                  1  https://stimg.cardekho.com/used-cars/common/ic...
# ...              ...                                                ...
# 1376               1  https://stimg.cardekho.com/used-cars/common/ic...
# 1377               1  https://stimg.cardekho.com/used-cars/common/ic...
# 1378               1  https://stimg.cardekho.com/used-cars/common/ic...
# 1379               1  https://stimg.cardekho.com/used-cars/common/ic...
# 1380               1  https://stimg.cardekho.com/used-cars/common/ic...
#
#             heading                                 desc
# 0     Trending Car!  High chances of sale in next 6 days
# 1     Trending Car!  High chances of sale in next 6 days
# 2     Trending Car!  High chances of sale in next 6 days
# 3     Trending Car!  High chances of sale in next 6 days
# 4     Trending Car!  High chances of sale in next 6 days
# ...             ...                                  ...
# 1376  Trending Car!  High chances of sale in next 6 days
# 1377  Trending Car!  High chances of sale in next 6 days
# 1378  Trending Car!  High chances of sale in next 6 days
# 1379  Trending Car!  High chances of sale in next 6 days
# 1380  Trending Car!  High chances of sale in next 6 days
#
# [1381 rows x 19 columns]

# %%
import pandas as pd
import json

# Function to safely load JSON if it's a string
def safe_load(x):
    if isinstance(x, str):
        try:
            return json.loads(x.replace("'", '"').replace("None", "1"))
        except json.JSONDecodeError:
            return None  # Return None if JSON loading fails
    return x  # If it's already a list or dict, return as is

# Apply the safe_load function to the 'new_car_overview' column
df["new_car_overview"] = df["new_car_overview"].apply(safe_load)

# Function to extract key-value pairs from the list of dictionaries
def extract_key_value_pairs(dict_list):
    if isinstance(dict_list, list):  # Check if the item is a list
        extracted_data = {}
        for item in dict_list:
            if isinstance(item, dict):  # Ensure each item is a dictionary
                key = item.get('key')
                value = item.get('value')
                if key:  # Only add if the key exists
                    extracted_data[key] = value
        return pd.Series(extracted_data)
    return pd.Series()  # Return an empty Series if dict_list is not a list

# Expand the 'new_car_overview' column into a new DataFrame
df_expanded = df["new_car_overview"].apply(extract_key_value_pairs)

# %%
def extract_key_value_pairs(dict_list):
    if isinstance(dict_list, list):
        extracted_data = {}
        for item in dict_list:
            if isinstance(item, dict):
                key = item.get('key')
                value = item.get('value')
                if key:  # Only add if the key exists
                    extracted_data[key] = value
        return pd.Series(extracted_data)
    return pd.Series()  # Return an empty Series if dict_list is not a list

# Apply the extraction function to the 'top' column
df2 = df['new_car_overview'].apply(lambda x: x['top'] if isinstance(x, dict) else None).apply(extract_key_value_pairs)

# %%
df2
# Out:
#      Registration Year     Insurance Validity Fuel Type    Seats  \
# 0                 2014  Third Party insurance    Petrol  5 Seats
# 1             Jul 2017          Comprehensive    Petrol  5 Seats
# 2             Nov 2021          Comprehensive    Petrol  5 Seats
# 3             Feb 2012            Third Party    Petrol  5 Seats
# 4                 2014  Third Party insurance    Diesel  5 Seats
# ...                ...                    ...       ...      ...
# 1376              2022  Third Party insurance    Petrol  5 Seats
# 1377              2014  Third Party insurance    Petrol  5 Seats
# 1378              2011  Third Party insurance    Petrol  5 Seats
# 1379              2012  Third Party insurance    Petrol  5 Seats
# 1380              2017  Third Party insurance    Diesel  5 Seats
#
#         Kms Driven   RTO     Ownership Engine Displacement Transmission  \
# 0       70,000 Kms  WB02   Third Owner             2494 cc    Automatic
# 1       23,981 Kms  WB24   First Owner              799 cc       Manual
# 2        7,100 Kms  WB06   First Owner              999 cc    Automatic
# 3       71,574 Kms  WB06  Second Owner             1197 cc       Manual
# 4       50,000 Kms  WB02  Second Owner             1968 cc    Automatic
# ...            ...   ...           ...                 ...          ...
# 1376    10,000 Kms   NaN   First Owner              998 cc       Manual
# 1377  1,20,000 Kms   NaN   First Owner              796 cc       Manual
# 1378    50,000 Kms  WB06   Third Owner             1796 cc    Automatic
# 1379    40,000 Kms   NaN   First Owner             1197 cc       Manual
# 1380  1,20,000 Kms   NaN  Second Owner             1461 cc       Manual
#
#       Year of Manufacture
# 0                  2014.0
# 1                  2017.0
# 2                  2021.0
# 3                  2011.0
# 4                  2014.0
# ...                   ...
# 1376               2022.0
# 1377               2014.0
# 1378               2011.0
# 1379               2012.0
# 1380               2017.0
#
# [1381 rows x 10 columns]

# %%
# Concatenate horizontally
dfk= pd.concat([df11, df2], axis=1)

# %%
dfk
# Out:
#       it      ft         bt        km transmission  ownerNo      owner  \
# 0      0  Petrol      Sedan    70,000    Automatic        3  3rd Owner
# 1      0  Petrol  Hatchback    23,981       Manual        1  1st Owner
# 2      0  Petrol        SUV     7,100    Automatic        1  1st Owner
# 3      0  Petrol  Hatchback    71,574       Manual        2  2nd Owner
# 4      0  Diesel        SUV    50,000    Automatic        2  2nd Owner
# ...   ..     ...        ...       ...          ...      ...        ...
# 1376   0  Petrol  Hatchback    10,000       Manual        1  1st Owner
# 1377   0  Petrol  Hatchback  1,20,000       Manual        1  1st Owner
# 1378   0  Petrol      Sedan    50,000    Automatic        3  3rd Owner
# 1379   0  Petrol  Hatchback    40,000       Manual        1  1st Owner
# 1380   0  Diesel        SUV  1,20,000       Manual        2  2nd Owner
#
#                 oem                  model  modelYear  ...  Registration Year  \
# 0            Toyota           Toyota Camry       2014  ...               2014
# 1            Datsun          Datsun RediGO       2017  ...           Jul 2017
# 2           Renault          Renault Kiger       2021  ...           Nov 2021
# 3           Hyundai            Hyundai i20       2011  ...           Feb 2012
# 4              Audi                Audi Q3       2014  ...               2014
# ...             ...                    ...        ...  ...                ...
# 1376         Maruti         Maruti Celerio       2022  ...               2022
# 1377         Maruti        Maruti Alto 800       2014  ...               2014
# 1378  Mercedes-Benz  Mercedes-Benz C-Class       2011  ...               2011
# 1379         Maruti            Maruti Ritz       2012  ...               2012
# 1380        Renault         Renault Duster       2017  ...               2017
#
#          Insurance Validity Fuel Type    Seats    Kms Driven   RTO  \
# 0     Third Party insurance    Petrol  5 Seats    70,000 Kms  WB02
# 1             Comprehensive    Petrol  5 Seats    23,981 Kms  WB24
# 2             Comprehensive    Petrol  5 Seats     7,100 Kms  WB06
# 3               Third Party    Petrol  5 Seats    71,574 Kms  WB06
# 4     Third Party insurance    Diesel  5 Seats    50,000 Kms  WB02
# ...                     ...       ...      ...           ...   ...
# 1376  Third Party insurance    Petrol  5 Seats    10,000 Kms   NaN
# 1377  Third Party insurance    Petrol  5 Seats  1,20,000 Kms   NaN
# 1378  Third Party insurance    Petrol  5 Seats    50,000 Kms  WB06
# 1379  Third Party insurance    Petrol  5 Seats    40,000 Kms   NaN
# 1380  Third Party insurance    Diesel  5 Seats  1,20,000 Kms   NaN
#
#          Ownership Engine Displacement Transmission Year of Manufacture
# 0      Third Owner             2494 cc    Automatic              2014.0
# 1      First Owner              799 cc       Manual              2017.0
# 2      First Owner              999 cc    Automatic              2021.0
# 3     Second Owner             1197 cc       Manual              2011.0
# 4     Second Owner             1968 cc    Automatic              2014.0
# ...            ...                 ...          ...                 ...
# 1376   First Owner              998 cc       Manual              2022.0
# 1377   First Owner              796 cc       Manual              2014.0
# 1378   Third Owner             1796 cc    Automatic              2011.0
# 1379   First Owner             1197 cc       Manual              2012.0
# 1380  Second Owner             1461 cc       Manual              2017.0
#
# [1381 rows x 29 columns]

# %%
#feature

# %%
df.new_car_feature=df["new_car_feature"].apply(lambda x:json.loads(x.replace("'",'"').replace("None","1")))
df_new=pd.DataFrame(df.new_car_feature.to_list())

# %%
df_new
# Out:
#        heading                                                top  \
# 0     Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 1     Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 2     Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 3     Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 4     Features  [{'value': 'Power Steering'}, {'value': 'Power...
# ...        ...                                                ...
# 1376  Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 1377  Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 1378  Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 1379  Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 1380  Features  [{'value': 'Power Steering'}, {'value': 'Power...
#
#                                                    data  \
# 0     [{'heading': 'Comfort & Convenience', 'subHead...
# 1     [{'heading': 'Comfort & Convenience', 'subHead...
# 2     [{'heading': 'Comfort & Convenience', 'subHead...
# 3     [{'heading': 'Comfort & Convenience', 'subHead...
# 4     [{'heading': 'Comfort & Convenience', 'subHead...
# ...                                                 ...
# 1376  [{'heading': 'Comfort & Convenience', 'subHead...
# 1377  [{'heading': 'Comfort & Convenience', 'subHead...
# 1378  [{'heading': 'Comfort & Convenience', 'subHead...
# 1379  [{'heading': 'Comfort & Convenience', 'subHead...
# 1380  [{'heading': 'Comfort & Convenience', 'subHead...
#
#                                              commonIcon
# 0     https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1     https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 2     https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 3     https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 4     https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# ...                                                 ...
# 1376  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1377  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1378  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1379  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1380  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
#
# [1381 rows x 4 columns]

# %%
import pandas as pd
import numpy as np


# Ensure 'top' column contains lists; replace non-lists with empty lists
df_new['top'] = df_new['top'].apply(lambda x: x if isinstance(x, list) else [])

# Extract feature values and concatenate them into a single string per row
df_new['Features'] = df_new['top'].apply(lambda x: ', '.join([item['value'] for item in x]))

# Drop the original 'top' column if no longer needed
df_new = df_new.drop(columns=['top'])

df_new
# Out:
#        heading                                               data  \
# 0     Features  [{'heading': 'Comfort & Convenience', 'subHead...
# 1     Features  [{'heading': 'Comfort & Convenience', 'subHead...
# 2     Features  [{'heading': 'Comfort & Convenience', 'subHead...
# 3     Features  [{'heading': 'Comfort & Convenience', 'subHead...
# 4     Features  [{'heading': 'Comfort & Convenience', 'subHead...
# ...        ...                                                ...
# 1376  Features  [{'heading': 'Comfort & Convenience', 'subHead...
# 1377  Features  [{'heading': 'Comfort & Convenience', 'subHead...
# 1378  Features  [{'heading': 'Comfort & Convenience', 'subHead...
# 1379  Features  [{'heading': 'Comfort & Convenience', 'subHead...
# 1380  Features  [{'heading': 'Comfort & Convenience', 'subHead...
#
#                                              commonIcon  \
# 0     https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1     https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 2     https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 3     https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 4     https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# ...                                                 ...
# 1376  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1377  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1378  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1379  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1380  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
#
#                                                Features
# 0     Power Steering, Power Windows Front, Air Condi...
# 1     Power Steering, Power Windows Front, Air Condi...
# 2     Power Steering, Power Windows Front, Air Condi...
# 3     Power Steering, Power Windows Front, Air Condi...
# 4     Power Steering, Power Windows Front, Air Condi...
# ...                                                 ...
# 1376  Power Steering, Power Windows Front, Air Condi...
# 1377  Power Steering, Power Windows Front, Air Condi...
# 1378  Power Steering, Power Windows Front, Air Condi...
# 1379  Power Steering, Power Windows Front, Air Condi...
# 1380  Power Steering, Power Windows Front, Air Condi...
#
# [1381 rows x 4 columns]

# %%
# Function to extract features and create columns
def extract_features(data):
    features_dict = {}
    for category in data:
        sub_heading = category['subHeading']
        features = [item['value'] for item in category['list']]
        features_dict[sub_heading] = ', '.join(features)
    return features_dict

# Apply the function to the 'data' column and convert to DataFrame
features_df = pd.json_normalize(df_new['data'].apply(extract_features))

# Concatenate with the original DataFrame if needed
df3 = pd.concat([df_new.drop(columns=['data']), features_df], axis=1)
df3
# Out:
#        heading                                         commonIcon  \
# 0     Features  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1     Features  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 2     Features  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 3     Features  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 4     Features  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# ...        ...                                                ...
# 1376  Features  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1377  Features  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1378  Features  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1379  Features  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1380  Features  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
#
#                                                Features  \
# 0     Power Steering, Power Windows Front, Air Condi...
# 1     Power Steering, Power Windows Front, Air Condi...
# 2     Power Steering, Power Windows Front, Air Condi...
# 3     Power Steering, Power Windows Front, Air Condi...
# 4     Power Steering, Power Windows Front, Air Condi...
# ...                                                 ...
# 1376  Power Steering, Power Windows Front, Air Condi...
# 1377  Power Steering, Power Windows Front, Air Condi...
# 1378  Power Steering, Power Windows Front, Air Condi...
# 1379  Power Steering, Power Windows Front, Air Condi...
# 1380  Power Steering, Power Windows Front, Air Condi...
#
#                                                 Comfort  \
# 0     Power Steering, Power Windows Front, Power Win...
# 1     Power Steering, Power Windows Front, Remote Tr...
# 2     Power Steering, Power Windows Front, Power Win...
# 3     Power Steering, Power Windows Front, Power Win...
# 4     Power Steering, Power Windows Front, Power Win...
# ...                                                 ...
# 1376  Power Steering, Power Windows Front, Power Win...
# 1377  Power Steering, Power Windows Front, Remote Tr...
# 1378  Power Steering, Power Windows Front, Power Win...
# 1379  Power Steering, Power Windows Front, Power Win...
# 1380  Power Steering, Power Windows Front, Power Win...
#
#                                                Interior  \
# 0     Air Conditioner, Heater, Adjustable Steering, ...
# 1     Air Conditioner, Heater, Tachometer, Electroni...
# 2     Air Conditioner, Heater, Adjustable Steering, ...
# 3     Air Conditioner, Heater, Adjustable Steering, ...
# 4     Air Conditioner, Heater, Adjustable Steering, ...
# ...                                                 ...
# 1376  Air Conditioner, Heater, Adjustable Steering, ...
# 1377  Air Conditioner, Heater, Digital Odometer, Ele...
# 1378  Air Conditioner, Heater, Adjustable Steering, ...
# 1379  Air Conditioner, Heater, Adjustable Steering, ...
# 1380  Air Conditioner, Heater, Adjustable Steering, ...
#
#                                                Exterior  \
# 0     Adjustable Head Lights, Fog Lights Front, Fog ...
# 1     Adjustable Head Lights, Manually Adjustable Ex...
# 2     Adjustable Head Lights, Power Adjustable Exter...
# 3     Fog Lights Rear, Power Adjustable Exterior Rea...
# 4     Adjustable Head Lights, Fog Lights Front, Fog ...
# ...                                                 ...
# 1376  Adjustable Head Lights, Power Adjustable Exter...
# 1377  Adjustable Head Lights, Manually Adjustable Ex...
# 1378  Adjustable Head Lights, Fog Lights Front, Fog ...
# 1379  Adjustable Head Lights, Fog Lights Front, Fog ...
# 1380  Adjustable Head Lights, Fog Lights Front, Powe...
#
#                                                  Safety  \
# 0     Anti Lock Braking System, Brake Assist, Center...
# 1     Anti Lock Braking System, Centeral Locking, Ch...
# 2     Anti Lock Braking System, Centeral Locking, Po...
# 3     Centeral Locking, Power Door Locks, Child Safe...
# 4     Anti Lock Braking System, Brake Assist, Center...
# ...                                                 ...
# 1376  Anti Lock Braking System, Centeral Locking, Po...
# 1377  Day Night Rear View Mirror, Passenger Side Rea...
# 1378  Anti Lock Braking System, Brake Assist, Center...
# 1379  Anti Lock Braking System, Centeral Locking, Po...
# 1380  Anti Lock Braking System, Brake Assist, Center...
#
#                                           Entertainment
# 0     Cd Player, Dvd Player, Radio, Speakers Front, ...
# 1     Radio, Speakers Front, Usb Auxiliary Input, Bl...
# 2     Radio, Speakers Front, Speakers Rear, Integrat...
# 3       Cd Player, Radio, Speakers Front, Speakers Rear
# 4     Cd Player, Radio, Audio System Remote Control,...
# ...                                                 ...
# 1376  Radio, Speakers Front, Speakers Rear, Integrat...
# 1377                                                NaN
# 1378  Cd Player, Cd Changer, Radio, Audio System Rem...
# 1379  Cd Player, Radio, Speakers Front, Speakers Rea...
# 1380  Cd Player, Radio, Speakers Front, Speakers Rea...
#
# [1381 rows x 8 columns]

# %%
# Concatenate horizontally
dfk=pd.concat([dfk, df3], axis=1)

# %%
dfk
# Out:
#       it      ft         bt        km transmission  ownerNo      owner  \
# 0      0  Petrol      Sedan    70,000    Automatic        3  3rd Owner
# 1      0  Petrol  Hatchback    23,981       Manual        1  1st Owner
# 2      0  Petrol        SUV     7,100    Automatic        1  1st Owner
# 3      0  Petrol  Hatchback    71,574       Manual        2  2nd Owner
# 4      0  Diesel        SUV    50,000    Automatic        2  2nd Owner
# ...   ..     ...        ...       ...          ...      ...        ...
# 1376   0  Petrol  Hatchback    10,000       Manual        1  1st Owner
# 1377   0  Petrol  Hatchback  1,20,000       Manual        1  1st Owner
# 1378   0  Petrol      Sedan    50,000    Automatic        3  3rd Owner
# 1379   0  Petrol  Hatchback    40,000       Manual        1  1st Owner
# 1380   0  Diesel        SUV  1,20,000       Manual        2  2nd Owner
#
#                 oem                  model  modelYear  ...  Transmission  \
# 0            Toyota           Toyota Camry       2014  ...     Automatic
# 1            Datsun          Datsun RediGO       2017  ...        Manual
# 2           Renault          Renault Kiger       2021  ...     Automatic
# 3           Hyundai            Hyundai i20       2011  ...        Manual
# 4              Audi                Audi Q3       2014  ...     Automatic
# ...             ...                    ...        ...  ...           ...
# 1376         Maruti         Maruti Celerio       2022  ...        Manual
# 1377         Maruti        Maruti Alto 800       2014  ...        Manual
# 1378  Mercedes-Benz  Mercedes-Benz C-Class       2011  ...     Automatic
# 1379         Maruti            Maruti Ritz       2012  ...        Manual
# 1380        Renault         Renault Duster       2017  ...        Manual
#
#      Year of Manufacture   heading  \
# 0                 2014.0  Features
# 1                 2017.0  Features
# 2                 2021.0  Features
# 3                 2011.0  Features
# 4                 2014.0  Features
# ...                  ...       ...
# 1376              2022.0  Features
# 1377              2014.0  Features
# 1378              2011.0  Features
# 1379              2012.0  Features
# 1380              2017.0  Features
#
#                                              commonIcon  \
# 0     https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1     https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 2     https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 3     https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 4     https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# ...                                                 ...
# 1376  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1377  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1378  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1379  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
# 1380  https://stimg.cardekho.com/pwa/img/vdpN/tickG.svg
#
#                                                Features  \
# 0     Power Steering, Power Windows Front, Air Condi...
# 1     Power Steering, Power Windows Front, Air Condi...
# 2     Power Steering, Power Windows Front, Air Condi...
# 3     Power Steering, Power Windows Front, Air Condi...
# 4     Power Steering, Power Windows Front, Air Condi...
# ...                                                 ...
# 1376  Power Steering, Power Windows Front, Air Condi...
# 1377  Power Steering, Power Windows Front, Air Condi...
# 1378  Power Steering, Power Windows Front, Air Condi...
# 1379  Power Steering, Power Windows Front, Air Condi...
# 1380  Power Steering, Power Windows Front, Air Condi...
#
#                                                 Comfort  \
# 0     Power Steering, Power Windows Front, Power Win...
# 1     Power Steering, Power Windows Front, Remote Tr...
# 2     Power Steering, Power Windows Front, Power Win...
# 3     Power Steering, Power Windows Front, Power Win...
# 4     Power Steering, Power Windows Front, Power Win...
# ...                                                 ...
# 1376  Power Steering, Power Windows Front, Power Win...
# 1377  Power Steering, Power Windows Front, Remote Tr...
# 1378  Power Steering, Power Windows Front, Power Win...
# 1379  Power Steering, Power Windows Front, Power Win...
# 1380  Power Steering, Power Windows Front, Power Win...
#
#                                                Interior  \
# 0     Air Conditioner, Heater, Adjustable Steering, ...
# 1     Air Conditioner, Heater, Tachometer, Electroni...
# 2     Air Conditioner, Heater, Adjustable Steering, ...
# 3     Air Conditioner, Heater, Adjustable Steering, ...
# 4     Air Conditioner, Heater, Adjustable Steering, ...
# ...                                                 ...
# 1376  Air Conditioner, Heater, Adjustable Steering, ...
# 1377  Air Conditioner, Heater, Digital Odometer, Ele...
# 1378  Air Conditioner, Heater, Adjustable Steering, ...
# 1379  Air Conditioner, Heater, Adjustable Steering, ...
# 1380  Air Conditioner, Heater, Adjustable Steering, ...
#
#                                                Exterior  \
# 0     Adjustable Head Lights, Fog Lights Front, Fog ...
# 1     Adjustable Head Lights, Manually Adjustable Ex...
# 2     Adjustable Head Lights, Power Adjustable Exter...
# 3     Fog Lights Rear, Power Adjustable Exterior Rea...
# 4     Adjustable Head Lights, Fog Lights Front, Fog ...
# ...                                                 ...
# 1376  Adjustable Head Lights, Power Adjustable Exter...
# 1377  Adjustable Head Lights, Manually Adjustable Ex...
# 1378  Adjustable Head Lights, Fog Lights Front, Fog ...
# 1379  Adjustable Head Lights, Fog Lights Front, Fog ...
# 1380  Adjustable Head Lights, Fog Lights Front, Powe...
#
#                                                  Safety  \
# 0     Anti Lock Braking System, Brake Assist, Center...
# 1     Anti Lock Braking System, Centeral Locking, Ch...
# 2     Anti Lock Braking System, Centeral Locking, Po...
# 3     Centeral Locking, Power Door Locks, Child Safe...
# 4     Anti Lock Braking System, Brake Assist, Center...
# ...                                                 ...
# 1376  Anti Lock Braking System, Centeral Locking, Po...
# 1377  Day Night Rear View Mirror, Passenger Side Rea...
# 1378  Anti Lock Braking System, Brake Assist, Center...
# 1379  Anti Lock Braking System, Centeral Locking, Po...
# 1380  Anti Lock Braking System, Brake Assist, Center...
#
#                                           Entertainment
# 0     Cd Player, Dvd Player, Radio, Speakers Front, ...
# 1     Radio, Speakers Front, Usb Auxiliary Input, Bl...
# 2     Radio, Speakers Front, Speakers Rear, Integrat...
# 3       Cd Player, Radio, Speakers Front, Speakers Rear
# 4     Cd Player, Radio, Audio System Remote Control,...
# ...                                                 ...
# 1376  Radio, Speakers Front, Speakers Rear, Integrat...
# 1377                                                NaN
# 1378  Cd Player, Cd Changer, Radio, Audio System Rem...
# 1379  Cd Player, Radio, Speakers Front, Speakers Rea...
# 1380  Cd Player, Radio, Speakers Front, Speakers Rea...
#
# [1381 rows x 37 columns]

# %%
import pandas as pd
import json

# Function to safely convert JSON strings to dictionaries
def safe_json_loads(x):
    if isinstance(x, str):  # Check if the data is a string
        try:
            # Replace single quotes with double quotes and handle 'None'
            return json.loads(x.replace("'", '"').replace("None", "1"))
        except json.JSONDecodeError:
            # Handle JSON parsing errors
            print(f"Error decoding JSON for: {x}")
            return None
    elif isinstance(x, dict):
        # If already a dictionary, return it as is
        return x
    else:
        # Handle unexpected data types
        print(f"Unexpected data type: {type(x)}")
        return None

# Apply the function to safely transform the data
df['new_car_specs'] = df['new_car_specs'].apply(safe_json_loads)

# Convert the list of dictionaries to a DataFrame
df_new = pd.DataFrame(df['new_car_specs'].tolist())
df_new
# Out:
#              heading                                                top  \
# 0     Specifications  [{'key': 'Mileage', 'value': '19.16 kmpl'}, {'...
# 1     Specifications  [{'key': 'Mileage', 'value': '22.7 kmpl'}, {'k...
# 2     Specifications  [{'key': 'Mileage', 'value': '19.03 kmpl'}, {'...
# 3     Specifications  [{'key': 'Mileage', 'value': '17 kmpl'}, {'key...
# 4     Specifications  [{'key': 'Mileage', 'value': '15.73 kmpl'}, {'...
# ...              ...                                                ...
# 1376  Specifications  [{'key': 'Mileage', 'value': '25.24 kmpl'}, {'...
# 1377  Specifications  [{'key': 'Mileage', 'value': '22.74 kmpl'}, {'...
# 1378  Specifications  [{'key': 'Mileage', 'value': '11.74 kmpl'}, {'...
# 1379  Specifications  [{'key': 'Mileage', 'value': '18.5 kmpl'}, {'k...
# 1380  Specifications  [{'key': 'Mileage', 'value': '19.72 kmpl'}, {'...
#
#                                                    data commonIcon
# 0     [{'heading': 'Engine and Transmission', 'subHe...
# 1     [{'heading': 'Engine and Transmission', 'subHe...
# 2     [{'heading': 'Engine and Transmission', 'subHe...
# 3     [{'heading': 'Engine and Transmission', 'subHe...
# 4     [{'heading': 'Engine and Transmission', 'subHe...
# ...                                                 ...        ...
# 1376  [{'heading': 'Engine and Transmission', 'subHe...
# 1377  [{'heading': 'Engine and Transmission', 'subHe...
# 1378  [{'heading': 'Engine and Transmission', 'subHe...
# 1379  [{'heading': 'Engine and Transmission', 'subHe...
# 1380  [{'heading': 'Engine and Transmission', 'subHe...
#
# [1381 rows x 4 columns]

# %%
# Function to extract 'top' key-value pairs and add them as columns
def extract_top(row):
    if isinstance(row['top'], list):
        for item in row['top']:
            row[item['key']] = item['value']
    return row

# Apply the function to the DataFrame
df_new = df_new.apply(extract_top, axis=1)

# Drop the 'top' column after extraction
df_new.drop(columns=['top'], inplace=True)
df_new
# Out:
#        Engine          Max Power     Mileage Seats                 Torque  \
# 0     2494 CC           158.2bhp  19.16 kmpl     5                  213Nm
# 1      799 CC           53.64bhp   22.7 kmpl     5                   72Nm
# 2      999 CC           71.01bhp  19.03 kmpl     5                   96Nm
# 3     1197 CC  80 PS at 5200 rpm     17 kmpl     5  11.4 kgm at 4,000 rpm
# 4     1968 CC          174.33bhp  15.73 kmpl     5                  380Nm
# ...       ...                ...         ...   ...                    ...
# 1376   998 CC           65.71bhp  25.24 kmpl     5                   89Nm
# 1377   796 CC            47.3bhp  22.74 kmpl     5                   69Nm
# 1378  1796 CC             186bhp  11.74 kmpl     5                  285Nm
# 1379  1197 CC           85.80bhp   18.5 kmpl     5                  114Nm
# 1380  1461 CC          108.45bhp  19.72 kmpl     5                  245Nm
#
#      Wheel Size commonIcon                                               data  \
# 0            17             [{'heading': 'Engine and Transmission', 'subHe...
# 1           NaN             [{'heading': 'Engine and Transmission', 'subHe...
# 2           NaN             [{'heading': 'Engine and Transmission', 'subHe...
# 3            14             [{'heading': 'Engine and Transmission', 'subHe...
# 4            16             [{'heading': 'Engine and Transmission', 'subHe...
# ...         ...        ...                                                ...
# 1376        NaN             [{'heading': 'Engine and Transmission', 'subHe...
# 1377        NaN             [{'heading': 'Engine and Transmission', 'subHe...
# 1378         17             [{'heading': 'Engine and Transmission', 'subHe...
# 1379         14             [{'heading': 'Engine and Transmission', 'subHe...
# 1380         16             [{'heading': 'Engine and Transmission', 'subHe...
#
#              heading
# 0     Specifications
# 1     Specifications
# 2     Specifications
# 3     Specifications
# 4     Specifications
# ...              ...
# 1376  Specifications
# 1377  Specifications
# 1378  Specifications
# 1379  Specifications
# 1380  Specifications
#
# [1381 rows x 9 columns]

# %%
# Function to extract 'data' key-value pairs and add them as columns
def extract_data(row):
    if isinstance(row['data'], list):
        for section in row['data']:
            for item in section['list']:
                row[item['key']] = item['value']
    return row

# Apply the function to the DataFrame
df_new = df_new.apply(extract_data, axis=1)

# Drop the 'data' column after extraction
df_new.drop(columns=['data'], inplace=True)

# %%
df4=df_new
df4
# Out:
#        Acceleration Alloy Wheel Size BoreX Stroke Cargo Volumn   Color  \
# 0               NaN               17   90 X 98 mm          NaN   White
# 1               NaN              NaN          NaN          222     Red
# 2               NaN              NaN          NaN          405    Blue
# 3         12.96 Sec               14          NaN      295 Lit     Red
# 4       8.2 Seconds               16          NaN   460-litres   White
# ...             ...              ...          ...          ...     ...
# 1376            NaN              NaN          NaN          313  Others
# 1377     19 Seconds              NaN          NaN   177-litres  Others
# 1378    8.8 Seconds               17          NaN   475-litres  Others
# 1379     15 Seconds               14          NaN   236-liters  Others
# 1380  14.20 Seconds               16          NaN   410-litres  Others
#
#      Compression Ratio Displacement Drive Type   Engine  \
# 0                  NaN         2494        FWD  2494 CC
# 1                  NaN          799        2WD   799 CC
# 2                  NaN          999        NaN   999 CC
# 3                   :1         1197        FWD  1197 CC
# 4                  NaN         1968        AWD  1968 CC
# ...                ...          ...        ...      ...
# 1376               NaN          998        NaN   998 CC
# 1377               NaN          796        FWD   796 CC
# 1378             9.3:1         1796        RWD  1796 CC
# 1379               NaN         1197        FWD  1197 CC
# 1380               NaN         1461        AWD  1461 CC
#
#                  Engine Type  ... Turbo Charger Turning Radius  \
# 0     2AR FXE Petrol Engine   ...            No     5.5 metres
# 1         0.8L Petrol Engine  ...            No           4.7m
# 2                1.0L energy  ...           NaN            NaN
# 3             In-Line Engine  ...            No         5.20 m
# 4          TDI Diesel Engine  ...           Yes     5.9 metres
# ...                      ...  ...           ...            ...
# 1376                    K10C  ...           NaN            NaN
# 1377       F8D Petrol Engine  ...            No     4.6 metres
# 1378  Blue Efficiency Engine  ...            No    5.42 metres
# 1379  K Series Petrol Engine  ...            No     4.7 metres
# 1380   dCi THP Diesel Engine  ...           Yes     5.2 metres
#
#              Tyre Type Value Configuration Values per Cylinder Wheel Base  \
# 0      Tubeless,Radial                DOHC                 4.0     2775mm
# 1                  NaN                DOHC                 4.0     2348mm
# 2     Tubeless, Radial                 NaN                 4.0       2500
# 3      Tubeless,Radial                DOHC                 4.0   2,525 mm
# 4      Tubeless,Radial                DOHC                 4.0     2603mm
# ...                ...                 ...                 ...        ...
# 1376  Tubeless, Radial                 NaN                 4.0       2435
# 1377    Tubeless Tyres                DOHC                 4.0     2360mm
# 1378   Tubeless,Radial                 NaN                 4.0     2760mm
# 1379   Tubeless,Radial                DOHC                 4.0     2360mm
# 1380   Tubeless,Radial                DOHC                 4.0     2673mm
#
#      Wheel Size    Width commonIcon         heading
# 0            17   1825mm             Specifications
# 1           NaN   1560mm             Specifications
# 2           NaN     1750             Specifications
# 3            14  1710 mm             Specifications
# 4            16   2019mm             Specifications
# ...         ...      ...        ...             ...
# 1376        NaN     1655             Specifications
# 1377        NaN   1490mm             Specifications
# 1378         17   1770mm             Specifications
# 1379         14   1680mm             Specifications
# 1380         16   1822mm             Specifications
#
# [1381 rows x 42 columns]

# %%
# Concatenate horizontally
df_kolkata=pd.concat([dfk, df4], axis=1)

# %%
df_kolkata
# Out:
#       it      ft         bt        km transmission  ownerNo      owner  \
# 0      0  Petrol      Sedan    70,000    Automatic        3  3rd Owner
# 1      0  Petrol  Hatchback    23,981       Manual        1  1st Owner
# 2      0  Petrol        SUV     7,100    Automatic        1  1st Owner
# 3      0  Petrol  Hatchback    71,574       Manual        2  2nd Owner
# 4      0  Diesel        SUV    50,000    Automatic        2  2nd Owner
# ...   ..     ...        ...       ...          ...      ...        ...
# 1376   0  Petrol  Hatchback    10,000       Manual        1  1st Owner
# 1377   0  Petrol  Hatchback  1,20,000       Manual        1  1st Owner
# 1378   0  Petrol      Sedan    50,000    Automatic        3  3rd Owner
# 1379   0  Petrol  Hatchback    40,000       Manual        1  1st Owner
# 1380   0  Diesel        SUV  1,20,000       Manual        2  2nd Owner
#
#                 oem                  model  modelYear  ...  Turbo Charger  \
# 0            Toyota           Toyota Camry       2014  ...             No
# 1            Datsun          Datsun RediGO       2017  ...             No
# 2           Renault          Renault Kiger       2021  ...            NaN
# 3           Hyundai            Hyundai i20       2011  ...             No
# 4              Audi                Audi Q3       2014  ...            Yes
# ...             ...                    ...        ...  ...            ...
# 1376         Maruti         Maruti Celerio       2022  ...            NaN
# 1377         Maruti        Maruti Alto 800       2014  ...             No
# 1378  Mercedes-Benz  Mercedes-Benz C-Class       2011  ...             No
# 1379         Maruti            Maruti Ritz       2012  ...             No
# 1380        Renault         Renault Duster       2017  ...            Yes
#
#      Turning Radius         Tyre Type Value Configuration Values per Cylinder  \
# 0        5.5 metres   Tubeless,Radial                DOHC                 4.0
# 1              4.7m               NaN                DOHC                 4.0
# 2               NaN  Tubeless, Radial                 NaN                 4.0
# 3            5.20 m   Tubeless,Radial                DOHC                 4.0
# 4        5.9 metres   Tubeless,Radial                DOHC                 4.0
# ...             ...               ...                 ...                 ...
# 1376            NaN  Tubeless, Radial                 NaN                 4.0
# 1377     4.6 metres    Tubeless Tyres                DOHC                 4.0
# 1378    5.42 metres   Tubeless,Radial                 NaN                 4.0
# 1379     4.7 metres   Tubeless,Radial                DOHC                 4.0
# 1380     5.2 metres   Tubeless,Radial                DOHC                 4.0
#
#       Wheel Base Wheel Size    Width commonIcon         heading
# 0         2775mm         17   1825mm             Specifications
# 1         2348mm        NaN   1560mm             Specifications
# 2           2500        NaN     1750             Specifications
# 3       2,525 mm         14  1710 mm             Specifications
# 4         2603mm         16   2019mm             Specifications
# ...          ...        ...      ...        ...             ...
# 1376        2435        NaN     1655             Specifications
# 1377      2360mm        NaN   1490mm             Specifications
# 1378      2760mm         17   1770mm             Specifications
# 1379      2360mm         14   1680mm             Specifications
# 1380      2673mm         16   1822mm             Specifications
#
# [1381 rows x 79 columns]

# %%
df5=df["car_links"]

# %%
df_kolkata=pd.concat([df_kolkata,df5],axis=1)

# %%
df_kolkata
# Out:
#       it      ft         bt        km transmission  ownerNo      owner  \
# 0      0  Petrol      Sedan    70,000    Automatic        3  3rd Owner
# 1      0  Petrol  Hatchback    23,981       Manual        1  1st Owner
# 2      0  Petrol        SUV     7,100    Automatic        1  1st Owner
# 3      0  Petrol  Hatchback    71,574       Manual        2  2nd Owner
# 4      0  Diesel        SUV    50,000    Automatic        2  2nd Owner
# ...   ..     ...        ...       ...          ...      ...        ...
# 1376   0  Petrol  Hatchback    10,000       Manual        1  1st Owner
# 1377   0  Petrol  Hatchback  1,20,000       Manual        1  1st Owner
# 1378   0  Petrol      Sedan    50,000    Automatic        3  3rd Owner
# 1379   0  Petrol  Hatchback    40,000       Manual        1  1st Owner
# 1380   0  Diesel        SUV  1,20,000       Manual        2  2nd Owner
#
#                 oem                  model  modelYear  ...  Turning Radius  \
# 0            Toyota           Toyota Camry       2014  ...      5.5 metres
# 1            Datsun          Datsun RediGO       2017  ...            4.7m
# 2           Renault          Renault Kiger       2021  ...             NaN
# 3           Hyundai            Hyundai i20       2011  ...          5.20 m
# 4              Audi                Audi Q3       2014  ...      5.9 metres
# ...             ...                    ...        ...  ...             ...
# 1376         Maruti         Maruti Celerio       2022  ...             NaN
# 1377         Maruti        Maruti Alto 800       2014  ...      4.6 metres
# 1378  Mercedes-Benz  Mercedes-Benz C-Class       2011  ...     5.42 metres
# 1379         Maruti            Maruti Ritz       2012  ...      4.7 metres
# 1380        Renault         Renault Duster       2017  ...      5.2 metres
#
#              Tyre Type Value Configuration Values per Cylinder Wheel Base  \
# 0      Tubeless,Radial                DOHC                 4.0     2775mm
# 1                  NaN                DOHC                 4.0     2348mm
# 2     Tubeless, Radial                 NaN                 4.0       2500
# 3      Tubeless,Radial                DOHC                 4.0   2,525 mm
# 4      Tubeless,Radial                DOHC                 4.0     2603mm
# ...                ...                 ...                 ...        ...
# 1376  Tubeless, Radial                 NaN                 4.0       2435
# 1377    Tubeless Tyres                DOHC                 4.0     2360mm
# 1378   Tubeless,Radial                 NaN                 4.0     2760mm
# 1379   Tubeless,Radial                DOHC                 4.0     2360mm
# 1380   Tubeless,Radial                DOHC                 4.0     2673mm
#
#       Wheel Size    Width commonIcon         heading  \
# 0             17   1825mm             Specifications
# 1            NaN   1560mm             Specifications
# 2            NaN     1750             Specifications
# 3             14  1710 mm             Specifications
# 4             16   2019mm             Specifications
# ...          ...      ...        ...             ...
# 1376         NaN     1655             Specifications
# 1377         NaN   1490mm             Specifications
# 1378          17   1770mm             Specifications
# 1379          14   1680mm             Specifications
# 1380          16   1822mm             Specifications
#
#                                               car_links
# 0     https://www.cardekho.com/used-car-details/used...
# 1     https://www.cardekho.com/buy-used-car-details/...
# 2     https://www.cardekho.com/used-car-details/used...
# 3     https://www.cardekho.com/buy-used-car-details/...
# 4     https://www.cardekho.com/used-car-details/used...
# ...                                                 ...
# 1376  https://www.cardekho.com/used-car-details/used...
# 1377  https://www.cardekho.com/used-car-details/used...
# 1378  https://www.cardekho.com/used-car-details/used...
# 1379  https://www.cardekho.com/used-car-details/used...
# 1380  https://www.cardekho.com/used-car-details/used...
#
# [1381 rows x 80 columns]

# %%
df_kolkata["city"]="Kolkata"

# %%
df_kolkata
# Out:
#       it      ft         bt        km transmission  ownerNo      owner  \
# 0      0  Petrol      Sedan    70,000    Automatic        3  3rd Owner
# 1      0  Petrol  Hatchback    23,981       Manual        1  1st Owner
# 2      0  Petrol        SUV     7,100    Automatic        1  1st Owner
# 3      0  Petrol  Hatchback    71,574       Manual        2  2nd Owner
# 4      0  Diesel        SUV    50,000    Automatic        2  2nd Owner
# ...   ..     ...        ...       ...          ...      ...        ...
# 1376   0  Petrol  Hatchback    10,000       Manual        1  1st Owner
# 1377   0  Petrol  Hatchback  1,20,000       Manual        1  1st Owner
# 1378   0  Petrol      Sedan    50,000    Automatic        3  3rd Owner
# 1379   0  Petrol  Hatchback    40,000       Manual        1  1st Owner
# 1380   0  Diesel        SUV  1,20,000       Manual        2  2nd Owner
#
#                 oem                  model  modelYear  ...         Tyre Type  \
# 0            Toyota           Toyota Camry       2014  ...   Tubeless,Radial
# 1            Datsun          Datsun RediGO       2017  ...               NaN
# 2           Renault          Renault Kiger       2021  ...  Tubeless, Radial
# 3           Hyundai            Hyundai i20       2011  ...   Tubeless,Radial
# 4              Audi                Audi Q3       2014  ...   Tubeless,Radial
# ...             ...                    ...        ...  ...               ...
# 1376         Maruti         Maruti Celerio       2022  ...  Tubeless, Radial
# 1377         Maruti        Maruti Alto 800       2014  ...    Tubeless Tyres
# 1378  Mercedes-Benz  Mercedes-Benz C-Class       2011  ...   Tubeless,Radial
# 1379         Maruti            Maruti Ritz       2012  ...   Tubeless,Radial
# 1380        Renault         Renault Duster       2017  ...   Tubeless,Radial
#
#      Value Configuration Values per Cylinder Wheel Base Wheel Size    Width  \
# 0                   DOHC                 4.0     2775mm         17   1825mm
# 1                   DOHC                 4.0     2348mm        NaN   1560mm
# 2                    NaN                 4.0       2500        NaN     1750
# 3                   DOHC                 4.0   2,525 mm         14  1710 mm
# 4                   DOHC                 4.0     2603mm         16   2019mm
# ...                  ...                 ...        ...        ...      ...
# 1376                 NaN                 4.0       2435        NaN     1655
# 1377                DOHC                 4.0     2360mm        NaN   1490mm
# 1378                 NaN                 4.0     2760mm         17   1770mm
# 1379                DOHC                 4.0     2360mm         14   1680mm
# 1380                DOHC                 4.0     2673mm         16   1822mm
#
#      commonIcon         heading  \
# 0                Specifications
# 1                Specifications
# 2                Specifications
# 3                Specifications
# 4                Specifications
# ...         ...             ...
# 1376             Specifications
# 1377             Specifications
# 1378             Specifications
# 1379             Specifications
# 1380             Specifications
#
#                                               car_links     city
# 0     https://www.cardekho.com/used-car-details/used...  Kolkata
# 1     https://www.cardekho.com/buy-used-car-details/...  Kolkata
# 2     https://www.cardekho.com/used-car-details/used...  Kolkata
# 3     https://www.cardekho.com/buy-used-car-details/...  Kolkata
# 4     https://www.cardekho.com/used-car-details/used...  Kolkata
# ...                                                 ...      ...
# 1376  https://www.cardekho.com/used-car-details/used...  Kolkata
# 1377  https://www.cardekho.com/used-car-details/used...  Kolkata
# 1378  https://www.cardekho.com/used-car-details/used...  Kolkata
# 1379  https://www.cardekho.com/used-car-details/used...  Kolkata
# 1380  https://www.cardekho.com/used-car-details/used...  Kolkata
#
# [1381 rows x 81 columns]

# %%
path="D:\CHITRA\CARDEHO\\unclean_kolkata.csv"
df_kolkata.to_csv(path, index=False)
